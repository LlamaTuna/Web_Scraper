# %%
# Python program to scrape heading tags Jeff Becker 1/2023 V.1
impordf[df.label == 1].Headlinet pickle
from IPython import display
import math
from pprint import pprint
import requests
import nltk
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import random
from wordcloud import WordCloud
import os
import spacy
from textblob import TextBlob
from pattern.en import sentiment
import urllib3 
import re
import datetime
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

nlp = spacy.load('en_core_web_sm')
# %matplotlib inline
sns.set(style='darkgrid', context='notebook', font_scale=1.5, palette='Dark2')

headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"} 
#find what headers you are sending here: https://www.whatismybrowser.com/detect/what-http-headers-is-my-browser-sending

input_url = input("Enter the full URL to scrape: ") #user inputs URL to scrape
utc_datetime = datetime.datetime.utcnow() #utc data concatenated with sliced URL name, filename stored
date_string = utc_datetime.strftime("%Y-%m-%d-%H%M_UTC") 
filename = f'{input_url[8:len(date_string)]}_{date_string}'


cleanData = []
tag_words = []
regex = re.compile('[^a-zA-Z]')

def scrape(url_link):
    # create a list by type of heading tags
    # the user will have to determine what "h" tags are valid for given URL
    heading_tags = ["h1","h2","h3","h4"] 
    request = requests.get(url_link, headers = headers)
    Soup = BeautifulSoup(request.text, 'lxml') #create soup obejct

    if request.status_code == 200: #error handling for URL request
        print('Request successful.')
    elif request.status_code == 404:
        print('Error 404: Not Found.')
        
    for tags in Soup.find_all(heading_tags):
        tag_words.append(tags.text.strip())
        
    return tag_words
    
def post_process(scraped_list):   
    for i in scraped_list:  #slice based on data you want to include. Some junk data can be removed
        if len(i) > 16:    #Fliter a composite length of strings based on targeted threshold
            cleanData.append(regex.sub(' ', i)) #remove digits and punctuation

    deDup = list(set(cleanData))#convert to set then back to list to eliminate duplicate headline strings

    with open(filename, "wb") as fp: #Pickling data as list with UTC time stamp
        pickle.dump(deDup, fp)

    # with open(filename,'w') as a: # uncomment if you want to save a text file for manual review
    #     a.write('\n'.join(cleanData))

scraped_content = scrape(input_url) #scrape input URL
post_process(scraped_content) #process scraped tag data
# Out:
# Enter the full URL to scrape: https://www.kptv.com/
# Request successful.

# %% [markdown]
# <h3> The variable name "filename" is the stored value of the file. We can either work with that data or load previously scraped data at this point, i.e "foxnews_2023-01-07-2241_UTC". Be aware that pickled files will not display in Jupyter (UTF-8 error). To manually review the text, you have to uncomment the above text file code.<br><br> Once loaded, we slice and print the first five headlines to see if the content is as expected. </h3>

# %%
with open(filename, "rb") as fp: #Either load stored variable value for "filename" or saved pickled "example_1_0_23"
    saved_text = pickle.load(fp)

saved_text[0:5] #confirm your expected text is correct
# Out:
# ['Beloved Portland tree falls during wind storm',
#  '   cats at Silverton cat rescue die in fire',
#  'Pedestrian killed in Centennial Neighborhood crash  PPB says',
#  'Police  Idaho slaying suspect s DNA found at crime scene',
#  'Former ODOT employees sentenced to prison for    year crime spree']

# %% [markdown]
# <h3> Once we have the right text, we can check the polarity of the scraped headlines.
# <br><br>
# Sentence-level polarity detection is to decide whether a given sentence expresses either an overall positive or negative opinion. The compund score is tehoverall sentiment of the headline. The scale is -1 to 1, with -1 being the most negative and 1 being the most positive. </h3>

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA 

sia = SIA() 
score_data = []

for line in saved_text:
    score = sia.polarity_scores(line)
    score['Headline'] = line
    score_data.append(score)

pprint(score_data, width=100) #pretty print sentiment scores
# Out:
# [{'Headline': 'Beloved Portland tree falls during wind storm',
#   'compound': 0.5106,
#   'neg': 0.0,
#   'neu': 0.645,
#   'pos': 0.355},
#  {'Headline': '   cats at Silverton cat rescue die in fire',
#   'compound': -0.4588,
#   'neg': 0.432,
#   'neu': 0.342,
#   'pos': 0.226},
#  {'Headline': 'Pedestrian killed in Centennial Neighborhood crash  PPB says',
#   'compound': -0.802,
#   'neg': 0.545,
#   'neu': 0.455,
#   'pos': 0.0},
#  {'Headline': 'Police  Idaho slaying suspect s DNA found at crime scene',
#   'compound': -0.6908,
#   'neg': 0.449,
#   'neu': 0.551,
#   'pos': 0.0},
#  {'Headline': 'Former ODOT employees sentenced to prison for    year crime spree',
#   'compound': -0.7845,
#   'neg': 0.53,
#   'neu': 0.47,
#   'pos': 0.0},
#  {'Headline': 'Pedestrian struck  killed in N  Portland crash identified',
#   'compound': -0.8481,
#   'neg': 0.697,
#   'neu': 0.303,
#   'pos': 0.0},
#  {'Headline': '   year old found driving stolen car in N  Portland',
#   'compound': -0.4939,
#   'neg': 0.314,
#   'neu': 0.686,
#   'pos': 0.0},
#  {'Headline': 'Demolition begins on fire ravaged Portland church',
#   'compound': -0.34,
#   'neg': 0.286,
#   'neu': 0.714,
#   'pos': 0.0},
#  {'Headline': 'Suspect reveals motive behind burning historic Portland church',
#   'compound': -0.296,
#   'neg': 0.239,
#   'neu': 0.761,
#   'pos': 0.0},
#  {'Headline': 'Reward offered for information on Portland bank arson suspect',
#   'compound': 0.3612,
#   'neg': 0.171,
#   'neu': 0.543,
#   'pos': 0.287},
#  {'Headline': 'Man accused of chewing MAX passenger s face claims victim was  robot ',
#   'compound': -0.5106,
#   'neg': 0.323,
#   'neu': 0.677,
#   'pos': 0.0},
#  {'Headline': 'Turner  Haliburton leads Pacers past Trail Blazers       ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'New West Linn mayor is youngest in city s history',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': ' We just really want him to come home   Portland man with dementia missing for days',
#   'compound': -0.1548,
#   'neg': 0.131,
#   'neu': 0.774,
#   'pos': 0.095},
#  {'Headline': 'Blazers lose  th straight on road  Raptors win        ',
#   'compound': 0.4588,
#   'neg': 0.201,
#   'neu': 0.373,
#   'pos': 0.425},
#  {'Headline': 'Oregon leads US with highest voter turnout',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Camas driftwood artist makes masterpieces out of nature',
#   'compound': 0.5423,
#   'neg': 0.0,
#   'neu': 0.667,
#   'pos': 0.333},
#  {'Headline': 'Homeless man seriously injured in shooting  arson attack',
#   'compound': -0.7579,
#   'neg': 0.6,
#   'neu': 0.4,
#   'pos': 0.0},
#  {'Headline': 'Oregon Gov  Brown reflects on turbulent final term',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Motorcyclist killed in crash with car in Hazel Dell',
#   'compound': -0.802,
#   'neg': 0.507,
#   'neu': 0.493,
#   'pos': 0.0},
#  {'Headline': 'Vancouver teacher arrested for sending student nude photo  Police',
#   'compound': -0.4767,
#   'neg': 0.279,
#   'neu': 0.721,
#   'pos': 0.0},
#  {'Headline': '  arrested    illegal guns found after police track speeding car across Portland',
#   'compound': -0.7717,
#   'neg': 0.427,
#   'neu': 0.573,
#   'pos': 0.0},
#  {'Headline': 'Police arrest suspect in deadly Portland hotel shooting',
#   'compound': -0.5574,
#   'neg': 0.434,
#   'neu': 0.566,
#   'pos': 0.0},
#  {'Headline': 'First Latino sheriff of Marion County dies at   ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'What s up with that  bomb cyclone    Plus a very mild first half of January',
#   'compound': -0.4939,
#   'neg': 0.211,
#   'neu': 0.789,
#   'pos': 0.0},
#  {'Headline': 'Portland bike courier recovering after being hit by wrong way driver',
#   'compound': -0.4767,
#   'neg': 0.237,
#   'neu': 0.763,
#   'pos': 0.0},
#  {'Headline': 'Teenager arrested in attempted murder shooting of    year old boy',
#   'compound': -0.8316,
#   'neg': 0.494,
#   'neu': 0.506,
#   'pos': 0.0},
#  {'Headline': '   year old arrested for shooting that injures   outside Franklin High School',
#   'compound': -0.4767,
#   'neg': 0.237,
#   'neu': 0.763,
#   'pos': 0.0},
#  {'Headline': 'Man arrested after speeding  crashing car with no license plates',
#   'compound': -0.6486,
#   'neg': 0.398,
#   'neu': 0.602,
#   'pos': 0.0},
#  {'Headline': 'Money stolen from safe at Oak Grove bar in a matter of minutes  employees say',
#   'compound': -0.0516,
#   'neg': 0.176,
#   'neu': 0.604,
#   'pos': 0.22},
#  {'Headline': 'Suspect extradited to Portland after arrest for      house party murder',
#   'compound': -0.765,
#   'neg': 0.517,
#   'neu': 0.333,
#   'pos': 0.15}]

# %% [markdown]
# <h3>Now we can create Pandas data frame to visualize some of the headlines and scores. Compound is overall sentiment. </h3>

# %%
df = pd.DataFrame.from_records(score_data)
df
# Out:
#       neg    neu    pos  compound  \
# 0   0.000  0.645  0.355    0.5106
# 1   0.432  0.342  0.226   -0.4588
# 2   0.545  0.455  0.000   -0.8020
# 3   0.449  0.551  0.000   -0.6908
# 4   0.530  0.470  0.000   -0.7845
# 5   0.697  0.303  0.000   -0.8481
# 6   0.314  0.686  0.000   -0.4939
# 7   0.286  0.714  0.000   -0.3400
# 8   0.239  0.761  0.000   -0.2960
# 9   0.171  0.543  0.287    0.3612
# 10  0.323  0.677  0.000   -0.5106
# 11  0.000  1.000  0.000    0.0000
# 12  0.000  1.000  0.000    0.0000
# 13  0.131  0.774  0.095   -0.1548
# 14  0.201  0.373  0.425    0.4588
# 15  0.000  1.000  0.000    0.0000
# 16  0.000  0.667  0.333    0.5423
# 17  0.600  0.400  0.000   -0.7579
# 18  0.000  1.000  0.000    0.0000
# 19  0.507  0.493  0.000   -0.8020
# 20  0.279  0.721  0.000   -0.4767
# 21  0.427  0.573  0.000   -0.7717
# 22  0.434  0.566  0.000   -0.5574
# 23  0.000  1.000  0.000    0.0000
# 24  0.211  0.789  0.000   -0.4939
# 25  0.237  0.763  0.000   -0.4767
# 26  0.494  0.506  0.000   -0.8316
# 27  0.237  0.763  0.000   -0.4767
# 28  0.398  0.602  0.000   -0.6486
# 29  0.176  0.604  0.220   -0.0516
# 30  0.517  0.333  0.150   -0.7650
#
#                                              Headline
# 0       Beloved Portland tree falls during wind storm
# 1            cats at Silverton cat rescue die in fire
# 2   Pedestrian killed in Centennial Neighborhood c...
# 3   Police  Idaho slaying suspect s DNA found at c...
# 4   Former ODOT employees sentenced to prison for ...
# 5   Pedestrian struck  killed in N  Portland crash...
# 6      year old found driving stolen car in N  Por...
# 7   Demolition begins on fire ravaged Portland church
# 8   Suspect reveals motive behind burning historic...
# 9   Reward offered for information on Portland ban...
# 10  Man accused of chewing MAX passenger s face cl...
# 11  Turner  Haliburton leads Pacers past Trail Bla...
# 12  New West Linn mayor is youngest in city s history
# 13   We just really want him to come home   Portla...
# 14  Blazers lose  th straight on road  Raptors win...
# 15         Oregon leads US with highest voter turnout
# 16  Camas driftwood artist makes masterpieces out ...
# 17  Homeless man seriously injured in shooting  ar...
# 18  Oregon Gov  Brown reflects on turbulent final ...
# 19  Motorcyclist killed in crash with car in Hazel...
# 20  Vancouver teacher arrested for sending student...
# 21    arrested    illegal guns found after police ...
# 22  Police arrest suspect in deadly Portland hotel...
# 23   First Latino sheriff of Marion County dies at
# 24  What s up with that  bomb cyclone    Plus a ve...
# 25  Portland bike courier recovering after being h...
# 26  Teenager arrested in attempted murder shooting...
# 27     year old arrested for shooting that injures...
# 28  Man arrested after speeding  crashing car with...
# 29  Money stolen from safe at Oak Grove bar in a m...
# 30  Suspect extradited to Portland after arrest fo...

# %% [markdown]
# <h3>Now assign a positive or negative score based on the threshold for the compound score. It's the user's discretion on how to assign a score. In this case we'll use +/- .025 </h3>

# %%
df['label'] = 0
df.loc[df['compound'] > 0.25, 'label'] = 1
df.loc[df['compound'] < -0.25, 'label'] = -1
df
# Out:
#       neg    neu    pos  compound  \
# 0   0.000  0.645  0.355    0.5106
# 1   0.432  0.342  0.226   -0.4588
# 2   0.545  0.455  0.000   -0.8020
# 3   0.449  0.551  0.000   -0.6908
# 4   0.530  0.470  0.000   -0.7845
# 5   0.697  0.303  0.000   -0.8481
# 6   0.314  0.686  0.000   -0.4939
# 7   0.286  0.714  0.000   -0.3400
# 8   0.239  0.761  0.000   -0.2960
# 9   0.171  0.543  0.287    0.3612
# 10  0.323  0.677  0.000   -0.5106
# 11  0.000  1.000  0.000    0.0000
# 12  0.000  1.000  0.000    0.0000
# 13  0.131  0.774  0.095   -0.1548
# 14  0.201  0.373  0.425    0.4588
# 15  0.000  1.000  0.000    0.0000
# 16  0.000  0.667  0.333    0.5423
# 17  0.600  0.400  0.000   -0.7579
# 18  0.000  1.000  0.000    0.0000
# 19  0.507  0.493  0.000   -0.8020
# 20  0.279  0.721  0.000   -0.4767
# 21  0.427  0.573  0.000   -0.7717
# 22  0.434  0.566  0.000   -0.5574
# 23  0.000  1.000  0.000    0.0000
# 24  0.211  0.789  0.000   -0.4939
# 25  0.237  0.763  0.000   -0.4767
# 26  0.494  0.506  0.000   -0.8316
# 27  0.237  0.763  0.000   -0.4767
# 28  0.398  0.602  0.000   -0.6486
# 29  0.176  0.604  0.220   -0.0516
# 30  0.517  0.333  0.150   -0.7650
#
#                                              Headline  label
# 0       Beloved Portland tree falls during wind storm      1
# 1            cats at Silverton cat rescue die in fire     -1
# 2   Pedestrian killed in Centennial Neighborhood c...     -1
# 3   Police  Idaho slaying suspect s DNA found at c...     -1
# 4   Former ODOT employees sentenced to prison for ...     -1
# 5   Pedestrian struck  killed in N  Portland crash...     -1
# 6      year old found driving stolen car in N  Por...     -1
# 7   Demolition begins on fire ravaged Portland church     -1
# 8   Suspect reveals motive behind burning historic...     -1
# 9   Reward offered for information on Portland ban...      1
# 10  Man accused of chewing MAX passenger s face cl...     -1
# 11  Turner  Haliburton leads Pacers past Trail Bla...      0
# 12  New West Linn mayor is youngest in city s history      0
# 13   We just really want him to come home   Portla...      0
# 14  Blazers lose  th straight on road  Raptors win...      1
# 15         Oregon leads US with highest voter turnout      0
# 16  Camas driftwood artist makes masterpieces out ...      1
# 17  Homeless man seriously injured in shooting  ar...     -1
# 18  Oregon Gov  Brown reflects on turbulent final ...      0
# 19  Motorcyclist killed in crash with car in Hazel...     -1
# 20  Vancouver teacher arrested for sending student...     -1
# 21    arrested    illegal guns found after police ...     -1
# 22  Police arrest suspect in deadly Portland hotel...     -1
# 23   First Latino sheriff of Marion County dies at         0
# 24  What s up with that  bomb cyclone    Plus a ve...     -1
# 25  Portland bike courier recovering after being h...     -1
# 26  Teenager arrested in attempted murder shooting...     -1
# 27     year old arrested for shooting that injures...     -1
# 28  Man arrested after speeding  crashing car with...     -1
# 29  Money stolen from safe at Oak Grove bar in a m...      0
# 30  Suspect extradited to Portland after arrest fo...     -1

# %%
df2 = df[['Headline', 'label']] #save CSV of data with labels for future processing
df2.to_csv(filename +'.csv', mode='a', encoding='utf-8', index=False)

# %%
print("Positive headlines:\n") #print a sample of categorized headlines
pprint(list(df[df['label'] == 1].Headline)[:10], width=200)

print("\nNegative headlines:\n")
pprint(list(df[df['label'] == -1].Headline)[:10], width=200)
# Out:
# Positive headlines:
#
# ['Beloved Portland tree falls during wind storm',
#  'Reward offered for information on Portland bank arson suspect',
#  'Blazers lose  th straight on road  Raptors win        ',
#  'Camas driftwood artist makes masterpieces out of nature']
#
# Negative headlines:
#
# ['   cats at Silverton cat rescue die in fire',
#  'Pedestrian killed in Centennial Neighborhood crash  PPB says',
#  'Police  Idaho slaying suspect s DNA found at crime scene',
#  'Former ODOT employees sentenced to prison for    year crime spree',
#  'Pedestrian struck  killed in N  Portland crash identified',
#  '   year old found driving stolen car in N  Portland',
#  'Demolition begins on fire ravaged Portland church',
#  'Suspect reveals motive behind burning historic Portland church',
#  'Man accused of chewing MAX passenger s face claims victim was  robot ',
#  'Homeless man seriously injured in shooting  arson attack']

# %%
print(df.label.value_counts())

print(df.label.value_counts(normalize=True) * 100) #normalize data
# Out:
# -1    20
#  0     7
#  1     4
# Name: label, dtype: int64
# -1    64.516129
#  0    22.580645
#  1    12.903226
# Name: label, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 8)) #create a bar graph of sentiment distributions

counts = df.label.value_counts(normalize=True) * 100

sns.barplot(x=counts.index, y=counts, ax=ax)

ax.set_xticklabels(['Negative', 'Neutral', 'Positive'])
ax.set_ylabel("Percentage")

plt.show()

# %%
textblob_sentiment=[]
for s in saved_text:
    txt= TextBlob(s)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([s,a,b])

# %%
df_textblob = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_textblob
# Out:
#                                              Sentence  Polarity  Subjectivity
# 0       Beloved Portland tree falls during wind storm  0.700000      1.000000
# 1            cats at Silverton cat rescue die in fire  0.000000      0.000000
# 2   Pedestrian killed in Centennial Neighborhood c... -0.200000      0.000000
# 3   Police  Idaho slaying suspect s DNA found at c...  0.000000      0.000000
# 4   Former ODOT employees sentenced to prison for ...  0.000000      0.000000
# 5   Pedestrian struck  killed in N  Portland crash... -0.200000      0.000000
# 6      year old found driving stolen car in N  Por...  0.100000      0.200000
# 7   Demolition begins on fire ravaged Portland church  0.000000      0.000000
# 8   Suspect reveals motive behind burning historic... -0.200000      0.350000
# 9   Reward offered for information on Portland ban...  0.000000      0.000000
# 10  Man accused of chewing MAX passenger s face cl... -0.075000      0.050000
# 11  Turner  Haliburton leads Pacers past Trail Bla... -0.250000      0.250000
# 12  New West Linn mayor is youngest in city s history  0.136364      0.454545
# 13   We just really want him to come home   Portla...  0.000000      0.125000
# 14  Blazers lose  th straight on road  Raptors win...  0.500000      0.400000
# 15         Oregon leads US with highest voter turnout  0.000000      0.000000
# 16  Camas driftwood artist makes masterpieces out ...  0.000000      0.000000
# 17  Homeless man seriously injured in shooting  ar... -0.333333      0.666667
# 18  Oregon Gov  Brown reflects on turbulent final ...  0.000000      1.000000
# 19  Motorcyclist killed in crash with car in Hazel... -0.200000      0.000000
# 20  Vancouver teacher arrested for sending student...  0.000000      0.000000
# 21    arrested    illegal guns found after police ... -0.500000      0.500000
# 22  Police arrest suspect in deadly Portland hotel... -0.125000      0.200000
# 23   First Latino sheriff of Marion County dies at     0.250000      0.333333
# 24  What s up with that  bomb cyclone    Plus a ve...  0.172222      0.383333
# 25  Portland bike courier recovering after being h... -0.500000      0.900000
# 26  Teenager arrested in attempted murder shooting...  0.100000      0.200000
# 27     year old arrested for shooting that injures...  0.086667      0.263333
# 28  Man arrested after speeding  crashing car with...  0.000000      0.000000
# 29  Money stolen from safe at Oak Grove bar in a m...  0.500000      0.500000
# 30  Suspect extradited to Portland after arrest fo... -0.050000      0.000000

# %%
df_textblob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      31 non-null     object
#  1   Polarity      31 non-null     float64
#  2   Subjectivity  31 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 872.0+ bytes

# %%
sns.displot(df_textblob["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Textblob)")
# Out:
# Text(0.5, 15.440000000000012, 'Sentence Polarity (Textblob)')

# %%
sns.displot(df_textblob["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Textblob)")
# Out:
# Text(0.5, 15.440000000000012, 'Sentence Subjectivity (Textblob)')

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer #tokenize and remove stop words from corpus
from nltk.corpus import stopwords

stop_words = stopwords.words('english')

def process_text(headlines):
    sent_tokens = []
    for headline in headlines:
        head_tokens = word_tokenize(headline)
        head_tokens = [t.lower() for t in head_tokens if t.lower() not in stop_words]
        sent_tokens.extend(head_tokens)
        print(headline)
    return sent_tokens

# %%
pos_lines = list(df[df.label == 1].Headline)


pos_tokens = process_text(pos_lines)


pos_freq = nltk.FreqDist(pos_tokens)

# %%
word_freq = pd.DataFrame(my_counter.most_common(30),
                             columns=['Words', 'count'])

# %%
y_val = [x[1] for x in pos_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Positive Word Frequency Distribution")
plt.show()

# %%
y_final = []
for i, k, z, t in zip(y_val[0::4], y_val[1::4], y_val[2::4], y_val[3::4]):
    y_final.append(math.log(i + k + z + t))

x_val = [math.log(i + 1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Positive Word Frequency Distribution")
plt.plot(x_val, y_final)
plt.show()

# %%
neg_lines = list(df2[df2.label == -1].Headline)

neg_tokens = process_text(neg_lines)
neg_freq = nltk.FreqDist(neg_tokens)

neg_freq.most_common(20)
# Out:
# [('portland', 21),
#  ('suspect', 10),
#  ('arrested', 10),
#  ('police', 8),
#  ('year', 8),
#  ('car', 8),
#  ('shooting', 8),
#  ('man', 7),
#  ('killed', 6),
#  ('crash', 6),
#  ('found', 6),
#  ('old', 6),
#  ('fire', 4),
#  ('pedestrian', 4),
#  ('crime', 4),
#  ('n', 4),
#  ('church', 4),
#  ('arson', 4),
#  ('speeding', 4),
#  ('arrest', 4)]

# %%
y_val = [x[1] for x in neg_freq.most_common()]

fig = plt.figure(figsize=(12,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Negative Word Frequency Distribution")
plt.show()

# %%
y_final = []
for i, k, z in zip(y_val[0::3], y_val[1::3], y_val[2::3]):
    if i + k + z == 0:
        break
    y_final.append(math.log(i + k + z))

x_val = [math.log(i+1) for i in range(len(y_final))]

fig = plt.figure(figsize=(12,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Negative Word Frequency Distribution")
plt.plot(x_val, y_final)
plt.show()

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer #tokenize and remove stop words from corpus
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

stop_tokens = []

def process_text(headlines):
    for line in headlines:
        toks = word_tokenize(line)
        toks = [t.lower() for t in toks if t.lower() not in stop_words]
        stop_tokens.extend(toks)
    
    return stop_tokens

process_text(saved_text)
# Out:
# ['beloved',
#  'portland',
#  'tree',
#  'falls',
#  'wind',
#  'storm',
#  'cats',
#  'silverton',
#  'cat',
#  'rescue',
#  'die',
#  'fire',
#  'pedestrian',
#  'killed',
#  'centennial',
#  'neighborhood',
#  'crash',
#  'ppb',
#  'says',
#  'police',
#  'idaho',
#  'slaying',
#  'suspect',
#  'dna',
#  'found',
#  'crime',
#  'scene',
#  'former',
#  'odot',
#  'employees',
#  'sentenced',
#  'prison',
#  'year',
#  'crime',
#  'spree',
#  'pedestrian',
#  'struck',
#  'killed',
#  'n',
#  'portland',
#  'crash',
#  'identified',
#  'year',
#  'old',
#  'found',
#  'driving',
#  'stolen',
#  'car',
#  'n',
#  'portland',
#  'demolition',
#  'begins',
#  'fire',
#  'ravaged',
#  'portland',
#  'church',
#  'suspect',
#  'reveals',
#  'motive',
#  'behind',
#  'burning',
#  'historic',
#  'portland',
#  'church',
#  'reward',
#  'offered',
#  'information',
#  'portland',
#  'bank',
#  'arson',
#  'suspect',
#  'man',
#  'accused',
#  'chewing',
#  'max',
#  'passenger',
#  'face',
#  'claims',
#  'victim',
#  'robot',
#  'turner',
#  'haliburton',
#  'leads',
#  'pacers',
#  'past',
#  'trail',
#  'blazers',
#  'new',
#  'west',
#  'linn',
#  'mayor',
#  'youngest',
#  'city',
#  'history',
#  'really',
#  'want',
#  'come',
#  'home',
#  'portland',
#  'man',
#  'dementia',
#  'missing',
#  'days',
#  'blazers',
#  'lose',
#  'th',
#  'straight',
#  'road',
#  'raptors',
#  'win',
#  'oregon',
#  'leads',
#  'us',
#  'highest',
#  'voter',
#  'turnout',
#  'camas',
#  'driftwood',
#  'artist',
#  'makes',
#  'masterpieces',
#  'nature',
#  'homeless',
#  'man',
#  'seriously',
#  'injured',
#  'shooting',
#  'arson',
#  'attack',
#  'oregon',
#  'gov',
#  'brown',
#  'reflects',
#  'turbulent',
#  'final',
#  'term',
#  'motorcyclist',
#  'killed',
#  'crash',
#  'car',
#  'hazel',
#  'dell',
#  'vancouver',
#  'teacher',
#  'arrested',
#  'sending',
#  'student',
#  'nude',
#  'photo',
#  'police',
#  'arrested',
#  'illegal',
#  'guns',
#  'found',
#  'police',
#  'track',
#  'speeding',
#  'car',
#  'across',
#  'portland',
#  'police',
#  'arrest',
#  'suspect',
#  'deadly',
#  'portland',
#  'hotel',
#  'shooting',
#  'first',
#  'latino',
#  'sheriff',
#  'marion',
#  'county',
#  'dies',
#  'bomb',
#  'cyclone',
#  'plus',
#  'mild',
#  'first',
#  'half',
#  'january',
#  'portland',
#  'bike',
#  'courier',
#  'recovering',
#  'hit',
#  'wrong',
#  'way',
#  'driver',
#  'teenager',
#  'arrested',
#  'attempted',
#  'murder',
#  'shooting',
#  'year',
#  'old',
#  'boy',
#  'year',
#  'old',
#  'arrested',
#  'shooting',
#  'injures',
#  'outside',
#  'franklin',
#  'high',
#  'school',
#  'man',
#  'arrested',
#  'speeding',
#  'crashing',
#  'car',
#  'license',
#  'plates',
#  'money',
#  'stolen',
#  'safe',
#  'oak',
#  'grove',
#  'bar',
#  'matter',
#  'minutes',
#  'employees',
#  'say',
#  'suspect',
#  'extradited',
#  'portland',
#  'arrest',
#  'house',
#  'party',
#  'murder']

# %%
from nltk.stem import WordNetLemmatizer #Lemmatize the words with stopwords removed
ls = WordNetLemmatizer()
lem_tokens = []
for t in stop_tokens:
    lemma = ls.lemmatize(t) 
    if len(lemma) > 1: #remove random single charcters from lemmatizing
        lem_tokens.append(lemma)

# %%
#lem_tokens #uncomment to see ouput of stemmed tokens

# %%
from collections import Counter     #get the top 30 words to make a data frame
my_counter = Counter(lem_tokens)
# my_counter.most_common(25)

word_freq = pd.DataFrame(my_counter.most_common(30),
                             columns=['Words', 'count'])
word_freq
# Out:
#          Words  count
# 0     portland     11
# 1      suspect      5
# 2     arrested      5
# 3       police      4
# 4         year      4
# 5          car      4
# 6          man      4
# 7     shooting      4
# 8       killed      3
# 9        crash      3
# 10       found      3
# 11         old      3
# 12         cat      2
# 13        fire      2
# 14  pedestrian      2
# 15         say      2
# 16       crime      2
# 17    employee      2
# 18      stolen      2
# 19      church      2
# 20       arson      2
# 21        lead      2
# 22      blazer      2
# 23      oregon      2
# 24    speeding      2
# 25      arrest      2
# 26       first      2
# 27      murder      2
# 28     beloved      1
# 29        tree      1

# %%
fig, ax = plt.subplots(figsize=(14, 14))  #make a bar graph ot the top 30 words from the data frame

# Plot horizontal bar graph
word_freq.sort_values(by='count').plot.barh(
                                            x='Words',
                                            y='count',
                                            ax=ax,
                                            color="blue")
ax.set_title("Most Common Words Found")
plt.show()

# %%
tokens = []

tokenizer = RegexpTokenizer(r'\w+')
for i in saved_text:
    tokens.append(tokenizer.tokenize(i))
flat_tokens = [item for sublist in stem_tokens for item in sublist] #flatten list of lists

# %%
flat_tokens = [item for sublist in stop_tokens_plot for item in sublist] 
flat_tokens
