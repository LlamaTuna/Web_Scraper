# %% [markdown]
# <h7>
# Jeff Becker # 200182924 <br>
# U of L Goldsmiths <br>
# BSc <br>
# CM2015 Programming With Data<br>
# Midterm Assignment Fall 2022<br>
#
# </h7>
# <br>
# <br>
#
#
# <h1> Negative Bias in Online Media Organtization Headlines. </h1>
#
#
# **Thesis:**
# Do online news media organizations have an overall negative bias in the presentation of content to consumers? That is the question that this research will attempt to answer.  I will examine news headlines  and attempt to determine if there is an overall bias towards negative content.
#
# There are various theories as to why a news media organization would exhibit negative bias. Those reasons may include an intentional attempt to encourage engagement by displaying salacious or scandalous content(“clickbait”), unconscious bias towards negativity, political and socially motivated activism, over emphasis on content which is inherently negative, or that newsworthy stories tend to be more negative than positive. The reasons why this occurs are beyond the scope of this project. Rather, I will ask the question: Is there a tendency for a negative bias in news media reporting and attempt to answer that question with scraped data from contemporary online news media organizations.
#
# **Background:**
# There are a multitude of  reasons for the psychological, sociological and physiological motivators regarding a preference for consuming more negative content rather than neutral or positive content. Some theories include the evolutionary component of human survival mechanisms. According to Soroka, Fournier, and Nir a human’s vigilance and attention to potentially threatening elements is neurologically “hardwired (Soroka et al.).
#
# There also may be differences based on environmental factors such as culture, religion, political paradigms, etc. Soroka, Fournier, and Nir’s study, in which they examined people’s psychophysiological reactions to video news content in 17 countries revealed that, globally, humans are more aroused by and attentive to negative news on average (Soroka et al.).
#
# **Abstract:**
# The reasons for news media bias have been extensively studied. These studies involve large data sets, self reporting of respondents and samples of content. The scope of these studies and their implications is vast. This project is not an explainer for sociological or psychological phenomena regarding negative news media bias. Rather, this is a small scale, limited research project only to demonstrate that contemporary news media organizations do in fact have an overall negative bias in their reporting.
#
# Why is negative bias of concern? There is research demonstrating that consumption of negative news media can have negative health consequences (Kathirvel). Therefore, the study of negative bias in the news media is a valid public health concern. There is already a significant mental health decline in the post COVID 19 pandemic world (Lindberg). It is important to consider how news media reporting affects mental health and how news media reporting continues to inform overall sentiment, attitudes and outlook among world citizens.
#
#
# **Methodology:**
# Bias has a number of definitions, however, for the purpose of this research I will adhere to this definition: cause to feel or show inclination or prejudice for or against someone or something. In this instance the inclination is towards negativity. Negativity can be defined a variety of ways but, in the context of sentiment, negativity is pessimism, skepticism and disagreeableness.
#
# It is important that the tools used to score negativity should match the overall definition of negativity. The tools used in this instance is from the Python NLTK library : VADER - Valence Aware Dictionary for sEntiment Reasoning.
#
# Why VADER? VADER has shown good performance with classification accuracy (F1 scores) and in some instances can outperform more sophisticated sentiment analysis tools and even human beings (Hutto and Gilbert).  Additionally VADER does not require training data like some other classifiers which saves time and resources for equally valid results.
#
# Additionally, I’ll use the Textblob library to score subjectivity. Subjectivity lies between [0,1]. Subjectivity quantifies the amount of personal opinion and factual information contained in the text. The higher subjectivity means that the text contains personal opinion rather than factual information.  While this does not necessarily correlate to negative bias, it can inform the level of personal opinion injected into the statement which can be then compared to the relative level of negative bias.
#
#
# The data will be scraped from news media organizations websites. Because of limitations on the amount of data, the scraped data will be the headlines only. Since headlines are intended to encourage engagement, I believe that the headline is a fair indicator of the overall sentiment of the content of the article.
#
# Many headline data uses HTML tags of h1, h2, h3, etc. Because it’s not possible to know without inspecting the div tags of the website, it is an evaluation that has to be made by the researcher. For instance, the website CNN uses class id div tags which can be difficult to scrape without making custom Xpath queries. Creating a special scraper for one site that does not work on other sites may capture data inconsistently. For that reason I will limit the scope to sites that can be scraped for headlines using h1 tags.
#
# I will attempt to keep an even distribution of the types of news sites, based on reputation, so that the types of political and social bias is not focused in one direction. For example, Fox News is notoriously conservative whereas the Guardian US is often regarded as left leaning. I will scrape both of these sites to create a balanced approach. Other sites explored will be the NY Post, the New York Times, the Daily Mail, BBC, along with two of my local news sites, KPTV and Oregonlive. There may be some stylistic variation between traditional news sites and tabloid style news. The Daily Mail is known to have tabloid style reporting whereas the New York Times is known for traditional, in-depth reporting. Based on these distinctions, I'll attempt to answer the question of: is there a difference in the negativity based on the style of reporting?
#
# Each of these scraped sites will receive their own discrete data set which will be labeled and worked with until the conclusion. The raw scrape will be preserved so that it can be reviewed with other sentiment analyzers to compare the accuracy of the results at a later date, should one choose to do so.
#
# At the end of the document I’ll offer a ranking of which news organizations exhibited the most negative bias based on the above methodology.
#
# **Limitations:**
# As stated, the scraper that I have developed only scrapes HTML “h” tags. It is possible that news organizations websites that were not scraped could exhibit less, equal or more bias. My selection of news organizations to scrape is not scientific and may be subject to my own personal bias. The depth and breadth of the project is limited and relies on the operator to select the appropriate website.
#
# Punctuation and digits are eliminated with regex expressions. This may have implications for sentiment analysis. VADER is trained to score punctuation, capitalization and emojis. However when analyzing headlines, emojis are seldom used and punctuation is often skipped due to the style of headline writing. Case is retained for sentiment scoring but not the frequency plots.
#
# The data scraped is lemmatized, not stemmed at the tokenization step. The Porter, Snowball and Lancaster stemmers created too many useless words. For a large machine learning dataset, generalized data is appropriate. For the limited amount of data in this project, and since I am not creating a training and testing data set, that level of stemming is not needed.
#
# The words are lemmatized at the token phase where frequency plots are drawn, not when the sentiment is scored. It is unknown how that may affect the results,
#
# Some words become single characters when lemmatized. For instance “NFL” becomes “n” “f” and “l”. Those words are eliminated for the frequency plots as they have no value for visualizations.
#
# News headlines are updated frequently and may change by the minute. No conclusions should be drawn about the overall bias of a particular news media organization based on the analysis of one scrape.

# %%
# Python program to scrape heading tags Jeff Becker 1/2023 V.1

import pickle
from IPython import display
import math
from pprint import pprint
import requests
import nltk
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import random
from wordcloud import WordCloud
import os
import spacy
from textblob import TextBlob
from pattern.en import sentiment
import urllib3 
import re
import datetime
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
import cv2


nlp = spacy.load('en_core_web_sm')
# %matplotlib inline
sns.set(style='darkgrid', context='notebook', font_scale=1.5, palette='Dark2')

headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"} 
#find what headers you are sending here: https://www.whatismybrowser.com/detect/what-http-headers-is-my-browser-sending

input_url = input("Enter the full URL to scrape: ") #user inputs URL to scrape
utc_datetime = datetime.datetime.utcnow() #utc data concatenated with sliced URL name, filename stored
date_string = utc_datetime.strftime("%Y-%m-%d-%H%M_UTC") 
filename = f'{input_url[12:len(date_string)]}_{date_string}'


cleanData = []
tag_words = []
regex = re.compile('[^a-zA-Z]')

def scrape(url_link):
    # create a list by type of heading tags
    # the user will have to determine what "h" tags are valid for given URL
    heading_tags = ["h1","h2","h3","h4"] 
    request = requests.get(url_link, headers = headers)
    Soup = BeautifulSoup(request.text, 'lxml') #create soup obejct

    if request.status_code == 200: #error handling for URL request
        print('Request successful.')
    elif request.status_code == 404:
        print('Error 404: Not Found.')
        
    for tags in Soup.find_all(heading_tags):
        tag_words.append(tags.text.strip())
        
    return tag_words
    
    
def post_process(scraped_list):   
    for i in scraped_list:  #slice based on data you want to include. Some junk data can be removed
        if len(i) > 16:    #Fliter a composite length of strings based on targeted threshold
            cleanData.append(regex.sub(' ', i)) #remove digits and punctuation

    deDup = list(set(cleanData))#convert to set then back to list to eliminate duplicate headline strings

    with open(filename, "wb") as fp: #Pickling data as list with UTC time stamp
        pickle.dump(deDup, fp)

    # with open(filename,'w') as a: # uncomment if you want to save a text file for manual review
    #     a.write('\n'.join(cleanData))

scraped_content = scrape(input_url) #scrape input URL
post_process(scraped_content) #process scraped tag data

# %% [markdown]
# <h4> The variable name "filename" is the stored value of the file. We can either work with that data or load previously scraped data at this point, i.e "foxnews_2023-01-07-2241_UTC". Be aware that pickled files will not display in Jupyter (UTF-8 error). To manually review the text, you have to uncomment the above text file code.<br><br> Once loaded, we slice and print the first five headlines to see if the content is as expected. </h4>

# %%
with open(filename, "rb") as fp: #Either load stored variable value for "filename" or saved pickled file "example_1_0_23"
    saved_text = pickle.load(fp)

saved_text[0:5] #confirm your expected text is correct
# Out:
# ['Oregon women s basketball leading scorer Grace VanSlooten hurts right foot in loss to Arizona',
#  'Winterhawks rolled by East leaders Winnipeg     ',
#  'Your Regional News Pages',
#  'Portland Japanese Garden brings in the New Year with tea ceremony and dance',
#  'Seattle Seahawks beat Rams       in overtime  then earn spot in NFL playoffs after Lions beat Packers']

# %% [markdown]
# <h4> Once we have the right text, we can check the polarity of the scraped headlines.
# <br><br>
# Sentence-level polarity detection is to decide whether a given sentence expresses either an overall positive or negative opinion. The compund score is tehoverall sentiment of the headline. The scale is -1 to 1, with -1 being the most negative and 1 being the most positive.<br><br> Some ot the code below was adapted from
# <a href="https://www.learndatasci.com/tutorials/sentiment-analysis-reddit-headlines-pythons-nltk/"> Sentiment Analysis on Reddit News Headlines with Python’s Natural Language Toolkit (NLTK)</a>
#
# Some changes made for this program.
#
# </h4>

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA 

sia = SIA() 
score_data = []

for line in saved_text:
    score = sia.polarity_scores(line)
    score['Headline'] = line
    score_data.append(score)

pprint(score_data, width=100) #pretty print sentiment scores
# Out:
# [{'Headline': 'Oregon women s basketball leading scorer Grace VanSlooten hurts right foot in loss '
#               'to Arizona',
#   'compound': -0.3818,
#   'neg': 0.281,
#   'neu': 0.573,
#   'pos': 0.146},
#  {'Headline': 'Winterhawks rolled by East leaders Winnipeg     ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Your Regional News Pages', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Portland Japanese Garden brings in the New Year with tea ceremony and dance',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Seattle Seahawks beat Rams       in overtime  then earn spot in NFL playoffs after '
#               'Lions beat Packers',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Buffalo Bills win for Damar Hamlin and eliminate New England Patriots from playoffs',
#   'compound': 0.5859,
#   'neg': 0.0,
#   'neu': 0.759,
#   'pos': 0.241},
#  {'Headline': 'CES products range from flashy to creepy to cool     highlights',
#   'compound': 0.3182,
#   'neg': 0.0,
#   'neu': 0.796,
#   'pos': 0.204},
#  {'Headline': 'Workforce participation remains depressed  especially in rural Oregon',
#   'compound': -0.5106,
#   'neg': 0.32,
#   'neu': 0.68,
#   'pos': 0.0},
#  {'Headline': 'Brock Purdy  San Francisco   ers roll Arizona Cardinals for   th consecutive win',
#   'compound': 0.5859,
#   'neg': 0.0,
#   'neu': 0.743,
#   'pos': 0.257},
#  {'Headline': 'Hidden glass float schedule released for      in Lincoln City',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Teaching children to read  Which districts use phonics based programs',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Ask Extension  I found a praying mantis egg case  Should I move it ',
#   'compound': 0.3612,
#   'neg': 0.0,
#   'neu': 0.783,
#   'pos': 0.217},
#  {'Headline': 'Latest Twitter cuts involve eliminating even more staff in content moderation',
#   'compound': -0.296,
#   'neg': 0.18,
#   'neu': 0.82,
#   'pos': 0.0},
#  {'Headline': 'Romance novelist who faked suicide reemerges online',
#   'compound': -0.2263,
#   'neg': 0.344,
#   'neu': 0.382,
#   'pos': 0.275},
#  {'Headline': 'Nude photo and sex texts sent to student lead to Vancouver teacher s arrest  police '
#               'say',
#   'compound': -0.34,
#   'neg': 0.146,
#   'neu': 0.854,
#   'pos': 0.0},
#  {'Headline': 'NFL playoffs  Busy Week    slate will decide playoff field',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'See the most expensive home for sale in each of Oregon s    counties',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Oregon women s basketball guard Ahlise Hurst cleared to return from left leg injury',
#   'compound': -0.34,
#   'neg': 0.184,
#   'neu': 0.724,
#   'pos': 0.092},
#  {'Headline': 'Circles in the Sand schedule released for      on southern Oregon coast',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'What TV channel is Commanders vs Cowboys today  Free live stream  prediction  odds  '
#               'time  how to watch Washington vs Dallas online           ',
#   'compound': 0.5106,
#   'neg': 0.0,
#   'neu': 0.858,
#   'pos': 0.142},
#  {'Headline': 'No  Hooters is not closing because of  millennials ',
#   'compound': -0.296,
#   'neg': 0.239,
#   'neu': 0.761,
#   'pos': 0.0},
#  {'Headline': 'Green Bay Packers vs Detroit Lions free live stream  score  odds  time  TV channel  '
#               'how to watch Sunday Night Football online           ',
#   'compound': 0.5106,
#   'neg': 0.0,
#   'neu': 0.858,
#   'pos': 0.142},
#  {'Headline': '  men arrested after running from Portland police',
#   'compound': -0.4767,
#   'neg': 0.341,
#   'neu': 0.659,
#   'pos': 0.0},
#  {'Headline': 'New fast spreading COVID    variant with creepy nickname  What we know',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Liz Weston  I want to leave my home to a friend when I die  What s the best way ',
#   'compound': 0.5574,
#   'neg': 0.214,
#   'neu': 0.42,
#   'pos': 0.366},
#  {'Headline': 'What TV channel is North Dakota State vs South Dakota State football on today  Live '
#               'stream  odds',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Betty Jean Lee  who led the family business that introduced Chinese takeout to '
#               'Portland  dies at   ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Already a Subscriber', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Wrestling  Vale s Ava Collins stuns nationally ranked opponent in Idaho s Rollie '
#               'Lane Invitational',
#   'compound': 0.0258,
#   'neg': 0.0,
#   'neu': 0.916,
#   'pos': 0.084},
#  {'Headline': 'Georgia Bulldogs look to launch dynasty against TCU in College Football Playoff '
#               'championship game',
#   'compound': 0.4404,
#   'neg': 0.0,
#   'neu': 0.818,
#   'pos': 0.182},
#  {'Headline': 'NFL playoffs  Dolphins  Jaguars back  Patriots head home',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Russell Wilson  Denver Broncos beat Justin Herbert  playoff bound Chargers      ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'After chaotic vote for speaker  Oregon Republican Lori Chavez DeRemer happy to be '
#               'sworn in',
#   'compound': 0.128,
#   'neg': 0.161,
#   'neu': 0.653,
#   'pos': 0.186},
#  {'Headline': 'Silverton house fire kills    cats',
#   'compound': -0.7096,
#   'neg': 0.663,
#   'neu': 0.337,
#   'pos': 0.0},
#  {'Headline': 'Preservationists say windows at former Portland Korean Church are worth saving  Are '
#               'they Povey Brothers glass ',
#   'compound': 0.2263,
#   'neg': 0.0,
#   'neu': 0.888,
#   'pos': 0.112},
#  {'Headline': 'Dear Annie  Mom considers cutting off allowance of    year old bully son',
#   'compound': -0.2732,
#   'neg': 0.288,
#   'neu': 0.552,
#   'pos': 0.16},
#  {'Headline': 'Trail Blazers lose         at Toronto Raptors  fall below      for  st time this '
#               'season  At the buzzer',
#   'compound': -0.4019,
#   'neg': 0.153,
#   'neu': 0.847,
#   'pos': 0.0},
#  {'Headline': 'SAIF says data breach may have compromised Social Security numbers  medical '
#               'information',
#   'compound': 0.34,
#   'neg': 0.0,
#   'neu': 0.821,
#   'pos': 0.179},
#  {'Headline': 'Northwest Travel Guide          places to thrill you and chill you out',
#   'compound': 0.3612,
#   'neg': 0.0,
#   'neu': 0.8,
#   'pos': 0.2},
#  {'Headline': 'Never opened      million plus biofuels refinery facing foreclosure in southern '
#               'Oregon',
#   'compound': -0.128,
#   'neg': 0.13,
#   'neu': 0.87,
#   'pos': 0.0},
#  {'Headline': 'Too many Oregon children can t read  Should districts be forced to drop discredited '
#               'curriculum ',
#   'compound': -0.7906,
#   'neg': 0.421,
#   'neu': 0.579,
#   'pos': 0.0},
#  {'Headline': 'Tacoma guaranteed income program shows how much it can help',
#   'compound': 0.4019,
#   'neg': 0.0,
#   'neu': 0.769,
#   'pos': 0.231},
#  {'Headline': 'Oregon Ducks defensive lineman Brandon Dorlus returning in     ',
#   'compound': 0.0258,
#   'neg': 0.0,
#   'neu': 0.864,
#   'pos': 0.136},
#  {'Headline': 'Portland pedestrian killed on SE Division identified  second fatal crash of     ',
#   'compound': -0.8934,
#   'neg': 0.572,
#   'neu': 0.428,
#   'pos': 0.0},
#  {'Headline': 'READ MORE TOP NEWS ', 'compound': 0.2716, 'neg': 0.0, 'neu': 0.589, 'pos': 0.411},
#  {'Headline': 'More on OregonLive com', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Footer Navigation', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Boy     intentionally shot teacher at school  police say',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Oregon State  Raegan Beers too much as Beavers whip Arizona State       in women s '
#               'basketball',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Portland s Sunday showers turn to rain Monday  highs in the low   s',
#   'compound': -0.2732,
#   'neg': 0.174,
#   'neu': 0.826,
#   'pos': 0.0},
#  {'Headline': 'Storms continue to batter California in  relentless parade ',
#   'compound': 0.0516,
#   'neg': 0.0,
#   'neu': 0.854,
#   'pos': 0.146},
#  {'Headline': 'A newly discovered comet will be visible in the night sky this month',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Let s go eat absurdly inexpensive Cantonese food at Fortune BBQ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'School resumes Monday at Portland s Franklin High  site of parking lot shooting',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Oregon women s basketball commits    turnovers in loss at Arizona',
#   'compound': -0.296,
#   'neg': 0.221,
#   'neu': 0.673,
#   'pos': 0.106},
#  {'Headline': 'Beignet bummer  NOLA Doughnuts closes all Portland area locations',
#   'compound': -0.3818,
#   'neg': 0.245,
#   'neu': 0.755,
#   'pos': 0.0},
#  {'Headline': 'Supporters of former president storm Brazil s top government offices',
#   'compound': 0.5719,
#   'neg': 0.0,
#   'neu': 0.598,
#   'pos': 0.402},
#  {'Headline': 'Kate Brown  Unpopular governor leaves legacy of COVID safety  clemency  climate '
#               'regulation  but also disappointment',
#   'compound': -0.5499,
#   'neg': 0.23,
#   'neu': 0.672,
#   'pos': 0.098},
#  {'Headline': 'Arizona State linebacker Connor Soelle commits to transfer to Oregon Ducks',
#   'compound': 0.0258,
#   'neg': 0.0,
#   'neu': 0.901,
#   'pos': 0.099},
#  {'Headline': 'Basketball game at Franklin High School postponed after parking lot shooting '
#               'injures  ',
#   'compound': -0.2023,
#   'neg': 0.141,
#   'neu': 0.859,
#   'pos': 0.0},
#  {'Headline': 'Cincinnati Bengals beat Baltimore Ravens to avoid coin flip  set up home rematch',
#   'compound': -0.296,
#   'neg': 0.155,
#   'neu': 0.845,
#   'pos': 0.0},
#  {'Headline': 'Clear Creek Distillery founder dies  a final toast to Steve McCarthy  Steve Duin '
#               'column',
#   'compound': 0.3818,
#   'neg': 0.0,
#   'neu': 0.822,
#   'pos': 0.178},
#  {'Headline': 'Former Multnomah County Animal Services staff  volunteers say deep rooted problems '
#               'have led to years of animal neglect',
#   'compound': -0.6908,
#   'neg': 0.263,
#   'neu': 0.737,
#   'pos': 0.0},
#  {'Headline': '   year old caught driving stolen car through North Portland  police say',
#   'compound': -0.4939,
#   'neg': 0.242,
#   'neu': 0.758,
#   'pos': 0.0},
#  {'Headline': 'Chicago Bears land No    pick in NFL Draft after Houston Texans rally for win at '
#               'Indianapolis',
#   'compound': 0.3818,
#   'neg': 0.11,
#   'neu': 0.7,
#   'pos': 0.19},
#  {'Headline': 'Want to get rid of moss in your landscape  Not so fast  Ask Extension',
#   'compound': 0.0772,
#   'neg': 0.0,
#   'neu': 0.909,
#   'pos': 0.091},
#  {'Headline': 'Tesla crash off cliff shatters idyllic image of California doctor s family',
#   'compound': -0.4019,
#   'neg': 0.213,
#   'neu': 0.787,
#   'pos': 0.0},
#  {'Headline': 'Bill Monroe  Some of the Oregon State Police Fish and Wildlife Division s '
#               'encounters are stranger than fiction',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'This Portland pizzeria is No    on a list of the world s best pizzas',
#   'compound': 0.4588,
#   'neg': 0.134,
#   'neu': 0.61,
#   'pos': 0.256},
#  {'Headline': 'Rewinding Oregon women s basketball s       loss to Arizona',
#   'compound': -0.3182,
#   'neg': 0.277,
#   'neu': 0.723,
#   'pos': 0.0},
#  {'Headline': 'Eugene based author Cai Emmons  who wrote about living with a fatal ALS diagnosis  '
#               'dies at   ',
#   'compound': -0.5423,
#   'neg': 0.2,
#   'neu': 0.8,
#   'pos': 0.0},
#  {'Headline': 'Oregonians to receive     million in unclaimed money',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'N Faly Dante  Will Richardson lead Oregon men s basketball to upset at Utah  keep '
#               'Ducks  postseason hopes alive',
#   'compound': 0.4215,
#   'neg': 0.118,
#   'neu': 0.636,
#   'pos': 0.245},
#  {'Headline': 'Singer Woody Guthrie s rented flat in Lents is for sale  his Portland legacy '
#               'remains',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Dear Doctor  Are all the medications I take suppressing my dream sleep ',
#   'compound': 0.5574,
#   'neg': 0.0,
#   'neu': 0.662,
#   'pos': 0.338},
#  {'Headline': 'Oregon Ducks coach Dan Lanning gets portrait tattoo of wife Sauphia with several '
#               'meaningful symbols',
#   'compound': 0.3182,
#   'neg': 0.0,
#   'neu': 0.859,
#   'pos': 0.141}]

# %% [markdown]
# <h4>Now we can create Pandas data frame to visualize some of the headlines and scores. Compound is overall sentiment. </h4>

# %%
df = pd.DataFrame.from_records(score_data)
df
# Out:
#       neg    neu    pos  compound  \
# 0   0.281  0.573  0.146   -0.3818
# 1   0.000  1.000  0.000    0.0000
# 2   0.000  1.000  0.000    0.0000
# 3   0.000  1.000  0.000    0.0000
# 4   0.000  1.000  0.000    0.0000
# ..    ...    ...    ...       ...
# 71  0.000  1.000  0.000    0.0000
# 72  0.118  0.636  0.245    0.4215
# 73  0.000  1.000  0.000    0.0000
# 74  0.000  0.662  0.338    0.5574
# 75  0.000  0.859  0.141    0.3182
#
#                                              Headline
# 0   Oregon women s basketball leading scorer Grace...
# 1    Winterhawks rolled by East leaders Winnipeg
# 2                            Your Regional News Pages
# 3   Portland Japanese Garden brings in the New Yea...
# 4   Seattle Seahawks beat Rams       in overtime  ...
# ..                                                ...
# 71  Oregonians to receive     million in unclaimed...
# 72  N Faly Dante  Will Richardson lead Oregon men ...
# 73  Singer Woody Guthrie s rented flat in Lents is...
# 74  Dear Doctor  Are all the medications I take su...
# 75  Oregon Ducks coach Dan Lanning gets portrait t...
#
# [76 rows x 5 columns]

# %% [markdown]
# <h4>Now assign a positive or negative score based on the threshold for the compound score. It's the user's discretion on how to assign a score. In this case we'll use +/- .025 </h4>

# %%
df['label'] = 0
df.loc[df['compound'] > 0.25, 'label'] = 1
df.loc[df['compound'] < -0.25, 'label'] = -1
df
# Out:
#       neg    neu    pos  compound  \
# 0   0.281  0.573  0.146   -0.3818
# 1   0.000  1.000  0.000    0.0000
# 2   0.000  1.000  0.000    0.0000
# 3   0.000  1.000  0.000    0.0000
# 4   0.000  1.000  0.000    0.0000
# ..    ...    ...    ...       ...
# 71  0.000  1.000  0.000    0.0000
# 72  0.118  0.636  0.245    0.4215
# 73  0.000  1.000  0.000    0.0000
# 74  0.000  0.662  0.338    0.5574
# 75  0.000  0.859  0.141    0.3182
#
#                                              Headline  label
# 0   Oregon women s basketball leading scorer Grace...     -1
# 1    Winterhawks rolled by East leaders Winnipeg           0
# 2                            Your Regional News Pages      0
# 3   Portland Japanese Garden brings in the New Yea...      0
# 4   Seattle Seahawks beat Rams       in overtime  ...      0
# ..                                                ...    ...
# 71  Oregonians to receive     million in unclaimed...      0
# 72  N Faly Dante  Will Richardson lead Oregon men ...      1
# 73  Singer Woody Guthrie s rented flat in Lents is...      0
# 74  Dear Doctor  Are all the medications I take su...      1
# 75  Oregon Ducks coach Dan Lanning gets portrait t...      1
#
# [76 rows x 6 columns]

# %%
df2 = df[['Headline', 'label']] #save CSV of data with labels for future processing
df2.to_csv(filename +'.csv', mode='a', encoding='utf-8', index=False)

# %%
print("Positive headlines:\n") #print a sample of categorized headlines
pprint(list(df[df['label'] == 1].Headline)[:10], width=200)

print("\nNegative headlines:\n")
pprint(list(df[df['label'] == -1].Headline)[:10], width=200)
# Out:
# Positive headlines:
#
# ['Buffalo Bills win for Damar Hamlin and eliminate New England Patriots from playoffs',
#  'CES products range from flashy to creepy to cool     highlights',
#  'Brock Purdy  San Francisco   ers roll Arizona Cardinals for   th consecutive win',
#  'Ask Extension  I found a praying mantis egg case  Should I move it ',
#  'What TV channel is Commanders vs Cowboys today  Free live stream  prediction  odds  time  how to watch Washington vs Dallas online           ',
#  'Green Bay Packers vs Detroit Lions free live stream  score  odds  time  TV channel  how to watch Sunday Night Football online           ',
#  'Liz Weston  I want to leave my home to a friend when I die  What s the best way ',
#  'Georgia Bulldogs look to launch dynasty against TCU in College Football Playoff championship game',
#  'SAIF says data breach may have compromised Social Security numbers  medical information',
#  'Northwest Travel Guide          places to thrill you and chill you out']
#
# Negative headlines:
#
# ['Oregon women s basketball leading scorer Grace VanSlooten hurts right foot in loss to Arizona',
#  'Workforce participation remains depressed  especially in rural Oregon',
#  'Latest Twitter cuts involve eliminating even more staff in content moderation',
#  'Nude photo and sex texts sent to student lead to Vancouver teacher s arrest  police say',
#  'Oregon women s basketball guard Ahlise Hurst cleared to return from left leg injury',
#  'No  Hooters is not closing because of  millennials ',
#  '  men arrested after running from Portland police',
#  'Silverton house fire kills    cats',
#  'Dear Annie  Mom considers cutting off allowance of    year old bully son',
#  'Trail Blazers lose         at Toronto Raptors  fall below      for  st time this season  At the buzzer']

# %%
print(df.label.value_counts())

print(df.label.value_counts(normalize=True) * 100) #normalize data
# Out:
#  0    35
# -1    22
#  1    19
# Name: label, dtype: int64
#  0    46.052632
# -1    28.947368
#  1    25.000000
# Name: label, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 8)) #create a bar graph of sentiment distributions

counts = df.label.value_counts(normalize=True) * 100

sns.barplot(x=counts.index, y=counts, ax=ax)

ax.set_xticklabels(['Negative', 'Neutral', 'Positive'])
ax.set_ylabel(filename[0:18] + " Percentage")

# plt.savefig(filename + ".png") #uncomment to safe plot image
plt.show()

# %%
textblob_sentiment=[]
for s in saved_text:
    txt= TextBlob(s)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([s,a,b])

# %%
df_textblob = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_textblob
# Out:
#                                              Sentence  Polarity  Subjectivity
# 0   Oregon women s basketball leading scorer Grace...  0.285714      0.535714
# 1    Winterhawks rolled by East leaders Winnipeg       0.000000      0.000000
# 2                            Your Regional News Pages  0.000000      0.000000
# 3   Portland Japanese Garden brings in the New Yea...  0.068182      0.227273
# 4   Seattle Seahawks beat Rams       in overtime  ...  0.000000      0.000000
# ..                                                ...       ...           ...
# 71  Oregonians to receive     million in unclaimed...  0.000000      0.000000
# 72  N Faly Dante  Will Richardson lead Oregon men ...  0.100000      0.400000
# 73  Singer Woody Guthrie s rented flat in Lents is... -0.025000      0.125000
# 74  Dear Doctor  Are all the medications I take su...  0.000000      0.000000
# 75  Oregon Ducks coach Dan Lanning gets portrait t...  0.250000      0.250000
#
# [76 rows x 3 columns]

# %%
df_textblob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      76 non-null     object
#  1   Polarity      76 non-null     float64
#  2   Subjectivity  76 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.9+ KB

# %%
sns.displot(df_textblob["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Textblob)")
# Out:
# Text(0.5, 15.440000000000012, 'Sentence Polarity (Textblob)')

# %%
sns.displot(df_textblob["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Textblob)")
# Out:
# Text(0.5, 15.440000000000012, 'Sentence Subjectivity (Textblob)')

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer #tokenize and remove stop words from corpus
from nltk.corpus import stopwords

stop_words = stopwords.words('english')

def process_text(headlines):
    sent_tokens = []
    for headline in headlines:
        head_tokens = word_tokenize(headline)
        head_tokens = [t.lower() for t in head_tokens if t.lower() not in stop_words]
        sent_tokens.extend(head_tokens)
    return sent_tokens

# %%
pos_lines = list(df[df.label == 1].Headline)

pos_tokens = process_text(pos_lines)

longPosTokens = [i for i in pos_tokens if len(i)> 1]
pos_freq = nltk.FreqDist(longPosTokens)

# %%
freq_dist = nltk.FreqDist(pos_freq)
#Frequency Distribution Plot
plt.subplots(figsize=(16,10))

freq_dist.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
y_val = [x[1] for x in pos_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Positive Word Frequency Distribution")
plt.show()

# %%
y_final = []
for i, k, z, t in zip(y_val[0::4], y_val[1::4], y_val[2::4], y_val[3::4]):
    y_final.append(math.log(i + k + z + t))

x_val = [math.log(i + 1) for i in range(len(y_final))]

fig = plt.figure(figsize=(11,6))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Positive Word Frequency Distribution")
plt.plot(x_val, y_final)
plt.show()

# %%
neg_lines = list(df2[df2.label == -1].Headline)

neg_tokens = process_text(neg_lines)

longNegTokens = [i for i in neg_tokens if len(i)> 1]
neg_freq = nltk.FreqDist(longNegTokens)

# %%
freq_dist = nltk.FreqDist(neg_freq)
#Frequency Distribution Plot
plt.subplots(figsize=(11,6))
freq_dist.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
y_val = [x[1] for x in neg_freq.most_common()]

fig = plt.figure(figsize=(12,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Negative Word Frequency Distribution")
plt.show()

# %%
y_final = []
for i, k, z in zip(y_val[0::3], y_val[1::3], y_val[2::3]):
    if i + k + z == 0:
        break
    y_final.append(math.log(i + k + z))

x_val = [math.log(i+1) for i in range(len(y_final))]

fig = plt.figure(figsize=(12,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Negative Word Frequency Distribution")
plt.plot(x_val, y_final)
plt.show()

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer #tokenize and remove stop words from corpus
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

stop_tokens = []

def process_text(headlines):
    for line in headlines:
        toks = word_tokenize(line)
        toks = [t.lower() for t in toks if t.lower() not in stop_words]
        stop_tokens.extend(toks)
    
    return stop_tokens

process_text(saved_text)
# Out:
# ['best',
#  'stylish',
#  'gifts',
#  'men',
#  'holiday',
#  'list',
#  'fitness',
#  'deals',
#  'amazon',
#  'new',
#  'year',
#  'sale',
#  'get',
#  'blood',
#  'pumping',
#  'rebny',
#  'gala',
#  'return',
#  'seated',
#  'affair',
#  'prince',
#  'harry',
#  'villain',
#  'camilla',
#  'need',
#  'rehabilitate',
#  'image',
#  'dangerous',
#  'chick',
#  'fil',
#  'urges',
#  'customers',
#  'take',
#  'action',
#  'investigates',
#  'fraudulent',
#  'activity',
#  'mobile',
#  'app',
#  'accounts',
#  'old',
#  'nasa',
#  'satellite',
#  'falling',
#  'sky',
#  'weekend',
#  'shawn',
#  'mendes',
#  'ditches',
#  'signature',
#  'curls',
#  'new',
#  'shaved',
#  'letters',
#  'editor',
#  'jan',
#  'lip',
#  'service',
#  'larsa',
#  'pippen',
#  'marcus',
#  'jordan',
#  'pack',
#  'pda',
#  'miami',
#  'date',
#  'night',
#  'dolly',
#  'parton',
#  'joins',
#  'call',
#  'kat',
#  'pay',
#  'tribute',
#  'leslie',
#  'jordan',
#  'swearing',
#  'boebert',
#  'accused',
#  'cursing',
#  'marjorie',
#  'taylor',
#  'greene',
#  'house',
#  'speaker',
#  'vote',
#  'sealed',
#  'deal',
#  'selling',
#  'tampa',
#  'star',
#  'officially',
#  'engaged',
#  'chad',
#  'ochocinco',
#  'johnson',
#  'best',
#  'treadmills',
#  'upgrade',
#  'home',
#  'gym',
#  'ny',
#  'post',
#  'sports',
#  'columnist',
#  'mark',
#  'cannizzaro',
#  'talks',
#  'bills',
#  'vs',
#  'patriots',
#  'game',
#  'damar',
#  'hamlin',
#  'honored',
#  'snow',
#  'many',
#  'regions',
#  'dealing',
#  'warm',
#  'dry',
#  'winter',
#  'season',
#  'hits',
#  'midpoint',
#  'right',
#  'fingertips',
#  'jets',
#  'coach',
#  'apologizes',
#  'team',
#  'collapse',
#  'tale',
#  'two',
#  'fights',
#  'hamlin',
#  'shows',
#  'best',
#  'us',
#  'congress',
#  'much',
#  'abbott',
#  'says',
#  'biden',
#  'border',
#  'visit',
#  'little',
#  'late',
#  'hand',
#  'delivered',
#  'letter',
#  'secure',
#  'border',
#  'heroes',
#  'zeros',
#  'jets',
#  'loss',
#  'dolphins',
#  'coordinator',
#  'another',
#  'brutal',
#  'day',
#  'fumble',
#  'aaron',
#  'hernandez',
#  'fianc',
#  'e',
#  'accused',
#  'wasting',
#  'daughter',
#  'trust',
#  'fund',
#  'scholars',
#  'contest',
#  'high',
#  'school',
#  'students',
#  'new',
#  'york',
#  'area',
#  'open',
#  'enter',
#  'f',
#  'ked',
#  'emrata',
#  'curses',
#  'ellen',
#  'degeneres',
#  'taylor',
#  'swift',
#  'interview',
#  'resurfaces',
#  'got',
#  'chanel',
#  'goodie',
#  'bag',
#  'nyc',
#  'hospital',
#  'giving',
#  'birth',
#  'best',
#  'celestial',
#  'themed',
#  'luxury',
#  'gifts',
#  'women',
#  'celine',
#  'dion',
#  'fans',
#  'protest',
#  'rolling',
#  'stone',
#  'offices',
#  'snub',
#  'crime',
#  'cynical',
#  'el',
#  'paso',
#  'cleanup',
#  'biden',
#  'visit',
#  'perfectly',
#  'sums',
#  'pathetic',
#  'border',
#  'policy',
#  'sephora',
#  'announces',
#  'birthday',
#  'gift',
#  'offerings',
#  'already',
#  'celebrating',
#  'prince',
#  'harry',
#  'accuses',
#  'royal',
#  'family',
#  'going',
#  'bed',
#  'devil',
#  'help',
#  'image',
#  'new',
#  'interview',
#  'giants',
#  'week',
#  'report',
#  'card',
#  'reserves',
#  'hold',
#  'manhattan',
#  'leasing',
#  'data',
#  'shows',
#  'significant',
#  'dip',
#  'fourth',
#  'quarter',
#  'history',
#  'repeats',
#  'bolsonaro',
#  'supporters',
#  'storm',
#  'brazil',
#  'capital',
#  'city',
#  'jan',
#  'style',
#  'attack',
#  'heroes',
#  'zeros',
#  'giants',
#  'loss',
#  'eagles',
#  'special',
#  'teams',
#  'cash',
#  'famed',
#  'photographer',
#  'lists',
#  'stunning',
#  'nyc',
#  'co',
#  'op',
#  'twitter',
#  'employees',
#  'battling',
#  'misinformation',
#  'among',
#  'latest',
#  'layoffs',
#  'since',
#  'musk',
#  'takeover',
#  'fresh',
#  'bad',
#  'news',
#  'kids',
#  'makes',
#  'pot',
#  'legalization',
#  'look',
#  'even',
#  'worse',
#  'hamline',
#  'university',
#  'professor',
#  'fired',
#  'showing',
#  'images',
#  'muhammad',
#  'warned',
#  'students',
#  'syllabus',
#  'hear',
#  'jordan',
#  'peele',
#  'bought',
#  'corey',
#  'feldman',
#  'prosthetic',
#  'ear',
#  'stand',
#  'mets',
#  'remain',
#  'carlos',
#  'correa',
#  'likely',
#  'landing',
#  'spot',
#  'trending',
#  'sports',
#  'coned',
#  'bilked',
#  'mta',
#  'electric',
#  'bills',
#  'years',
#  'tune',
#  'least',
#  'ig',
#  'knicks',
#  'expecting',
#  'two',
#  'key',
#  'players',
#  'back',
#  'lineup',
#  'accuser',
#  'evelyn',
#  'yang',
#  'expects',
#  'fuller',
#  'extent',
#  'columbia',
#  'obgyn',
#  'sex',
#  'crimes',
#  'exposed',
#  'trial',
#  'two',
#  'shot',
#  'nyc',
#  'suspects',
#  'hit',
#  'pedestrian',
#  'car',
#  'fleeing',
#  'cops',
#  'nonprofit',
#  'completeplayground',
#  'settles',
#  'fidi',
#  'signs',
#  'year',
#  'lease',
#  'biden',
#  'failed',
#  'death',
#  'penalty',
#  'campaign',
#  'promise',
#  'paved',
#  'way',
#  'nyc',
#  'capital',
#  'murder',
#  'case',
#  'post',
#  'steve',
#  'cuozzo',
#  'recalls',
#  'years',
#  'job',
#  'bag',
#  'em',
#  'nyc',
#  'grocers',
#  'demand',
#  'clampdown',
#  'shoplifters',
#  'violent',
#  'heists',
#  'escalate',
#  'ex',
#  'virginia',
#  'tech',
#  'soccer',
#  'player',
#  'refused',
#  'blm',
#  'kneel',
#  'gets',
#  'k',
#  'settlement',
#  'pregnant',
#  'keke',
#  'palmer',
#  'says',
#  'wait',
#  'get',
#  'hands',
#  'baby',
#  'ny',
#  'covid',
#  'deaths',
#  'spiked',
#  'december',
#  'since',
#  'early',
#  'pandemic',
#  'best',
#  'everything',
#  'post',
#  'woman',
#  'eating',
#  'raw',
#  'salmon',
#  'disgusts',
#  'fellow',
#  'bus',
#  'riders',
#  'encouraging',
#  'reality',
#  'around',
#  'giants',
#  'entering',
#  'playoffs',
#  'idaho',
#  'murder',
#  'arrest',
#  'catfishing',
#  'cop',
#  'history',
#  'messaging',
#  'underage',
#  'girls',
#  'joy',
#  'behar',
#  'weighs',
#  'prince',
#  'harry',
#  'drama',
#  'view',
#  'royal',
#  'family',
#  'treats',
#  'meghan',
#  'markle',
#  'like',
#  'yoko',
#  'ono',
#  'robert',
#  'saleh',
#  'assesses',
#  'jets',
#  'season',
#  'loss',
#  'dolphins',
#  'tex',
#  'mess',
#  'biden',
#  'spends',
#  'three',
#  'hours',
#  'el',
#  'paso',
#  'first',
#  'border',
#  'visit',
#  'president',
#  'hochul',
#  'personally',
#  'putting',
#  'screws',
#  'ny',
#  'dems',
#  'tries',
#  'salvage',
#  'top',
#  'judge',
#  'pick',
#  'migrants',
#  'plead',
#  'el',
#  'paso',
#  'cops',
#  'rounded',
#  'ahead',
#  'biden',
#  'visit',
#  'video',
#  'tiktoker',
#  'claims',
#  'found',
#  'titanic',
#  'easter',
#  'egg',
#  'disney',
#  'frozen',
#  'highest',
#  'ice',
#  'skating',
#  'rink',
#  'nyc',
#  'open',
#  'hudson',
#  'yards',
#  'month',
#  'self',
#  'care',
#  'essentials',
#  'new',
#  'year',
#  'shop',
#  'week',
#  'critical',
#  'moment',
#  'biden',
#  'act',
#  'china',
#  'threat',
#  'gunman',
#  'threatens',
#  'mta',
#  'bus',
#  'driver',
#  'demanded',
#  'pay',
#  'andrew',
#  'tate',
#  'possibly',
#  'hospitalized',
#  'romania',
#  'get',
#  'caught',
#  'lying',
#  'resume',
#  'get',
#  'fired',
#  'larsa',
#  'pippen',
#  'marcus',
#  'jordan',
#  'pack',
#  'pda',
#  'miami',
#  'date',
#  'night',
#  'police',
#  'plane',
#  'circled',
#  'alleged',
#  'idaho',
#  'killer',
#  'pa',
#  'home',
#  'hours',
#  'records',
#  'best',
#  'new',
#  'skin',
#  'care',
#  'beauty',
#  'tools',
#  'use',
#  'home',
#  'prince',
#  'harry',
#  'villain',
#  'camilla',
#  'body',
#  'stepmom',
#  'left',
#  'street',
#  'rehab',
#  'image',
#  'plain',
#  'sight',
#  'online',
#  'sleuths',
#  'claim',
#  'idaho',
#  'murder',
#  'suspect',
#  'attended',
#  'vigil',
#  'held',
#  'four',
#  'victims',
#  'orthodontist',
#  'charged',
#  'allegedly',
#  'soliciting',
#  'minors',
#  'nude',
#  'photos',
#  'possessing',
#  'child',
#  'porn',
#  'teachers',
#  'remember',
#  'year',
#  'old',
#  'girl',
#  'mauled',
#  'death',
#  'pitbull',
#  'damar',
#  'spiritual',
#  'bills',
#  'honor',
#  'injured',
#  'hamlin',
#  'emotional',
#  'win',
#  'patriots',
#  'nets',
#  'edge',
#  'win',
#  'potential',
#  'kevin',
#  'durant',
#  'injury',
#  'nightmare',
#  'looms',
#  'gan',
#  'slashed',
#  'way',
#  'box',
#  'office',
#  'debut',
#  'biden',
#  'box',
#  'check',
#  'border',
#  'bop',
#  'democracy',
#  'worthy',
#  'investment',
#  'commentary',
#  'common',
#  'sense',
#  'nonsense',
#  'white',
#  'sox',
#  'star',
#  'closer',
#  'start',
#  'cancer',
#  'treatment',
#  'lsu',
#  'gymnast',
#  'asks',
#  'fans',
#  'respectful',
#  'wild',
#  'scene',
#  'gone',
#  'girl',
#  'husband',
#  'missing',
#  'massachusetts',
#  'mom',
#  'arrested',
#  'misleading',
#  'cops',
#  'virginia',
#  'mayor',
#  'says',
#  'year',
#  'old',
#  'shooting',
#  'teacher',
#  'red',
#  'flag',
#  'country',
#  'miami',
#  'best',
#  'new',
#  'hotels',
#  'prince',
#  'harry',
#  'minutes',
#  'interview',
#  'bombshells',
#  'drugs',
#  'racism',
#  'violence',
#  'kevin',
#  'durant',
#  'forced',
#  'nets',
#  'game',
#  'apparent',
#  'knee',
#  'injury',
#  'never',
#  'miss',
#  'story',
#  'smart',
#  'apps',
#  'make',
#  'work',
#  'life',
#  'easier',
#  'feline',
#  'frisky',
#  'curtis',
#  'sliwa',
#  'tries',
#  'convince',
#  'mayor',
#  'brooklyn',
#  'neighbors',
#  'use',
#  'feral',
#  'cats',
#  'combat',
#  'rats',
#  'amenity',
#  'packed',
#  'las',
#  'vegas',
#  'mansion',
#  'also',
#  'gun',
#  'range',
#  'nyc',
#  'hospitals',
#  'dodge',
#  'nurse',
#  'strike',
#  'others',
#  'prep',
#  'really',
#  'bad',
#  'situation',
#  'eight',
#  'enough',
#  'star',
#  'adam',
#  'rich',
#  'dead',
#  'california',
#  'architect',
#  'scott',
#  'johnson',
#  'buys',
#  'grand',
#  'nyc',
#  'pad',
#  'prince',
#  'harry',
#  'admits',
#  'still',
#  'questions',
#  'princess',
#  'diana',
#  'unexplained',
#  'death',
#  'flip',
#  'back',
#  'cover',
#  'damar',
#  'hamlin',
#  'win',
#  'shirts',
#  'raising',
#  'money',
#  'first',
#  'responders',
#  'hospital',
#  'prince',
#  'harry',
#  'william',
#  'snapped',
#  'physical',
#  'fight',
#  'caused',
#  'nasty',
#  'cuts',
#  'dinner',
#  'top',
#  'two',
#  'adams',
#  'nyc',
#  'mayor',
#  'sits',
#  'cindy',
#  'eight',
#  'enough',
#  'star',
#  'adam',
#  'rich',
#  'dead',
#  'gave',
#  'manicure',
#  'ended',
#  'emergency',
#  'room',
#  'smells',
#  'like',
#  'teen',
#  'spirit',
#  'lsu',
#  'gymnast',
#  'asks',
#  'fans',
#  'respectful',
#  'wild',
#  'scene',
#  'front',
#  'cover',
#  'back',
#  'cover',
#  'full',
#  'squeeze',
#  'best',
#  'juice',
#  'cleanses',
#  'nyc',
#  'grocers',
#  'simple',
#  'fix',
#  'serial',
#  'shoplifters',
#  'lawmakers',
#  'listen',
#  'mayor',
#  'adams',
#  'needs',
#  'follow',
#  'road',
#  'safety',
#  'success',
#  'unlock',
#  'apple',
#  'device',
#  'owner',
#  'dies',
#  'seattle',
#  'public',
#  'schools',
#  'sue',
#  'big',
#  'tech',
#  'creating',
#  'youth',
#  'mental',
#  'health',
#  'crisis',
#  'miami',
#  'hottest',
#  'restaurants',
#  'amazon',
#  'workers',
#  'joke',
#  'potential',
#  'jeff',
#  'bezos',
#  'comeback',
#  'return',
#  'king',
#  'always',
#  'wanted',
#  'mint',
#  'nfts',
#  'masterclass',
#  'artists',
#  'entrepreneurs',
#  'prince',
#  'harry',
#  'admits',
#  'drinking',
#  'heavily',
#  'using',
#  'hard',
#  'drugs',
#  'minutes',
#  'power',
#  'deal',
#  'magstack',
#  'charging',
#  'station',
#  'city',
#  'council',
#  'embrace',
#  'sanity',
#  'cost',
#  'saving',
#  'retiree',
#  'health',
#  'plan',
#  'clean',
#  'shirts',
#  'veggies',
#  'jewelry',
#  'sonic',
#  'soak',
#  'ultrasonic',
#  'cleaner',
#  'alexa',
#  'cls',
#  'fill',
#  'fff',
#  'lindy',
#  'ruff',
#  'damon',
#  'severson',
#  'jesper',
#  'bratt',
#  'jack',
#  'hughes',
#  'talk',
#  'devils',
#  'win',
#  'rangers',
#  'cent',
#  'eminem',
#  'say',
#  'developing',
#  'mile',
#  'tv',
#  'series',
#  'awestruck',
#  'jane',
#  'fonda',
#  'weak',
#  'knees',
#  'met',
#  'tom',
#  'brady',
#  'jets',
#  'players',
#  'workout',
#  'damar',
#  'hamlin',
#  'jerseys',
#  'prior',
#  'dolphins',
#  'game',
#  'congress',
#  'dithered',
#  'us',
#  'withered',
#  'spend',
#  'less',
#  'bottle',
#  'wine',
#  'bottle',
#  'bundle',
#  'wine',
#  'insiders',
#  'erin',
#  'andrews',
#  'goes',
#  'hole',
#  'reporters',
#  'treat',
#  'athletes',
#  'like',
#  'animals',
#  'cops',
#  'concerned',
#  'missing',
#  'pa',
#  'mom',
#  'failed',
#  'pick',
#  'son',
#  'bus',
#  'stop',
#  'trio',
#  'swipes',
#  'k',
#  'distracting',
#  'brink',
#  'truck',
#  ...]

# %%
from nltk.stem import WordNetLemmatizer #Lemmatize the words with stopwords removed
ls = WordNetLemmatizer()
lem_tokens = []
for t in stop_tokens:
    lemma = ls.lemmatize(t) 
    if len(lemma) > 1: #remove random single charcters from lemmatizing
        lem_tokens.append(lemma)

# %%
#lem_tokens #uncomment to see ouput of stemmed tokens

# %%
from collections import Counter     #get the top 30 words to make a data frame
my_counter = Counter(lem_tokens)
# my_counter.most_common(25)

word_freq = pd.DataFrame(my_counter.most_common(30),
                             columns=['Words', 'count'])
word_freq
# Out:
#         Words  count
# 0         nyc     14
# 1      prince     10
# 2       harry     10
# 3        best      8
# 4         new      8
# 5       biden      8
# 6        year      7
# 7      hamlin      7
# 8       death      7
# 9        star      6
# 10      damar      6
# 11        say      6
# 12        get      5
# 13        jet      5
# 14        two      5
# 15     border      5
# 16     school      5
# 17        cop      5
# 18        mom      5
# 19      image      4
# 20     jordan      4
# 21      miami      4
# 22    accused      4
# 23       bill      4
# 24     season      4
# 25      visit      4
# 26       loss      4
# 27  interview      4
# 28        fan      4
# 29      giant      4

# %%
fig, ax = plt.subplots(figsize=(14, 14))  #make a bar graph ot the top 30 words from the data frame

# Plot horizontal bar graph
word_freq.sort_values(by='count').plot.barh(
                                            x='Words',
                                            y='count',
                                            ax=ax,
                                            color="blue")
ax.set_title("Most Common Words Found")
plt.show()

# %%
guardian={-1:40.983607, 0:40.983607, 1:18.032787}
NYTimes = {-1:19.444444, 0:50.000000,  1:30.555556}
BBC = { -1:28.1690140, 0:57.746479,1:14.084507}
FoxNews = {-1:29.5180720, 0:40.361446, 1:30.120482}
NPR = { -1:31.25, 0:43.75, 1:25.00}
KPTV = {-1:63.333333, 0:23.333333, 1:13.333333}
DailyMail = {-1:56.730769, 0:19.230769, 1:24.038462}
NYPost = { -1:34.355828, 0:44.785276, 1:20.858896}
Oregonlive = {-1:28.947368, 0:46.052632, 1:25.000000}

# %%
from matplotlib import pyplot
file_names = ['kptv.co_2023-01-09-0433_UTC.png',
              'dailyma_2023-01-09-0435_UTC.png',
              'st.com_2023-01-09-0441_UTC.png',
              'oregonl_2023-01-09-0446_UTC.png',
              'theguar_2023-01-09-0449_UTC.png',
              'nytimes_2023-01-09-0453_UTC.png',
              'bbc.com_2023-01-09-0457_UTC.png',
              'foxnews_2023-01-09-0501_UTC.png',
              'npr.org_2023-01-09-0504_UTC.png']
# create subplots instances
fig, axes = pyplot.subplots(4,4, figsize=(25,20))

for name, ax in zip(file_names, axes.ravel()):
    image = cv2.imread(name)

    # plot image into the subplot
    ax.imshow(image[:,:,::-1])

# %%
import cv2

# create figure
fig = plt.figure(figsize=(30,30))
 
# reading images
Image1 = cv2.imread('kptv.co_2023-01-09-0433_UTC.png')
             
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image1[:,:,::-1])
plt.axis('off')
plt.title("KPTV")
# Out:
# Text(0.5, 1.0, 'KPTV')

# %%
Image2 = cv2.imread('dailyma_2023-01-09-0435_UTC.png')

# create figure
fig = plt.figure(figsize=(30,30))
                    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image2[:,:,::-1])
plt.axis('off')
plt.title("Daily Mail")
# Out:
# Text(0.5, 1.0, 'Daily Mail')

# %%
Image3 = cv2.imread('st.com_2023-01-09-0441_UTC.png')

# create figure
fig = plt.figure(figsize=(30,30))
                    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image3[:,:,::-1])
plt.axis('off')
plt.title("NY Post")
# Out:
# Text(0.5, 1.0, 'NY Post')

# %%
Image4 = cv2.imread('oregonl_2023-01-09-0446_UTC.png')

# create figure
fig = plt.figure(figsize=(30,30))
                    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image4[:,:,::-1])
plt.axis('off')
plt.title("Oregonlive")
# Out:
# Text(0.5, 1.0, 'Oregonlive')

# %%
Image5 = cv2.imread('theguar_2023-01-09-0449_UTC.png')

# create figure
fig = plt.figure(figsize=(30,30))
                    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image5[:,:,::-1])
plt.axis('off')
plt.title("The Guardian")
# Out:
# Text(0.5, 1.0, 'The Guardian')

# %%
Image6 = cv2.imread('nytimes_2023-01-09-0453_UTC.png')

# create figure
fig = plt.figure(figsize=(30,30))
                    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image6[:,:,::-1])
plt.axis('off')
plt.title("NY Times")
# Out:
# Text(0.5, 1.0, 'NY Times')

# %%
Image7 = cv2.imread('bbc.com_2023-01-09-0457_UTC.png')

# create figure
fig = plt.figure(figsize=(30,30))
                    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image7[:,:,::-1])
plt.axis('off')
plt.title("BBC")
# Out:
# Text(0.5, 1.0, 'BBC')

# %%
Image8 = cv2.imread('foxnews_2023-01-09-0501_UTC.png')

# create figure
fig = plt.figure(figsize=(30,30))
                    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image8[:,:,::-1])
plt.axis('off')
plt.title("Fox News")
# Out:
# Text(0.5, 1.0, 'Fox News')

# %%
Image9 = cv2.imread('npr.org_2023-01-09-0504_UTC.png')

# create figure
fig = plt.figure(figsize=(30,30))
                    
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image9[:,:,::-1])
plt.axis('off')
plt.title("NPR")
# Out:
# Text(0.5, 1.0, 'NPR')

# %%
data = {"Guardian":{-1:40.983607, 0:40.983607, 1:18.032787},"NYTimes":{-1:19.444444, 0:50.000000,  1:30.555556}, "BBC":{ -1:28.1690140, 0:57.746479,1:14.084507}, "FoxNews":{-1:29.5180720, 0:40.361446, 1:30.120482},"NPR":{ -1:31.25, 0:43.75, 1:25.00},"KPTV":{-1:63.333333, 0:23.333333, 1:13.333333}, "DailyMail":{-1:56.730769, 0:19.230769, 1:24.038462}, "NYPost":{ -1:34.355828, 0:44.785276, 1:20.858896}, "Oregonlive":{-1:28.947368, 0:46.052632, 1:25.000000}}

data
# Out:
# {'Guardian': {-1: 40.983607, 0: 40.983607, 1: 18.032787},
#  'NYTimes': {-1: 19.444444, 0: 50.0, 1: 30.555556},
#  'BBC': {-1: 28.169014, 0: 57.746479, 1: 14.084507},
#  'FoxNews': {-1: 29.518072, 0: 40.361446, 1: 30.120482},
#  'NPR': {-1: 31.25, 0: 43.75, 1: 25.0},
#  'KPTV': {-1: 63.333333, 0: 23.333333, 1: 13.333333},
#  'DailyMail': {-1: 56.730769, 0: 19.230769, 1: 24.038462},
#  'NYPost': {-1: 34.355828, 0: 44.785276, 1: 20.858896},
#  'Oregonlive': {-1: 28.947368, 0: 46.052632, 1: 25.0}}

# %%
data_words = {"Guardian":{"Negative":40.983607, "Neutral":40.983607, "Positive":18.032787},"NYTimes":{"Negative":19.444444, "Neutral":50.000000, "Positive":30.555556}, "BBC":{ "Negative":28.1690140, "Neutral":57.746479,"Positive":14.084507}, "FoxNews":{"Negative":29.5180720, "Neutral":40.361446, "Positive":30.120482},"NPR":{ "Negative":31.25, "Neutral":43.75, "Positive":25.00},"KPTV":{"Negative":63.333333, "Neutral":23.333333, "Positive":13.333333}, "DailyMail":{"Negative":56.730769, "Neutral":19.230769, "Positive":24.038462}, "NYPost":{ "Negative":34.355828, "Neutral":44.785276, "Positive":20.858896}, "Oregonlive":{"Negative":28.947368, "Neutral":46.052632, "Positive":25.000000}}

# %%
df = pd.DataFrame(data_words).T



df.plot(kind="bar", figsize=(12, 8))
plt.title("Negative, Neutral and Positive Sentiment of Media Headlines")
plt.xlabel("Media Organization")
plt.ylabel("Word Frequency by Type")
# Out:
# Text(0, 0.5, 'Word Frequency by Type')

# %% [markdown]
# **Summary:**
# The data clearly demonstrates that overall, the analyzed online news media organizations exhibited a negative bias in their headlines.  Only two news media organizations, the New York Times and Fox News,  had a greater positive score than negative. Fox News’s negative score was within 1 point of its positive score which may be within the margin of error. The news media organization KPTV Fox 12 exhibited the highest bias score of approximately 63 negative words  versus approximately 13 positive words. The Daily Mail’s negative sentiment score was nearly double that of its positive score. Please see the data for additional details.

# %% [markdown]
# **Works Cited**
#
# Hutto, C., and Eric Gilbert. “VADER: A Parsimonious Rule-Based Model for Sentiment Analysis of Social Media Text.” Proceedings of the International AAAI Conference on Web and Social Media, vol. 8, no. 1, 16 May 2014, ojs.aaai.org/index.php/ICWSM/article/view/14550.
#
# Kathirvel, Natarajan. “Post COVID-19 Pandemic Mental Health Challenges.” Asian Journal of Psychiatry, vol. 53, Oct. 2020, p. 102430, www.ncbi.nlm.nih.gov/pmc/articles/PMC7507979/, 10.1016/j.ajp.2020.102430.
#
# Lindberg, Sara. “Is Watching the News Bad for Mental Health?” Verywell Mind, 18 May 2020, www.verywellmind.com/is-watching-the-news-bad-for-mental-health-4802320.
#
# Soroka, Stuart, et al. “Cross-National Evidence of a Negativity Bias in Psychophysiological 	Reactions to News.” Proceedings of the National Academy of Sciences, vol. 116, no. 38, 3 Sept. 2019, pp. 18888–18892, www.pnas.org/content/116/38/18888, 10.1073/pnas.1908369116.

# %%
pipreqsnb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [456], in <cell line: 1>()
# ----> 1 pipreqsnb
#
# NameError: name 'pipreqsnb' is not defined

# %%
pip install pipreqsnb
# Out:
# Collecting pipreqsnb
#   Downloading pipreqsnb-0.2.4.tar.gz (3.7 kB)
# Collecting pipreqs
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: requests in /home/vance_octane/anaconda3/lib/python3.9/site-packages (from yarg->pipreqs->pipreqsnb) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vance_octane/anaconda3/lib/python3.9/site-packages (from requests->yarg->pipreqs->pipreqsnb) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/vance_octane/anaconda3/lib/python3.9/site-packages (from requests->yarg->pipreqs->pipreqsnb) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/vance_octane/anaconda3/lib/python3.9/site-packages (from requests->yarg->pipreqs->pipreqsnb) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/vance_octane/anaconda3/lib/python3.9/site-packages (from requests->yarg->pipreqs->pipreqsnb) (1.26.9)
# Building wheels for collected packages: pipreqsnb, docopt
#   Building wheel for pipreqsnb (setup.py) ... done
#   Created wheel for pipreqsnb: filename=pipreqsnb-0.2.4-py3-none-any.whl size=4145 sha256=de1fc4d3e9912fbdd33520a7f0b959a5dac13002b78d9f66545ced632b09adf0
#   Stored in directory: /home/vance_octane/.cache/pip/wheels/fc/08/53/b2d8c3871408edb7893ce9d4b3df5b011340b9c124c44a8ac3
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=8771ccb9155b335f1e1c86af78aa523128974fda4b3152c969ee9b281005e71f
#   Stored in directory: /home/vance_octane/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built pipreqsnb docopt
# Installing collected packages: yarg, docopt, pipreqs, pipreqsnb
# Successfully installed docopt-0.6.2 pipreqs-0.4.11 pipreqsnb-0.2.4 yarg-0.1.9
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pipreqsnb
# Out:
# Exception occurred while working on file /home/vance_octane/Bsc/cm2015_PWD/midterm/MidtermTests/Midterm.ipynb, cell 6/16
# Traceback (most recent call last):
#   File "/home/vance_octane/anaconda3/bin/pipreqsnb", line 8, in <module>
#     sys.exit(main())
#   File "/home/vance_octane/anaconda3/lib/python3.9/site-packages/pipreqsnb/pipreqsnb.py", line 130, in main
#     raise e
#   File "/home/vance_octane/anaconda3/lib/python3.9/site-packages/pipreqsnb/pipreqsnb.py", line 126, in main
#     imports += get_import_string_from_source(source)
#   File "/home/vance_octane/anaconda3/lib/python3.9/site-packages/pipreqsnb/pipreqsnb.py", line 26, in get_import_string_from_source
#     tree = ast.parse(source)
#   File "/home/vance_octane/anaconda3/lib/python3.9/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#   File "<unknown>", line 1
#     >>> for sentence in cleanData:
#     ^
# SyntaxError: invalid syntax
