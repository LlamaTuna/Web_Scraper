# %%
# Python program to scrape heading tags
import pickle
from IPython import display
import math
from pprint import pprint
import requests
import nltk
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import random
from wordcloud import WordCloud
import os
import spacy
from textblob import TextBlob
from pattern.en import sentiment
import urllib3 
import re
import datetime
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

nlp = spacy.load('en_core_web_sm')
# %matplotlib inline
sns.set(style='darkgrid', context='talk', palette='Dark2')

cleanData = []
tag_words = []
regex = re.compile('[^a-zA-Z]')

headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"} 
#find what headers you are sending here: https://www.whatismybrowser.com/detect/what-http-headers-is-my-browser-sending

url_link = 'https://oregonlive.com' #define URL to scrape
utc_datetime = datetime.datetime.utcnow()
date_string = utc_datetime.strftime("%Y-%m-%d-%H%M_UTC")
filename = f'{url_link[8:len(date_string)]}_{date_string}'


# scrape a chosen URL
request = requests.get(url_link, headers=headers)
Soup = BeautifulSoup(request.text, 'lxml') #create soup obejct

if request.status_code == 200: #error handling for URL request
    print('Request successful.')
elif request.status_code == 404:
    print('Error 404: Not Found.')
    

# creating a list by type of heading tags
heading_tags = ["h1","h2","h3"] #the user will have to determine what "h" tags are valid for given URL
for tags in Soup.find_all(heading_tags):
    tag_words.append(tags.text.strip())
#     lower_words = [strg.lower() for strg in tag_words] #some sentiment analyzers analyze case
    
for i in tag_words:  #slice based on data you want to include. Some junk data can be removed
    if len(i) > 16:    #Fliter a composite length of strings based on targeted threshold
        cleanData.append(regex.sub(' ', i))

deDup = list(set(cleanData))

with open(filename, "wb") as fp: #Pickling data as list with UTC time stamp
    pickle.dump(deDup, fp)

# with open(filename,'w') as a: # uncomment if you want to save a text copy to avoid utf-8 error message
#     a.write('\n'.join(cleanData))
# Out:
# Request successful.

# %% [markdown]
# <h3> The variable name "filename" is the stored value of the file. We can either work with that data or load previously scraped data at this point, i.e "foxnews_2023-01-07-2241_UTC". Be aware that pickled files will not display in Jupyter, to review the text you have to uncomment the above file writing code.<br><br> Once loaded, we slice and print the first five headlines to see if the content is as expected. </h3>

# %%
with open(filename, "rb") as fp: #Either load stored variable value for "filename" or saved pickled "example_1_0_23"
    saved_text = pickle.load(fp)

saved_text[0:5] #confirm your expected text is correct
# Out:
# ['See the most expensive home for sale in each of Oregon s    counties',
#  'More on OregonLive com',
#  'Portland Public Schools slows efforts to end early algebra for select middle schoolers',
#  'Oregon State mailbag  Pac         schedule  Game Day in Corvallis next season  transfer talk',
#  'Liz Weston  Why don t most credit cards require a PIN when you use them ']

# %% [markdown]
# <h3> Once we have the right text, we can check the polarity of the scraped headlines.
# <br><br>
# Sentence-level polarity detection is to decide whether a given sentence expresses either an overall positive or negative opinion. </h3>

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA 

sia = SIA() 
score_data = []

for line in saved_text:
    score = sia.polarity_scores(line)
    score['Headline'] = line
    score_data.append(score)

pprint(score_data, width=100) #pretty print sentiment scores
# Out:
# [{'Headline': 'See the most expensive home for sale in each of Oregon s    counties',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'More on OregonLive com', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Portland Public Schools slows efforts to end early algebra for select middle '
#               'schoolers',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Oregon State mailbag  Pac         schedule  Game Day in Corvallis next season  '
#               'transfer talk',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Liz Weston  Why don t most credit cards require a PIN when you use them ',
#   'compound': 0.4391,
#   'neg': 0.0,
#   'neu': 0.806,
#   'pos': 0.194},
#  {'Headline': 'Beignet bummer  NOLA Doughnuts closes all Portland area locations',
#   'compound': -0.3818,
#   'neg': 0.245,
#   'neu': 0.755,
#   'pos': 0.0},
#  {'Headline': 'Make travel plans now for weekend closure of I    near I     beginning Friday night',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'All state football       Oregon s top  A stars',
#   'compound': 0.2023,
#   'neg': 0.0,
#   'neu': 0.735,
#   'pos': 0.265},
#  {'Headline': 'Rewinding Oregon men s basketball s       win at Utah',
#   'compound': 0.5859,
#   'neg': 0.0,
#   'neu': 0.612,
#   'pos': 0.388},
#  {'Headline': 'Arrest made in      Portland house party shooting that killed Jemare Manns',
#   'compound': -0.6369,
#   'neg': 0.392,
#   'neu': 0.455,
#   'pos': 0.153},
#  {'Headline': 'Workshops and lectures to add to your winter calendar',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Tacoma guaranteed income program shows how much it can help',
#   'compound': 0.4019,
#   'neg': 0.0,
#   'neu': 0.769,
#   'pos': 0.231},
#  {'Headline': 'Damar Hamlin and COVID vaccines  No scientific basis for bogus claim of link to '
#               'more athletes collapsing  dying',
#   'compound': -0.5688,
#   'neg': 0.226,
#   'neu': 0.774,
#   'pos': 0.0},
#  {'Headline': ' Today  show segment gives a shout out to Portland hotel and hostel as a women s '
#               'travel pick',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'N Faly Dante  Will Richardson lead Oregon men s basketball to upset at Utah  keep '
#               'postseason hopes alive for Ducks',
#   'compound': 0.4215,
#   'neg': 0.113,
#   'neu': 0.652,
#   'pos': 0.235},
#  {'Headline': 'Already a Subscriber', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Dear Annie  Loser in a college football bet may experience serious fallout if they '
#               'pay up',
#   'compound': -0.3612,
#   'neg': 0.31,
#   'neu': 0.558,
#   'pos': 0.132},
#  {'Headline': 'Stars matter  Georgia  TCU both excel in player development',
#   'compound': 0.4767,
#   'neg': 0.0,
#   'neu': 0.631,
#   'pos': 0.369},
#  {'Headline': 'Hidden glass float schedule released for      in Lincoln City',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Preservationists say windows at former Portland Korean Church are worth saving  Are '
#               'they Povey Brothers glass ',
#   'compound': 0.2263,
#   'neg': 0.0,
#   'neu': 0.888,
#   'pos': 0.112},
#  {'Headline': 'No     Arizona erases a    point deficit during final three minutes to stun Oregon '
#               'State      ',
#   'compound': -0.5994,
#   'neg': 0.308,
#   'neu': 0.692,
#   'pos': 0.0},
#  {'Headline': 'Circles in the Sand schedule released for      on southern Oregon coast',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Pedestrian dies after being hit by a car in Southeast Portland',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Portland Thorns to name Mike Norris head coach',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Trail Blazers lack of execution late in games costing them victories   We just '
#               'haven t been good enough down the stretch ',
#   'compound': 0.1531,
#   'neg': 0.099,
#   'neu': 0.776,
#   'pos': 0.125},
#  {'Headline': 'Abortion pills to become available at retail  online pharmacies under      FDA '
#               'change',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Let s go eat absurdly inexpensive Cantonese food at Fortune BBQ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Gary Payton II probable for Portland Trail Blazers at Toronto Raptors  Game '
#               'preview  time  TV channel  how to watch free live stream online',
#   'compound': 0.5106,
#   'neg': 0.0,
#   'neu': 0.87,
#   'pos': 0.13},
#  {'Headline': 'Patrick Mahomes sets record  Chiefs beat Raiders for AFC s top seed',
#   'compound': 0.2023,
#   'neg': 0.0,
#   'neu': 0.847,
#   'pos': 0.153},
#  {'Headline': 'Aloha man charged with murder for October shooting in SE Portland Fred Meyer '
#               'parking lot',
#   'compound': -0.7579,
#   'neg': 0.333,
#   'neu': 0.667,
#   'pos': 0.0},
#  {'Headline': 'No  Hooters is not closing because of  millennials ',
#   'compound': -0.296,
#   'neg': 0.239,
#   'neu': 0.761,
#   'pos': 0.0},
#  {'Headline': 'SAIF says data breach may have compromised Social Security numbers  medical '
#               'information',
#   'compound': 0.34,
#   'neg': 0.0,
#   'neu': 0.821,
#   'pos': 0.179},
#  {'Headline': 'Idaho quadruple murder suspect and white Elantra sedan  The trail began with the '
#               'car',
#   'compound': -0.7845,
#   'neg': 0.365,
#   'neu': 0.635,
#   'pos': 0.0},
#  {'Headline': 'Steeple falls  historic stained glass shatters  as crews demolish fire ravaged '
#               'former Portland Korean Church',
#   'compound': -0.34,
#   'neg': 0.146,
#   'neu': 0.854,
#   'pos': 0.0},
#  {'Headline': 'Boy     intentionally shot teacher at school  police say',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Dear Doctor  Can platelet rich plasma therapy relieve arthritis related back pain ',
#   'compound': 0.6597,
#   'neg': 0.165,
#   'neu': 0.4,
#   'pos': 0.435},
#  {'Headline': 'Man charged with murder in fatal shooting of    year old at Portland s Embassy '
#               'Suites hotel',
#   'compound': -0.875,
#   'neg': 0.455,
#   'neu': 0.545,
#   'pos': 0.0},
#  {'Headline': 'Oregon men s basketball in desperate need of win at Utah to keep postseason hopes '
#               'alive',
#   'compound': 0.7845,
#   'neg': 0.102,
#   'neu': 0.489,
#   'pos': 0.409},
#  {'Headline': 'READ MORE TOP NEWS ', 'compound': 0.2716, 'neg': 0.0, 'neu': 0.589, 'pos': 0.411},
#  {'Headline': 'Romance novelist who faked suicide reemerges online',
#   'compound': -0.2263,
#   'neg': 0.344,
#   'neu': 0.382,
#   'pos': 0.275},
#  {'Headline': 'Washington State ends No    Arizona s home winning streak',
#   'compound': 0.296,
#   'neg': 0.19,
#   'neu': 0.517,
#   'pos': 0.293},
#  {'Headline': 'Oregon State lands standout Wyoming defensive end Oluwaseyi Omotosho',
#   'compound': 0.0258,
#   'neg': 0.0,
#   'neu': 0.879,
#   'pos': 0.121},
#  {'Headline': 'Dear Doctor  Very low testosterone can cause loss of muscle and bone',
#   'compound': -0.2716,
#   'neg': 0.288,
#   'neu': 0.552,
#   'pos': 0.16},
#  {'Headline': 'Bill Monroe  Some of the Oregon State Police Fish and Wildlife Division s '
#               'encounters are stranger than fiction',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Eugene based author Cai Emmons  who wrote about living with a fatal ALS diagnosis  '
#               'dies at   ',
#   'compound': -0.5423,
#   'neg': 0.2,
#   'neu': 0.8,
#   'pos': 0.0},
#  {'Headline': 'Teaching children to read  Which districts use phonics based programs',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'After chaotic vote for speaker  Oregon Republican Lori Chavez DeRemer happy to be '
#               'sworn in',
#   'compound': 0.128,
#   'neg': 0.161,
#   'neu': 0.653,
#   'pos': 0.186},
#  {'Headline': 'This Portland pizzeria is No    on a list of the world s best pizzas',
#   'compound': 0.4588,
#   'neg': 0.134,
#   'neu': 0.61,
#   'pos': 0.256},
#  {'Headline': 'What is Kevin McCarthy s speakership going to be like ',
#   'compound': 0.3612,
#   'neg': 0.0,
#   'neu': 0.762,
#   'pos': 0.238},
#  {'Headline': 'Wrestling  Vale s Ava Collins stuns nationally ranked opponent in Idaho s Rollie '
#               'Lane Invitational',
#   'compound': 0.0258,
#   'neg': 0.0,
#   'neu': 0.916,
#   'pos': 0.084},
#  {'Headline': 'Oregon State Beavers at No     Arizona Wildcats women s basketball score updates  '
#               'live stream  TV channel         ',
#   'compound': -0.296,
#   'neg': 0.136,
#   'neu': 0.864,
#   'pos': 0.0},
#  {'Headline': 'Tesla crash off cliff shatters idyllic image of California doctor s family',
#   'compound': -0.4019,
#   'neg': 0.213,
#   'neu': 0.787,
#   'pos': 0.0},
#  {'Headline': 'A newly discovered comet will be visible in the night sky this month',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'New cello concerto reflects on climate change  mass migration',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Colorado defense silences Oregon State  as Beavers score a season low in       loss',
#   'compound': -0.4404,
#   'neg': 0.295,
#   'neu': 0.604,
#   'pos': 0.101},
#  {'Headline': 'Want to get rid of moss in your landscape  Not so fast  Ask Extension',
#   'compound': 0.0772,
#   'neg': 0.0,
#   'neu': 0.909,
#   'pos': 0.091},
#  {'Headline': '   year old boy accused of critically wounding another    year old in Portland '
#               'shooting',
#   'compound': -0.296,
#   'neg': 0.155,
#   'neu': 0.845,
#   'pos': 0.0},
#  {'Headline': 'All state volleyball       Oregon s top  A   A   A stars',
#   'compound': 0.2023,
#   'neg': 0.0,
#   'neu': 0.735,
#   'pos': 0.265},
#  {'Headline': 'Overtime law was supposed to help California farmworkers  Many make less money now',
#   'compound': 0.4019,
#   'neg': 0.0,
#   'neu': 0.816,
#   'pos': 0.184},
#  {'Headline': 'Locked up with no lawyer  This is the reality for    defendants in Oregon today',
#   'compound': -0.296,
#   'neg': 0.145,
#   'neu': 0.855,
#   'pos': 0.0},
#  {'Headline': 'Never opened      million plus biofuels refinery facing foreclosure in southern '
#               'Oregon',
#   'compound': -0.128,
#   'neg': 0.13,
#   'neu': 0.87,
#   'pos': 0.0},
#  {'Headline': 'Oregon Ducks coach Dan Lanning gets portrait tattoo of wife Sauphia with several '
#               'meaningful symbols',
#   'compound': 0.3182,
#   'neg': 0.0,
#   'neu': 0.859,
#   'pos': 0.141},
#  {'Headline': 'Clear Creek Distillery founder dies  a final toast to Steve McCarthy  Steve Duin '
#               'column',
#   'compound': 0.3818,
#   'neg': 0.0,
#   'neu': 0.822,
#   'pos': 0.178},
#  {'Headline': 'Dear Doctor  Are all the medications I take suppressing my dream sleep ',
#   'compound': 0.5574,
#   'neg': 0.0,
#   'neu': 0.662,
#   'pos': 0.338},
#  {'Headline': 'Nude photo and sex texts sent to student lead to Vancouver teacher s arrest  police '
#               'say',
#   'compound': -0.34,
#   'neg': 0.146,
#   'neu': 0.854,
#   'pos': 0.0},
#  {'Headline': 'Damar Hamlin s recovery continues  still in critical condition',
#   'compound': -0.3182,
#   'neg': 0.247,
#   'neu': 0.753,
#   'pos': 0.0},
#  {'Headline': 'Former Oregon Ducks quarterback Jay Butterfield commits to transfer to San Jose '
#               'State',
#   'compound': 0.0258,
#   'neg': 0.0,
#   'neu': 0.916,
#   'pos': 0.084},
#  {'Headline': '   year old caught driving stolen car through North Portland  police say',
#   'compound': -0.4939,
#   'neg': 0.242,
#   'neu': 0.758,
#   'pos': 0.0},
#  {'Headline': 'Oregon passes       COVID related deaths during pandemic',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Basketball game at Franklin High School postponed after parking lot shooting '
#               'injures  ',
#   'compound': -0.2023,
#   'neg': 0.141,
#   'neu': 0.859,
#   'pos': 0.0},
#  {'Headline': 'New fast spreading COVID    variant with creepy nickname  What we know',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': '  men arrested after running from Portland police',
#   'compound': -0.4767,
#   'neg': 0.341,
#   'neu': 0.659,
#   'pos': 0.0},
#  {'Headline': 'Your Regional News Pages', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Endyia Rogers  Grace VanSlooten send Oregon women s basketball cruising past '
#               'Arizona State',
#   'compound': 0.4215,
#   'neg': 0.0,
#   'neu': 0.797,
#   'pos': 0.203},
#  {'Headline': 'Jacksonville Jaguars vs Tennessee Titans free live stream  odds  prediction  time  '
#               'TV channel  watch NFL online           ',
#   'compound': 0.5106,
#   'neg': 0.0,
#   'neu': 0.82,
#   'pos': 0.18},
#  {'Headline': 'Father who shot   members of his family  then himself  was facing divorce',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'ODOT worker who filched   M from state gets    years in prison    others sentenced',
#   'compound': -0.5267,
#   'neg': 0.306,
#   'neu': 0.694,
#   'pos': 0.0},
#  {'Headline': 'All state boys soccer       Oregon s top  A   A   A stars',
#   'compound': 0.2023,
#   'neg': 0.0,
#   'neu': 0.769,
#   'pos': 0.231},
#  {'Headline': 'Footer Navigation', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Recapping Oregon Ducks  Holiday Bowl win  coach Dan Lanning s first year grades  '
#               'Talkin  Ducks',
#   'compound': 0.7579,
#   'neg': 0.0,
#   'neu': 0.649,
#   'pos': 0.351},
#  {'Headline': 'Singer Woody Guthrie s rented flat in Lents is for sale  his Portland legacy '
#               'remains',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0}]

# %% [markdown]
# <h3>Now we can create Pandas data frame to visualize some of the headlines and scores.</h3>

# %%
df = pd.DataFrame.from_records(score_data)
df
# Out:
#       neg    neu    pos  compound  \
# 0   0.000  1.000  0.000    0.0000
# 1   0.000  1.000  0.000    0.0000
# 2   0.000  1.000  0.000    0.0000
# 3   0.000  1.000  0.000    0.0000
# 4   0.000  0.806  0.194    0.4391
# ..    ...    ...    ...       ...
# 76  0.306  0.694  0.000   -0.5267
# 77  0.000  0.769  0.231    0.2023
# 78  0.000  1.000  0.000    0.0000
# 79  0.000  0.649  0.351    0.7579
# 80  0.000  1.000  0.000    0.0000
#
#                                              Headline
# 0   See the most expensive home for sale in each o...
# 1                              More on OregonLive com
# 2   Portland Public Schools slows efforts to end e...
# 3   Oregon State mailbag  Pac         schedule  Ga...
# 4   Liz Weston  Why don t most credit cards requir...
# ..                                                ...
# 76  ODOT worker who filched   M from state gets   ...
# 77  All state boys soccer       Oregon s top  A   ...
# 78                                  Footer Navigation
# 79  Recapping Oregon Ducks  Holiday Bowl win  coac...
# 80  Singer Woody Guthrie s rented flat in Lents is...
#
# [81 rows x 5 columns]

# %%
df['label'] = 0
df.loc[df['compound'] > 0.2, 'label'] = 1
df.loc[df['compound'] < -0.2, 'label'] = -1
df
# Out:
#       neg    neu    pos  compound  \
# 0   0.000  1.000  0.000    0.0000
# 1   0.000  1.000  0.000    0.0000
# 2   0.000  1.000  0.000    0.0000
# 3   0.000  1.000  0.000    0.0000
# 4   0.000  0.806  0.194    0.4391
# ..    ...    ...    ...       ...
# 76  0.306  0.694  0.000   -0.5267
# 77  0.000  0.769  0.231    0.2023
# 78  0.000  1.000  0.000    0.0000
# 79  0.000  0.649  0.351    0.7579
# 80  0.000  1.000  0.000    0.0000
#
#                                              Headline  label
# 0   See the most expensive home for sale in each o...      0
# 1                              More on OregonLive com      0
# 2   Portland Public Schools slows efforts to end e...      0
# 3   Oregon State mailbag  Pac         schedule  Ga...      0
# 4   Liz Weston  Why don t most credit cards requir...      1
# ..                                                ...    ...
# 76  ODOT worker who filched   M from state gets   ...     -1
# 77  All state boys soccer       Oregon s top  A   ...      1
# 78                                  Footer Navigation      0
# 79  Recapping Oregon Ducks  Holiday Bowl win  coac...      1
# 80  Singer Woody Guthrie s rented flat in Lents is...      0
#
# [81 rows x 6 columns]

# %%
df2 = df[['Headline', 'label']]
df2.to_csv(filename +'.csv', mode='a', encoding='utf-8', index=False)

# %%
print("Positive headlines:\n")
pprint(list(df[df['label'] == 1].Headline)[:10], width=200)

print("\nNegative headlines:\n")
pprint(list(df[df['label'] == -1].Headline)[:10], width=200)
# Out:
# Positive headlines:
#
# ['Liz Weston  Why don t most credit cards require a PIN when you use them ',
#  'All state football       Oregon s top  A stars',
#  'Rewinding Oregon men s basketball s       win at Utah',
#  'Tacoma guaranteed income program shows how much it can help',
#  'N Faly Dante  Will Richardson lead Oregon men s basketball to upset at Utah  keep postseason hopes alive for Ducks',
#  'Stars matter  Georgia  TCU both excel in player development',
#  'Preservationists say windows at former Portland Korean Church are worth saving  Are they Povey Brothers glass ',
#  'Gary Payton II probable for Portland Trail Blazers at Toronto Raptors  Game preview  time  TV channel  how to watch free live stream online',
#  'Patrick Mahomes sets record  Chiefs beat Raiders for AFC s top seed',
#  'SAIF says data breach may have compromised Social Security numbers  medical information']
#
# Negative headlines:
#
# ['Beignet bummer  NOLA Doughnuts closes all Portland area locations',
#  'Arrest made in      Portland house party shooting that killed Jemare Manns',
#  'Damar Hamlin and COVID vaccines  No scientific basis for bogus claim of link to more athletes collapsing  dying',
#  'Dear Annie  Loser in a college football bet may experience serious fallout if they pay up',
#  'No     Arizona erases a    point deficit during final three minutes to stun Oregon State      ',
#  'Aloha man charged with murder for October shooting in SE Portland Fred Meyer parking lot',
#  'No  Hooters is not closing because of  millennials ',
#  'Idaho quadruple murder suspect and white Elantra sedan  The trail began with the car',
#  'Steeple falls  historic stained glass shatters  as crews demolish fire ravaged former Portland Korean Church',
#  'Man charged with murder in fatal shooting of    year old at Portland s Embassy Suites hotel']

# %%
print(df.label.value_counts())

print(df.label.value_counts(normalize=True) * 100) #normalize data
# Out:
#  0    32
#  1    25
# -1    24
# Name: label, dtype: int64
#  0    39.506173
#  1    30.864198
# -1    29.629630
# Name: label, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 8))

counts = df.label.value_counts(normalize=True) * 100

sns.barplot(x=counts.index, y=counts, ax=ax)

ax.set_xticklabels(['Negative', 'Neutral', 'Positive'])
ax.set_ylabel("Percentage")

plt.show()

# %%
textblob_sentiment=[]
for s in saved_text:
    txt= TextBlob(s)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([s,a,b])

# %%
df_textblob = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_textblob
# Out:
#                                              Sentence  Polarity  Subjectivity
# 0   See the most expensive home for sale in each o...  0.000000      0.600000
# 1                              More on OregonLive com  0.500000      0.500000
# 2   Portland Public Schools slows efforts to end e...  0.033333      0.122222
# 3   Oregon State mailbag  Pac         schedule  Ga... -0.200000      0.200000
# 4   Liz Weston  Why don t most credit cards requir...  0.500000      0.500000
# ..                                                ...       ...           ...
# 76  ODOT worker who filched   M from state gets   ...  0.000000      0.000000
# 77  All state boys soccer       Oregon s top  A   ...  0.500000      0.500000
# 78                                  Footer Navigation  0.000000      0.000000
# 79  Recapping Oregon Ducks  Holiday Bowl win  coac...  0.525000      0.366667
# 80  Singer Woody Guthrie s rented flat in Lents is... -0.025000      0.125000
#
# [81 rows x 3 columns]

# %%
df_textblob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      81 non-null     object
#  1   Polarity      81 non-null     float64
#  2   Subjectivity  81 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 2.0+ KB

# %%
sns.displot(df_textblob["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Textblob)")
# Out:
# Text(0.5, 15.439999999999998, 'Sentence Polarity (Textblob)')

# %%
sns.displot(df_textblob["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Textblob)")
# Out:
# Text(0.5, 15.439999999999998, 'Sentence Subjectivity (Textblob)')

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
stop_tokens = []
stop_tokens_plot = []

def process_text(headlines):
    for line in headlines:
        toks = tokenizer.tokenize(line)
        toks = [t.lower() for t in toks if t.lower() not in stop_words]
        stop_tokens.extend(toks)
        stop_tokens_plot.append(toks)
    
    return stop_tokens

process_text(saved_text)
# Out:
# ['see',
#  'expensive',
#  'home',
#  'sale',
#  'oregon',
#  'counties',
#  'oregonlive',
#  'com',
#  'portland',
#  'public',
#  'schools',
#  'slows',
#  'efforts',
#  'end',
#  'early',
#  'algebra',
#  'select',
#  'middle',
#  'schoolers',
#  'oregon',
#  'state',
#  'mailbag',
#  'pac',
#  'schedule',
#  'game',
#  'day',
#  'corvallis',
#  'next',
#  'season',
#  'transfer',
#  'talk',
#  'liz',
#  'weston',
#  'credit',
#  'cards',
#  'require',
#  'pin',
#  'use',
#  'beignet',
#  'bummer',
#  'nola',
#  'doughnuts',
#  'closes',
#  'portland',
#  'area',
#  'locations',
#  'state',
#  'football',
#  'oregon',
#  'top',
#  'stars',
#  'rewinding',
#  'oregon',
#  'men',
#  'basketball',
#  'win',
#  'utah',
#  'arrest',
#  'made',
#  'portland',
#  'house',
#  'party',
#  'shooting',
#  'killed',
#  'jemare',
#  'manns',
#  'workshops',
#  'lectures',
#  'add',
#  'winter',
#  'calendar',
#  'tacoma',
#  'guaranteed',
#  'income',
#  'program',
#  'shows',
#  'much',
#  'help',
#  'damar',
#  'hamlin',
#  'covid',
#  'vaccines',
#  'scientific',
#  'basis',
#  'bogus',
#  'claim',
#  'link',
#  'athletes',
#  'collapsing',
#  'dying',
#  'today',
#  'show',
#  'segment',
#  'gives',
#  'shout',
#  'portland',
#  'hotel',
#  'hostel',
#  'women',
#  'travel',
#  'pick',
#  'n',
#  'faly',
#  'dante',
#  'richardson',
#  'lead',
#  'oregon',
#  'men',
#  'basketball',
#  'upset',
#  'utah',
#  'keep',
#  'postseason',
#  'hopes',
#  'alive',
#  'ducks',
#  'already',
#  'subscriber',
#  'dear',
#  'annie',
#  'loser',
#  'college',
#  'football',
#  'bet',
#  'may',
#  'experience',
#  'serious',
#  'fallout',
#  'pay',
#  'stars',
#  'matter',
#  'georgia',
#  'tcu',
#  'excel',
#  'player',
#  'development',
#  'hidden',
#  'glass',
#  'float',
#  'schedule',
#  'released',
#  'lincoln',
#  'city',
#  'preservationists',
#  'say',
#  'windows',
#  'former',
#  'portland',
#  'korean',
#  'church',
#  'worth',
#  'saving',
#  'povey',
#  'brothers',
#  'glass',
#  'arizona',
#  'erases',
#  'point',
#  'deficit',
#  'final',
#  'three',
#  'minutes',
#  'stun',
#  'oregon',
#  'state',
#  'circles',
#  'sand',
#  'schedule',
#  'released',
#  'southern',
#  'oregon',
#  'coast',
#  'pedestrian',
#  'dies',
#  'hit',
#  'car',
#  'southeast',
#  'portland',
#  'portland',
#  'thorns',
#  'name',
#  'mike',
#  'norris',
#  'head',
#  'coach',
#  'trail',
#  'blazers',
#  'lack',
#  'execution',
#  'late',
#  'games',
#  'costing',
#  'victories',
#  'good',
#  'enough',
#  'stretch',
#  'abortion',
#  'pills',
#  'become',
#  'available',
#  'retail',
#  'online',
#  'pharmacies',
#  'fda',
#  'change',
#  'let',
#  'go',
#  'eat',
#  'absurdly',
#  'inexpensive',
#  'cantonese',
#  'food',
#  'fortune',
#  'bbq',
#  'gary',
#  'payton',
#  'ii',
#  'probable',
#  'portland',
#  'trail',
#  'blazers',
#  'toronto',
#  'raptors',
#  'game',
#  'preview',
#  'time',
#  'tv',
#  'channel',
#  'watch',
#  'free',
#  'live',
#  'stream',
#  'online',
#  'patrick',
#  'mahomes',
#  'sets',
#  'record',
#  'chiefs',
#  'beat',
#  'raiders',
#  'afc',
#  'top',
#  'seed',
#  'aloha',
#  'man',
#  'charged',
#  'murder',
#  'october',
#  'shooting',
#  'se',
#  'portland',
#  'fred',
#  'meyer',
#  'parking',
#  'lot',
#  'hooters',
#  'closing',
#  'millennials',
#  'saif',
#  'says',
#  'data',
#  'breach',
#  'may',
#  'compromised',
#  'social',
#  'security',
#  'numbers',
#  'medical',
#  'information',
#  'idaho',
#  'quadruple',
#  'murder',
#  'suspect',
#  'white',
#  'elantra',
#  'sedan',
#  'trail',
#  'began',
#  'car',
#  'steeple',
#  'falls',
#  'historic',
#  'stained',
#  'glass',
#  'shatters',
#  'crews',
#  'demolish',
#  'fire',
#  'ravaged',
#  'former',
#  'portland',
#  'korean',
#  'church',
#  'boy',
#  'intentionally',
#  'shot',
#  'teacher',
#  'school',
#  'police',
#  'say',
#  'dear',
#  'doctor',
#  'platelet',
#  'rich',
#  'plasma',
#  'therapy',
#  'relieve',
#  'arthritis',
#  'related',
#  'back',
#  'pain',
#  'man',
#  'charged',
#  'murder',
#  'fatal',
#  'shooting',
#  'year',
#  'old',
#  'portland',
#  'embassy',
#  'suites',
#  'hotel',
#  'oregon',
#  'men',
#  'basketball',
#  'desperate',
#  'need',
#  'win',
#  'utah',
#  'keep',
#  'postseason',
#  'hopes',
#  'alive',
#  'read',
#  'top',
#  'news',
#  'romance',
#  'novelist',
#  'faked',
#  'suicide',
#  'reemerges',
#  'online',
#  'washington',
#  'state',
#  'ends',
#  'arizona',
#  'home',
#  'winning',
#  'streak',
#  'oregon',
#  'state',
#  'lands',
#  'standout',
#  'wyoming',
#  'defensive',
#  'end',
#  'oluwaseyi',
#  'omotosho',
#  'dear',
#  'doctor',
#  'low',
#  'testosterone',
#  'cause',
#  'loss',
#  'muscle',
#  'bone',
#  'bill',
#  'monroe',
#  'oregon',
#  'state',
#  'police',
#  'fish',
#  'wildlife',
#  'division',
#  'encounters',
#  'stranger',
#  'fiction',
#  'eugene',
#  'based',
#  'author',
#  'cai',
#  'emmons',
#  'wrote',
#  'living',
#  'fatal',
#  'als',
#  'diagnosis',
#  'dies',
#  'teaching',
#  'children',
#  'read',
#  'districts',
#  'use',
#  'phonics',
#  'based',
#  'programs',
#  'chaotic',
#  'vote',
#  'speaker',
#  'oregon',
#  'republican',
#  'lori',
#  'chavez',
#  'deremer',
#  'happy',
#  'sworn',
#  'portland',
#  'pizzeria',
#  'list',
#  'world',
#  'best',
#  'pizzas',
#  'oregon',
#  'state',
#  'beavers',
#  'colorado',
#  'buffaloes',
#  'score',
#  'updates',
#  'live',
#  'stream',
#  'odds',
#  'tv',
#  'channel',
#  'kevin',
#  'mccarthy',
#  'speakership',
#  'going',
#  'like',
#  'wrestling',
#  'vale',
#  'ava',
#  'collins',
#  'stuns',
#  'nationally',
#  'ranked',
#  'opponent',
#  'idaho',
#  'rollie',
#  'lane',
#  'invitational',
#  'oregon',
#  'state',
#  'beavers',
#  'arizona',
#  'wildcats',
#  'women',
#  'basketball',
#  'score',
#  'updates',
#  'live',
#  'stream',
#  'tv',
#  'channel',
#  'tesla',
#  'crash',
#  'cliff',
#  'shatters',
#  'idyllic',
#  'image',
#  'california',
#  'doctor',
#  'family',
#  'newly',
#  'discovered',
#  'comet',
#  'visible',
#  'night',
#  'sky',
#  'month',
#  'new',
#  'cello',
#  'concerto',
#  'reflects',
#  'climate',
#  'change',
#  'mass',
#  'migration',
#  'colorado',
#  'defense',
#  'silences',
#  'oregon',
#  'state',
#  'beavers',
#  'score',
#  'season',
#  'low',
#  'loss',
#  'want',
#  'get',
#  'rid',
#  'moss',
#  'landscape',
#  'fast',
#  'ask',
#  'extension',
#  'year',
#  'old',
#  'boy',
#  'accused',
#  'critically',
#  'wounding',
#  'another',
#  'year',
#  'old',
#  'portland',
#  'shooting',
#  'state',
#  'volleyball',
#  'oregon',
#  'top',
#  'stars',
#  'overtime',
#  'law',
#  'supposed',
#  'help',
#  'california',
#  'farmworkers',
#  'many',
#  'make',
#  'less',
#  'money',
#  'locked',
#  'lawyer',
#  'reality',
#  'defendants',
#  'oregon',
#  'today',
#  'never',
#  'opened',
#  'million',
#  'plus',
#  'biofuels',
#  'refinery',
#  'facing',
#  'foreclosure',
#  'southern',
#  'oregon',
#  'oregon',
#  'ducks',
#  'coach',
#  'dan',
#  'lanning',
#  'gets',
#  'portrait',
#  'tattoo',
#  'wife',
#  'sauphia',
#  'several',
#  'meaningful',
#  'symbols',
#  'clear',
#  'creek',
#  'distillery',
#  'founder',
#  'dies',
#  'final',
#  'toast',
#  'steve',
#  'mccarthy',
#  'steve',
#  'duin',
#  'column',
#  'dear',
#  'doctor',
#  'medications',
#  'take',
#  'suppressing',
#  'dream',
#  'sleep',
#  'nude',
#  'photo',
#  'sex',
#  'texts',
#  'sent',
#  'student',
#  'lead',
#  'vancouver',
#  'teacher',
#  'arrest',
#  'police',
#  'say',
#  'damar',
#  'hamlin',
#  'recovery',
#  'continues',
#  'still',
#  'critical',
#  'condition',
#  'former',
#  'oregon',
#  'ducks',
#  'quarterback',
#  'jay',
#  'butterfield',
#  'commits',
#  'transfer',
#  'san',
#  'jose',
#  'state',
#  'year',
#  'old',
#  'caught',
#  'driving',
#  'stolen',
#  'car',
#  'north',
#  'portland',
#  'police',
#  'say',
#  'oregon',
#  'passes',
#  'covid',
#  'related',
#  'deaths',
#  'pandemic',
#  'basketball',
#  'game',
#  'franklin',
#  'high',
#  'school',
#  'postponed',
#  'parking',
#  'lot',
#  'shooting',
#  'injures',
#  'new',
#  'fast',
#  'spreading',
#  'covid',
#  'variant',
#  'creepy',
#  'nickname',
#  'know',
#  'men',
#  'arrested',
#  'running',
#  'portland',
#  'police',
#  'regional',
#  'news',
#  'pages',
#  'endyia',
#  'rogers',
#  'grace',
#  'vanslooten',
#  'send',
#  'oregon',
#  'women',
#  'basketball',
#  'cruising',
#  'past',
#  'arizona',
#  'state',
#  'jacksonville',
#  'jaguars',
#  'vs',
#  'tennessee',
#  'titans',
#  'free',
#  'live',
#  'stream',
#  'odds',
#  'prediction',
#  'time',
#  'tv',
#  'channel',
#  'watch',
#  'nfl',
#  'online',
#  'father',
#  'shot',
#  'members',
#  'family',
#  'facing',
#  'divorce',
#  'odot',
#  'worker',
#  'filched',
#  'state',
#  'gets',
#  'years',
#  'prison',
#  'others',
#  'sentenced',
#  'state',
#  'boys',
#  'soccer',
#  'oregon',
#  'top',
#  'stars',
#  'footer',
#  'navigation',
#  'recapping',
#  'oregon',
#  'ducks',
#  'holiday',
#  'bowl',
#  'win',
#  'coach',
#  'dan',
#  'lanning',
#  'first',
#  'year',
#  'grades',
#  'talkin',
#  'ducks',
#  'singer',
#  'woody',
#  'guthrie',
#  'rented',
#  'flat',
#  'lents',
#  'sale',
#  'portland',
#  'legacy',
#  'remains']

# %%
flat_tokens = [item for sublist in stop_tokens_plot for item in sublist] 
flat_tokens
# Out:
# ['see',
#  'expensive',
#  'home',
#  'sale',
#  'oregon',
#  'counties',
#  'oregonlive',
#  'com',
#  'portland',
#  'public',
#  'schools',
#  'slows',
#  'efforts',
#  'end',
#  'early',
#  'algebra',
#  'select',
#  'middle',
#  'schoolers',
#  'oregon',
#  'state',
#  'mailbag',
#  'pac',
#  'schedule',
#  'game',
#  'day',
#  'corvallis',
#  'next',
#  'season',
#  'transfer',
#  'talk',
#  'liz',
#  'weston',
#  'credit',
#  'cards',
#  'require',
#  'pin',
#  'use',
#  'beignet',
#  'bummer',
#  'nola',
#  'doughnuts',
#  'closes',
#  'portland',
#  'area',
#  'locations',
#  'state',
#  'football',
#  'oregon',
#  'top',
#  'stars',
#  'rewinding',
#  'oregon',
#  'men',
#  'basketball',
#  'win',
#  'utah',
#  'arrest',
#  'made',
#  'portland',
#  'house',
#  'party',
#  'shooting',
#  'killed',
#  'jemare',
#  'manns',
#  'workshops',
#  'lectures',
#  'add',
#  'winter',
#  'calendar',
#  'tacoma',
#  'guaranteed',
#  'income',
#  'program',
#  'shows',
#  'much',
#  'help',
#  'damar',
#  'hamlin',
#  'covid',
#  'vaccines',
#  'scientific',
#  'basis',
#  'bogus',
#  'claim',
#  'link',
#  'athletes',
#  'collapsing',
#  'dying',
#  'today',
#  'show',
#  'segment',
#  'gives',
#  'shout',
#  'portland',
#  'hotel',
#  'hostel',
#  'women',
#  'travel',
#  'pick',
#  'n',
#  'faly',
#  'dante',
#  'richardson',
#  'lead',
#  'oregon',
#  'men',
#  'basketball',
#  'upset',
#  'utah',
#  'keep',
#  'postseason',
#  'hopes',
#  'alive',
#  'ducks',
#  'already',
#  'subscriber',
#  'dear',
#  'annie',
#  'loser',
#  'college',
#  'football',
#  'bet',
#  'may',
#  'experience',
#  'serious',
#  'fallout',
#  'pay',
#  'stars',
#  'matter',
#  'georgia',
#  'tcu',
#  'excel',
#  'player',
#  'development',
#  'hidden',
#  'glass',
#  'float',
#  'schedule',
#  'released',
#  'lincoln',
#  'city',
#  'preservationists',
#  'say',
#  'windows',
#  'former',
#  'portland',
#  'korean',
#  'church',
#  'worth',
#  'saving',
#  'povey',
#  'brothers',
#  'glass',
#  'arizona',
#  'erases',
#  'point',
#  'deficit',
#  'final',
#  'three',
#  'minutes',
#  'stun',
#  'oregon',
#  'state',
#  'circles',
#  'sand',
#  'schedule',
#  'released',
#  'southern',
#  'oregon',
#  'coast',
#  'pedestrian',
#  'dies',
#  'hit',
#  'car',
#  'southeast',
#  'portland',
#  'portland',
#  'thorns',
#  'name',
#  'mike',
#  'norris',
#  'head',
#  'coach',
#  'trail',
#  'blazers',
#  'lack',
#  'execution',
#  'late',
#  'games',
#  'costing',
#  'victories',
#  'good',
#  'enough',
#  'stretch',
#  'abortion',
#  'pills',
#  'become',
#  'available',
#  'retail',
#  'online',
#  'pharmacies',
#  'fda',
#  'change',
#  'let',
#  'go',
#  'eat',
#  'absurdly',
#  'inexpensive',
#  'cantonese',
#  'food',
#  'fortune',
#  'bbq',
#  'gary',
#  'payton',
#  'ii',
#  'probable',
#  'portland',
#  'trail',
#  'blazers',
#  'toronto',
#  'raptors',
#  'game',
#  'preview',
#  'time',
#  'tv',
#  'channel',
#  'watch',
#  'free',
#  'live',
#  'stream',
#  'online',
#  'patrick',
#  'mahomes',
#  'sets',
#  'record',
#  'chiefs',
#  'beat',
#  'raiders',
#  'afc',
#  'top',
#  'seed',
#  'aloha',
#  'man',
#  'charged',
#  'murder',
#  'october',
#  'shooting',
#  'se',
#  'portland',
#  'fred',
#  'meyer',
#  'parking',
#  'lot',
#  'hooters',
#  'closing',
#  'millennials',
#  'saif',
#  'says',
#  'data',
#  'breach',
#  'may',
#  'compromised',
#  'social',
#  'security',
#  'numbers',
#  'medical',
#  'information',
#  'idaho',
#  'quadruple',
#  'murder',
#  'suspect',
#  'white',
#  'elantra',
#  'sedan',
#  'trail',
#  'began',
#  'car',
#  'steeple',
#  'falls',
#  'historic',
#  'stained',
#  'glass',
#  'shatters',
#  'crews',
#  'demolish',
#  'fire',
#  'ravaged',
#  'former',
#  'portland',
#  'korean',
#  'church',
#  'boy',
#  'intentionally',
#  'shot',
#  'teacher',
#  'school',
#  'police',
#  'say',
#  'dear',
#  'doctor',
#  'platelet',
#  'rich',
#  'plasma',
#  'therapy',
#  'relieve',
#  'arthritis',
#  'related',
#  'back',
#  'pain',
#  'man',
#  'charged',
#  'murder',
#  'fatal',
#  'shooting',
#  'year',
#  'old',
#  'portland',
#  'embassy',
#  'suites',
#  'hotel',
#  'oregon',
#  'men',
#  'basketball',
#  'desperate',
#  'need',
#  'win',
#  'utah',
#  'keep',
#  'postseason',
#  'hopes',
#  'alive',
#  'read',
#  'top',
#  'news',
#  'romance',
#  'novelist',
#  'faked',
#  'suicide',
#  'reemerges',
#  'online',
#  'washington',
#  'state',
#  'ends',
#  'arizona',
#  'home',
#  'winning',
#  'streak',
#  'oregon',
#  'state',
#  'lands',
#  'standout',
#  'wyoming',
#  'defensive',
#  'end',
#  'oluwaseyi',
#  'omotosho',
#  'dear',
#  'doctor',
#  'low',
#  'testosterone',
#  'cause',
#  'loss',
#  'muscle',
#  'bone',
#  'bill',
#  'monroe',
#  'oregon',
#  'state',
#  'police',
#  'fish',
#  'wildlife',
#  'division',
#  'encounters',
#  'stranger',
#  'fiction',
#  'eugene',
#  'based',
#  'author',
#  'cai',
#  'emmons',
#  'wrote',
#  'living',
#  'fatal',
#  'als',
#  'diagnosis',
#  'dies',
#  'teaching',
#  'children',
#  'read',
#  'districts',
#  'use',
#  'phonics',
#  'based',
#  'programs',
#  'chaotic',
#  'vote',
#  'speaker',
#  'oregon',
#  'republican',
#  'lori',
#  'chavez',
#  'deremer',
#  'happy',
#  'sworn',
#  'portland',
#  'pizzeria',
#  'list',
#  'world',
#  'best',
#  'pizzas',
#  'oregon',
#  'state',
#  'beavers',
#  'colorado',
#  'buffaloes',
#  'score',
#  'updates',
#  'live',
#  'stream',
#  'odds',
#  'tv',
#  'channel',
#  'kevin',
#  'mccarthy',
#  'speakership',
#  'going',
#  'like',
#  'wrestling',
#  'vale',
#  'ava',
#  'collins',
#  'stuns',
#  'nationally',
#  'ranked',
#  'opponent',
#  'idaho',
#  'rollie',
#  'lane',
#  'invitational',
#  'oregon',
#  'state',
#  'beavers',
#  'arizona',
#  'wildcats',
#  'women',
#  'basketball',
#  'score',
#  'updates',
#  'live',
#  'stream',
#  'tv',
#  'channel',
#  'tesla',
#  'crash',
#  'cliff',
#  'shatters',
#  'idyllic',
#  'image',
#  'california',
#  'doctor',
#  'family',
#  'newly',
#  'discovered',
#  'comet',
#  'visible',
#  'night',
#  'sky',
#  'month',
#  'new',
#  'cello',
#  'concerto',
#  'reflects',
#  'climate',
#  'change',
#  'mass',
#  'migration',
#  'colorado',
#  'defense',
#  'silences',
#  'oregon',
#  'state',
#  'beavers',
#  'score',
#  'season',
#  'low',
#  'loss',
#  'want',
#  'get',
#  'rid',
#  'moss',
#  'landscape',
#  'fast',
#  'ask',
#  'extension',
#  'year',
#  'old',
#  'boy',
#  'accused',
#  'critically',
#  'wounding',
#  'another',
#  'year',
#  'old',
#  'portland',
#  'shooting',
#  'state',
#  'volleyball',
#  'oregon',
#  'top',
#  'stars',
#  'overtime',
#  'law',
#  'supposed',
#  'help',
#  'california',
#  'farmworkers',
#  'many',
#  'make',
#  'less',
#  'money',
#  'locked',
#  'lawyer',
#  'reality',
#  'defendants',
#  'oregon',
#  'today',
#  'never',
#  'opened',
#  'million',
#  'plus',
#  'biofuels',
#  'refinery',
#  'facing',
#  'foreclosure',
#  'southern',
#  'oregon',
#  'oregon',
#  'ducks',
#  'coach',
#  'dan',
#  'lanning',
#  'gets',
#  'portrait',
#  'tattoo',
#  'wife',
#  'sauphia',
#  'several',
#  'meaningful',
#  'symbols',
#  'clear',
#  'creek',
#  'distillery',
#  'founder',
#  'dies',
#  'final',
#  'toast',
#  'steve',
#  'mccarthy',
#  'steve',
#  'duin',
#  'column',
#  'dear',
#  'doctor',
#  'medications',
#  'take',
#  'suppressing',
#  'dream',
#  'sleep',
#  'nude',
#  'photo',
#  'sex',
#  'texts',
#  'sent',
#  'student',
#  'lead',
#  'vancouver',
#  'teacher',
#  'arrest',
#  'police',
#  'say',
#  'damar',
#  'hamlin',
#  'recovery',
#  'continues',
#  'still',
#  'critical',
#  'condition',
#  'former',
#  'oregon',
#  'ducks',
#  'quarterback',
#  'jay',
#  'butterfield',
#  'commits',
#  'transfer',
#  'san',
#  'jose',
#  'state',
#  'year',
#  'old',
#  'caught',
#  'driving',
#  'stolen',
#  'car',
#  'north',
#  'portland',
#  'police',
#  'say',
#  'oregon',
#  'passes',
#  'covid',
#  'related',
#  'deaths',
#  'pandemic',
#  'basketball',
#  'game',
#  'franklin',
#  'high',
#  'school',
#  'postponed',
#  'parking',
#  'lot',
#  'shooting',
#  'injures',
#  'new',
#  'fast',
#  'spreading',
#  'covid',
#  'variant',
#  'creepy',
#  'nickname',
#  'know',
#  'men',
#  'arrested',
#  'running',
#  'portland',
#  'police',
#  'regional',
#  'news',
#  'pages',
#  'endyia',
#  'rogers',
#  'grace',
#  'vanslooten',
#  'send',
#  'oregon',
#  'women',
#  'basketball',
#  'cruising',
#  'past',
#  'arizona',
#  'state',
#  'jacksonville',
#  'jaguars',
#  'vs',
#  'tennessee',
#  'titans',
#  'free',
#  'live',
#  'stream',
#  'odds',
#  'prediction',
#  'time',
#  'tv',
#  'channel',
#  'watch',
#  'nfl',
#  'online',
#  'father',
#  'shot',
#  'members',
#  'family',
#  'facing',
#  'divorce',
#  'odot',
#  'worker',
#  'filched',
#  'state',
#  'gets',
#  'years',
#  'prison',
#  'others',
#  'sentenced',
#  'state',
#  'boys',
#  'soccer',
#  'oregon',
#  'top',
#  'stars',
#  'footer',
#  'navigation',
#  'recapping',
#  'oregon',
#  'ducks',
#  'holiday',
#  'bowl',
#  'win',
#  'coach',
#  'dan',
#  'lanning',
#  'first',
#  'year',
#  'grades',
#  'talkin',
#  'ducks',
#  'singer',
#  'woody',
#  'guthrie',
#  'rented',
#  'flat',
#  'lents',
#  'sale',
#  'portland',
#  'legacy',
#  'remains']

# %%
pos_lines = list(df[df.label == 1].headline)

pos_tokens = process_text(pos_lines)
pos_freq = nltk.FreqDist(pos_tokens)

pos_freq.most_common(20)
# Out:
# [('oregon', 32),
#  ('portland', 19),
#  ('state', 19),
#  ('top', 10),
#  ('basketball', 10),
#  ('ducks', 9),
#  ('stars', 8),
#  ('men', 7),
#  ('win', 6),
#  ('utah', 6),
#  ('dear', 6),
#  ('arizona', 6),
#  ('online', 6),
#  ('tv', 6),
#  ('channel', 6),
#  ('live', 6),
#  ('stream', 6),
#  ('doctor', 6),
#  ('year', 6),
#  ('shooting', 5)]

# %%
y_val = [x[1] for x in pos_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Positive)")
plt.show()

# %%
y_final = []
for i, k, z, t in zip(y_val[0::4], y_val[1::4], y_val[2::4], y_val[3::4]):
    y_final.append(math.log(i + k + z + t))

x_val = [math.log(i + 1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Word Frequency Distribution (Positive)")
plt.plot(x_val, y_final)
plt.show()

# %%
neg_lines = list(df2[df2.label == -1].headline)

neg_tokens = process_text(neg_lines)
neg_freq = nltk.FreqDist(neg_tokens)

neg_freq.most_common(20)
# Out:
# [('oregon', 36),
#  ('portland', 27),
#  ('state', 23),
#  ('basketball', 12),
#  ('top', 10),
#  ('shooting', 10),
#  ('year', 10),
#  ('ducks', 9),
#  ('stars', 8),
#  ('men', 8),
#  ('dear', 8),
#  ('arizona', 8),
#  ('police', 8),
#  ('doctor', 8),
#  ('old', 8),
#  ('say', 7),
#  ('online', 7),
#  ('tv', 7),
#  ('channel', 7),
#  ('live', 7)]

# %%
y_val = [x[1] for x in neg_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Negative)")
plt.show()

# %%
y_final = []
for i, k, z in zip(y_val[0::3], y_val[1::3], y_val[2::3]):
    if i + k + z == 0:
        break
    y_final.append(math.log(i + k + z))

x_val = [math.log(i+1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Word Frequency Distribution (Negative)")
plt.plot(x_val, y_final)
plt.show()

# %%
from nltk.stem import WordNetLemmatizer
ls = WordNetLemmatizer()
stem_tokens = []
for t in stop_tokens:
    if len(t) > 1:
        lemma = ls.lemmatize(t) 
        stem_tokens.append(lemma)

# %%
stem_tokens
# Out:
# ['see',
#  'expensive',
#  'home',
#  'sale',
#  'oregon',
#  'county',
#  'oregonlive',
#  'com',
#  'portland',
#  'public',
#  'school',
#  'slows',
#  'effort',
#  'end',
#  'early',
#  'algebra',
#  'select',
#  'middle',
#  'schoolers',
#  'oregon',
#  'state',
#  'mailbag',
#  'pac',
#  'schedule',
#  'game',
#  'day',
#  'corvallis',
#  'next',
#  'season',
#  'transfer',
#  'talk',
#  'liz',
#  'weston',
#  'credit',
#  'card',
#  'require',
#  'pin',
#  'use',
#  'beignet',
#  'bummer',
#  'nola',
#  'doughnut',
#  'close',
#  'portland',
#  'area',
#  'location',
#  'state',
#  'football',
#  'oregon',
#  'top',
#  'star',
#  'rewinding',
#  'oregon',
#  'men',
#  'basketball',
#  'win',
#  'utah',
#  'arrest',
#  'made',
#  'portland',
#  'house',
#  'party',
#  'shooting',
#  'killed',
#  'jemare',
#  'mann',
#  'workshop',
#  'lecture',
#  'add',
#  'winter',
#  'calendar',
#  'tacoma',
#  'guaranteed',
#  'income',
#  'program',
#  'show',
#  'much',
#  'help',
#  'damar',
#  'hamlin',
#  'covid',
#  'vaccine',
#  'scientific',
#  'basis',
#  'bogus',
#  'claim',
#  'link',
#  'athlete',
#  'collapsing',
#  'dying',
#  'today',
#  'show',
#  'segment',
#  'give',
#  'shout',
#  'portland',
#  'hotel',
#  'hostel',
#  'woman',
#  'travel',
#  'pick',
#  'faly',
#  'dante',
#  'richardson',
#  'lead',
#  'oregon',
#  'men',
#  'basketball',
#  'upset',
#  'utah',
#  'keep',
#  'postseason',
#  'hope',
#  'alive',
#  'duck',
#  'already',
#  'subscriber',
#  'dear',
#  'annie',
#  'loser',
#  'college',
#  'football',
#  'bet',
#  'may',
#  'experience',
#  'serious',
#  'fallout',
#  'pay',
#  'star',
#  'matter',
#  'georgia',
#  'tcu',
#  'excel',
#  'player',
#  'development',
#  'hidden',
#  'glass',
#  'float',
#  'schedule',
#  'released',
#  'lincoln',
#  'city',
#  'preservationist',
#  'say',
#  'window',
#  'former',
#  'portland',
#  'korean',
#  'church',
#  'worth',
#  'saving',
#  'povey',
#  'brother',
#  'glass',
#  'arizona',
#  'era',
#  'point',
#  'deficit',
#  'final',
#  'three',
#  'minute',
#  'stun',
#  'oregon',
#  'state',
#  'circle',
#  'sand',
#  'schedule',
#  'released',
#  'southern',
#  'oregon',
#  'coast',
#  'pedestrian',
#  'dy',
#  'hit',
#  'car',
#  'southeast',
#  'portland',
#  'portland',
#  'thorn',
#  'name',
#  'mike',
#  'norris',
#  'head',
#  'coach',
#  'trail',
#  'blazer',
#  'lack',
#  'execution',
#  'late',
#  'game',
#  'costing',
#  'victory',
#  'good',
#  'enough',
#  'stretch',
#  'abortion',
#  'pill',
#  'become',
#  'available',
#  'retail',
#  'online',
#  'pharmacy',
#  'fda',
#  'change',
#  'let',
#  'go',
#  'eat',
#  'absurdly',
#  'inexpensive',
#  'cantonese',
#  'food',
#  'fortune',
#  'bbq',
#  'gary',
#  'payton',
#  'ii',
#  'probable',
#  'portland',
#  'trail',
#  'blazer',
#  'toronto',
#  'raptor',
#  'game',
#  'preview',
#  'time',
#  'tv',
#  'channel',
#  'watch',
#  'free',
#  'live',
#  'stream',
#  'online',
#  'patrick',
#  'mahomes',
#  'set',
#  'record',
#  'chief',
#  'beat',
#  'raider',
#  'afc',
#  'top',
#  'seed',
#  'aloha',
#  'man',
#  'charged',
#  'murder',
#  'october',
#  'shooting',
#  'se',
#  'portland',
#  'fred',
#  'meyer',
#  'parking',
#  'lot',
#  'hooter',
#  'closing',
#  'millennials',
#  'saif',
#  'say',
#  'data',
#  'breach',
#  'may',
#  'compromised',
#  'social',
#  'security',
#  'number',
#  'medical',
#  'information',
#  'idaho',
#  'quadruple',
#  'murder',
#  'suspect',
#  'white',
#  'elantra',
#  'sedan',
#  'trail',
#  'began',
#  'car',
#  'steeple',
#  'fall',
#  'historic',
#  'stained',
#  'glass',
#  'shatters',
#  'crew',
#  'demolish',
#  'fire',
#  'ravaged',
#  'former',
#  'portland',
#  'korean',
#  'church',
#  'boy',
#  'intentionally',
#  'shot',
#  'teacher',
#  'school',
#  'police',
#  'say',
#  'dear',
#  'doctor',
#  'platelet',
#  'rich',
#  'plasma',
#  'therapy',
#  'relieve',
#  'arthritis',
#  'related',
#  'back',
#  'pain',
#  'man',
#  'charged',
#  'murder',
#  'fatal',
#  'shooting',
#  'year',
#  'old',
#  'portland',
#  'embassy',
#  'suite',
#  'hotel',
#  'oregon',
#  'men',
#  'basketball',
#  'desperate',
#  'need',
#  'win',
#  'utah',
#  'keep',
#  'postseason',
#  'hope',
#  'alive',
#  'read',
#  'top',
#  'news',
#  'romance',
#  'novelist',
#  'faked',
#  'suicide',
#  'reemerges',
#  'online',
#  'washington',
#  'state',
#  'end',
#  'arizona',
#  'home',
#  'winning',
#  'streak',
#  'oregon',
#  'state',
#  'land',
#  'standout',
#  'wyoming',
#  'defensive',
#  'end',
#  'oluwaseyi',
#  'omotosho',
#  'dear',
#  'doctor',
#  'low',
#  'testosterone',
#  'cause',
#  'loss',
#  'muscle',
#  'bone',
#  'bill',
#  'monroe',
#  'oregon',
#  'state',
#  'police',
#  'fish',
#  'wildlife',
#  'division',
#  'encounter',
#  'stranger',
#  'fiction',
#  'eugene',
#  'based',
#  'author',
#  'cai',
#  'emmons',
#  'wrote',
#  'living',
#  'fatal',
#  'al',
#  'diagnosis',
#  'dy',
#  'teaching',
#  'child',
#  'read',
#  'district',
#  'use',
#  'phonics',
#  'based',
#  'program',
#  'chaotic',
#  'vote',
#  'speaker',
#  'oregon',
#  'republican',
#  'lori',
#  'chavez',
#  'deremer',
#  'happy',
#  'sworn',
#  'portland',
#  'pizzeria',
#  'list',
#  'world',
#  'best',
#  'pizza',
#  'oregon',
#  'state',
#  'beaver',
#  'colorado',
#  'buffalo',
#  'score',
#  'update',
#  'live',
#  'stream',
#  'odds',
#  'tv',
#  'channel',
#  'kevin',
#  'mccarthy',
#  'speakership',
#  'going',
#  'like',
#  'wrestling',
#  'vale',
#  'ava',
#  'collins',
#  'stuns',
#  'nationally',
#  'ranked',
#  'opponent',
#  'idaho',
#  'rollie',
#  'lane',
#  'invitational',
#  'oregon',
#  'state',
#  'beaver',
#  'arizona',
#  'wildcat',
#  'woman',
#  'basketball',
#  'score',
#  'update',
#  'live',
#  'stream',
#  'tv',
#  'channel',
#  'tesla',
#  'crash',
#  'cliff',
#  'shatters',
#  'idyllic',
#  'image',
#  'california',
#  'doctor',
#  'family',
#  'newly',
#  'discovered',
#  'comet',
#  'visible',
#  'night',
#  'sky',
#  'month',
#  'new',
#  'cello',
#  'concerto',
#  'reflects',
#  'climate',
#  'change',
#  'mass',
#  'migration',
#  'colorado',
#  'defense',
#  'silence',
#  'oregon',
#  'state',
#  'beaver',
#  'score',
#  'season',
#  'low',
#  'loss',
#  'want',
#  'get',
#  'rid',
#  'moss',
#  'landscape',
#  'fast',
#  'ask',
#  'extension',
#  'year',
#  'old',
#  'boy',
#  'accused',
#  'critically',
#  'wounding',
#  'another',
#  'year',
#  'old',
#  'portland',
#  'shooting',
#  'state',
#  'volleyball',
#  'oregon',
#  'top',
#  'star',
#  'overtime',
#  'law',
#  'supposed',
#  'help',
#  'california',
#  'farmworkers',
#  'many',
#  'make',
#  'le',
#  'money',
#  'locked',
#  'lawyer',
#  'reality',
#  'defendant',
#  'oregon',
#  'today',
#  'never',
#  'opened',
#  'million',
#  'plus',
#  'biofuels',
#  'refinery',
#  'facing',
#  'foreclosure',
#  'southern',
#  'oregon',
#  'oregon',
#  'duck',
#  'coach',
#  'dan',
#  'lanning',
#  'get',
#  'portrait',
#  'tattoo',
#  'wife',
#  'sauphia',
#  'several',
#  'meaningful',
#  'symbol',
#  'clear',
#  'creek',
#  'distillery',
#  'founder',
#  'dy',
#  'final',
#  'toast',
#  'steve',
#  'mccarthy',
#  'steve',
#  'duin',
#  'column',
#  'dear',
#  'doctor',
#  'medication',
#  'take',
#  'suppressing',
#  'dream',
#  'sleep',
#  'nude',
#  'photo',
#  'sex',
#  'text',
#  'sent',
#  'student',
#  'lead',
#  'vancouver',
#  'teacher',
#  'arrest',
#  'police',
#  'say',
#  'damar',
#  'hamlin',
#  'recovery',
#  'continues',
#  'still',
#  'critical',
#  'condition',
#  'former',
#  'oregon',
#  'duck',
#  'quarterback',
#  'jay',
#  'butterfield',
#  'commits',
#  'transfer',
#  'san',
#  'jose',
#  'state',
#  'year',
#  'old',
#  'caught',
#  'driving',
#  'stolen',
#  'car',
#  'north',
#  'portland',
#  'police',
#  'say',
#  'oregon',
#  'pass',
#  'covid',
#  'related',
#  'death',
#  'pandemic',
#  'basketball',
#  'game',
#  'franklin',
#  'high',
#  'school',
#  'postponed',
#  'parking',
#  'lot',
#  'shooting',
#  'injures',
#  'new',
#  'fast',
#  'spreading',
#  'covid',
#  'variant',
#  'creepy',
#  'nickname',
#  'know',
#  'men',
#  'arrested',
#  'running',
#  'portland',
#  'police',
#  'regional',
#  'news',
#  'page',
#  'endyia',
#  'rogers',
#  'grace',
#  'vanslooten',
#  'send',
#  'oregon',
#  'woman',
#  'basketball',
#  'cruising',
#  'past',
#  'arizona',
#  'state',
#  'jacksonville',
#  'jaguar',
#  'v',
#  'tennessee',
#  'titan',
#  'free',
#  'live',
#  'stream',
#  'odds',
#  'prediction',
#  'time',
#  'tv',
#  'channel',
#  'watch',
#  'nfl',
#  'online',
#  'father',
#  'shot',
#  'member',
#  'family',
#  'facing',
#  'divorce',
#  'odot',
#  'worker',
#  'filched',
#  'state',
#  'get',
#  'year',
#  'prison',
#  'others',
#  'sentenced',
#  'state',
#  'boy',
#  'soccer',
#  'oregon',
#  'top',
#  'star',
#  'footer',
#  'navigation',
#  'recapping',
#  'oregon',
#  'duck',
#  'holiday',
#  'bowl',
#  'win',
#  'coach',
#  'dan',
#  'lanning',
#  'first',
#  'year',
#  'grade',
#  'talkin',
#  'duck',
#  'singer',
#  'woody',
#  'guthrie',
#  'rented',
#  'flat',
#  'lent',
#  'sale',
#  'portland',
#  'legacy',
#  'remains',
#  'liz',
#  'weston',
#  'credit',
#  'card',
#  'require',
#  'pin',
#  'use',
#  'state',
#  'football',
#  'oregon',
#  'top',
#  'star',
#  'rewinding',
#  'oregon',
#  'men',
#  'basketball',
#  'win',
#  'utah',
#  'tacoma',
#  'guaranteed',
#  'income',
#  'program',
#  'show',
#  'much',
#  'help',
#  'faly',
#  'dante',
#  'richardson',
#  'lead',
#  'oregon',
#  'men',
#  'basketball',
#  'upset',
#  'utah',
#  'keep',
#  'postseason',
#  'hope',
#  'alive',
#  'duck',
#  'star',
#  'matter',
#  'georgia',
#  'tcu',
#  'excel',
#  'player',
#  'development',
#  'preservationist',
#  'say',
#  'window',
#  'former',
#  'portland',
#  'korean',
#  'church',
#  'worth',
#  'saving',
#  'povey',
#  'brother',
#  'glass',
#  'gary',
#  'payton',
#  'ii',
#  'probable',
#  'portland',
#  'trail',
#  'blazer',
#  'toronto',
#  'raptor',
#  'game',
#  'preview',
#  'time',
#  'tv',
#  'channel',
#  'watch',
#  'free',
#  'live',
#  'stream',
#  'online',
#  'patrick',
#  'mahomes',
#  'set',
#  'record',
#  'chief',
#  'beat',
#  'raider',
#  'afc',
#  'top',
#  'seed',
#  'saif',
#  'say',
#  'data',
#  'breach',
#  'may',
#  'compromised',
#  'social',
#  'security',
#  'number',
#  'medical',
#  'information',
#  'dear',
#  'doctor',
#  'platelet',
#  'rich',
#  'plasma',
#  'therapy',
#  'relieve',
#  'arthritis',
#  'related',
#  'back',
#  'pain',
#  'oregon',
#  'men',
#  'basketball',
#  'desperate',
#  'need',
#  'win',
#  'utah',
#  'keep',
#  'postseason',
#  'hope',
#  'alive',
#  'read',
#  'top',
#  'news',
#  'washington',
#  'state',
#  'end',
#  'arizona',
#  'home',
#  'winning',
#  'streak',
#  'portland',
#  'pizzeria',
#  'list',
#  'world',
#  'best',
#  'pizza',
#  'kevin',
#  'mccarthy',
#  'speakership',
#  'going',
#  'like',
#  'state',
#  'volleyball',
#  'oregon',
#  'top',
#  'star',
#  'overtime',
#  'law',
#  'supposed',
#  'help',
#  'california',
#  'farmworkers',
#  'many',
#  'make',
#  'le',
#  'money',
#  'oregon',
#  'duck',
#  'coach',
#  'dan',
#  'lanning',
#  'get',
#  'portrait',
#  'tattoo',
#  'wife',
#  'sauphia',
#  'several',
#  'meaningful',
#  'symbol',
#  'clear',
#  'creek',
#  'distillery',
#  'founder',
#  'dy',
#  'final',
#  'toast',
#  'steve',
#  'mccarthy',
#  'steve',
#  'duin',
#  'column',
#  'dear',
#  'doctor',
#  'medication',
#  'take',
#  'suppressing',
#  'dream',
#  'sleep',
#  'endyia',
#  'rogers',
#  'grace',
#  'vanslooten',
#  'send',
#  'oregon',
#  'woman',
#  'basketball',
#  'cruising',
#  'past',
#  'arizona',
#  'state',
#  'jacksonville',
#  'jaguar',
#  'v',
#  'tennessee',
#  'titan',
#  'free',
#  'live',
#  'stream',
#  'odds',
#  'prediction',
#  'time',
#  'tv',
#  'channel',
#  'watch',
#  'nfl',
#  'online',
#  'state',
#  'boy',
#  'soccer',
#  'oregon',
#  'top',
#  'star',
#  'recapping',
#  'oregon',
#  'duck',
#  'holiday',
#  'bowl',
#  'win',
#  'coach',
#  'dan',
#  'lanning',
#  'first',
#  'year',
#  'grade',
#  'talkin',
#  'duck',
#  'beignet',
#  'bummer',
#  'nola',
#  'doughnut',
#  'close',
#  'portland',
#  'area',
#  'location',
#  'arrest',
#  'made',
#  'portland',
#  'house',
#  'party',
#  'shooting',
#  'killed',
#  'jemare',
#  'mann',
#  'damar',
#  'hamlin',
#  'covid',
#  'vaccine',
#  'scientific',
#  'basis',
#  'bogus',
#  'claim',
#  'link',
#  'athlete',
#  'collapsing',
#  'dying',
#  'dear',
#  'annie',
#  'loser',
#  'college',
#  'football',
#  'bet',
#  'may',
#  'experience',
#  'serious',
#  'fallout',
#  'pay',
#  'arizona',
#  'era',
#  'point',
#  'deficit',
#  'final',
#  'three',
#  'minute',
#  'stun',
#  ...]

# %%
filtered_tokens = [i for i in stem_tokens if len(i) > 1]

# %%
tokens = []

tokenizer = RegexpTokenizer(r'\w+')
for i in saved_text:
    tokens.append(tokenizer.tokenize(i))
flat_tokens = [item for sublist in tokens for item in sublist] #flatten list of lists

# %%
from collections import Counter
my_counter = Counter(filtered_tokens)
# my_counter.most_common(25)

word_freq = pd.DataFrame(my_counter.most_common(25),
                             columns=['words', 'count'])
word_freq.head()
# Out:
#         words  count
# 0      oregon     36
# 1    portland     27
# 2       state     23
# 3  basketball     12
# 4        year     12

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# Plot horizontal bar graph
word_freq.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="blue")
ax.set_title("Common Words Found")
plt.show()
