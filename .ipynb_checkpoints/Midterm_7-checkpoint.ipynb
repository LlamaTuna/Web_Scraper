# %%
# Python program to scrape heading tags Jeff Becker 1/2023 V.1
import pickle
from IPython import display
import math
from pprint import pprint
import requests
import nltk
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import random
from wordcloud import WordCloud
import os
import spacy
from textblob import TextBlob
from pattern.en import sentiment
import urllib3 
import re
import datetime
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

nlp = spacy.load('en_core_web_sm')
# %matplotlib inline
sns.set(style='darkgrid', context='talk', palette='Dark2')

headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"} 
#find what headers you are sending here: https://www.whatismybrowser.com/detect/what-http-headers-is-my-browser-sending

input_url = input("Enter the full URL to scrape: ") #user inputs URL to scrape
utc_datetime = datetime.datetime.utcnow() #utc data concatenated with sliced URL name, filename stored
date_string = utc_datetime.strftime("%Y-%m-%d-%H%M_UTC") 
filename = f'{input_url[8:len(date_string)]}_{date_string}'


cleanData = []
tag_words = []
regex = re.compile('[^a-zA-Z]')

def scrape(url_link):
    # create a list by type of heading tags
    # the user will have to determine what "h" tags are valid for given URL
    heading_tags = ["h1","h2","h3","h4"] 
    request = requests.get(url_link, headers = headers)
    Soup = BeautifulSoup(request.text, 'lxml') #create soup obejct

    if request.status_code == 200: #error handling for URL request
        print('Request successful.')
    elif request.status_code == 404:
        print('Error 404: Not Found.')
        
    for tags in Soup.find_all(heading_tags):
        tag_words.append(tags.text.strip())
        
    return tag_words
    
def post_process(scraped_list):   
    for i in scraped_list:  #slice based on data you want to include. Some junk data can be removed
        if len(i) > 16:    #Fliter a composite length of strings based on targeted threshold
            cleanData.append(regex.sub(' ', i)) #remove digits and punctuation

    deDup = list(set(cleanData))#convert to set then back to list to eliminate duplicate headline strings

    with open(filename, "wb") as fp: #Pickling data as list with UTC time stamp
        pickle.dump(deDup, fp)

    # with open(filename,'w') as a: # uncomment if you want to save a text file for manual review
    #     a.write('\n'.join(cleanData))

scraped_content = scrape(input_url) #scrape input URL
post_process(scraped_content) #process scraped tag data
# Out:
# Enter the full URL to scrape: https://www.theguardian.com/us
# Request successful.

# %% [markdown]
# <h3> The variable name "filename" is the stored value of the file. We can either work with that data or load previously scraped data at this point, i.e "foxnews_2023-01-07-2241_UTC". Be aware that pickled files will not display in Jupyter (UTF-8 error). To manually review the text, you have to uncomment the above text file code.<br><br> Once loaded, we slice and print the first five headlines to see if the content is as expected. </h3>

# %%
with open(filename, "rb") as fp: #Either load stored variable value for "filename" or saved pickled "example_1_0_23"
    saved_text = pickle.load(fp)

saved_text[0:5] #confirm your expected text is correct
# Out:
# ['Prince Harry s book could be  beginning of end  for royals  warns Charles s biographer',
#  'Immigration  Biden tells migrants not to  show up at the border  in new policy announcement',
#  'Andrew Tate isn t feminism s inadvertent bastard child  He s sexism s last gasp',
#  'In his own write  Prince Harry s ghostwriter is so famous that George Clooney made a film of his life',
#  ' Vulnerable boys are drawn in   Schools fear spread of Andrew Tate s misogyny']

# %% [markdown]
# <h3> Once we have the right text, we can check the polarity of the scraped headlines.
# <br><br>
# Sentence-level polarity detection is to decide whether a given sentence expresses either an overall positive or negative opinion. The compund score is tehoverall sentiment of the headline. The scale is -1 to 1, with -1 being the most negative and 1 being the most positive. </h3>

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA 

sia = SIA() 
score_data = []

for line in saved_text:
    score = sia.polarity_scores(line)
    score['Headline'] = line
    score_data.append(score)

pprint(score_data, width=100) #pretty print sentiment scores
# Out:
# [{'Headline': 'Prince Harry s book could be  beginning of end  for royals  warns Charles s '
#               'biographer',
#   'compound': -0.1027,
#   'neg': 0.104,
#   'neu': 0.896,
#   'pos': 0.0},
#  {'Headline': 'Immigration  Biden tells migrants not to  show up at the border  in new policy '
#               'announcement',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Andrew Tate isn t feminism s inadvertent bastard child  He s sexism s last gasp',
#   'compound': -0.5423,
#   'neg': 0.259,
#   'neu': 0.741,
#   'pos': 0.0},
#  {'Headline': 'In his own write  Prince Harry s ghostwriter is so famous that George Clooney made '
#               'a film of his life',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': ' Vulnerable boys are drawn in   Schools fear spread of Andrew Tate s misogyny',
#   'compound': -0.6249,
#   'neg': 0.338,
#   'neu': 0.662,
#   'pos': 0.0},
#  {'Headline': 'An art treasure long cherished by Muslims is deemed offensive  But to whom ',
#   'compound': 0.1901,
#   'neg': 0.127,
#   'neu': 0.635,
#   'pos': 0.238},
#  {'Headline': 'Publishing  Man pleads guilty to stealing more than       manuscripts',
#   'compound': -0.7579,
#   'neg': 0.481,
#   'neu': 0.519,
#   'pos': 0.0},
#  {'Headline': 'California  Back to back storms drop deluge of rain and snow with more ahead',
#   'compound': -0.2732,
#   'neg': 0.139,
#   'neu': 0.861,
#   'pos': 0.0},
#  {'Headline': 'Margaret Cho   I was never in doubt that I d do standup ',
#   'compound': 0.2755,
#   'neg': 0.0,
#   'neu': 0.791,
#   'pos': 0.209},
#  {'Headline': ' A search for ourselves   Shipwreck becomes focus of slavery debate',
#   'compound': -0.7003,
#   'neg': 0.375,
#   'neu': 0.625,
#   'pos': 0.0},
#  {'Headline': 'Skiing  Shiffrin ties Vonn s World Cup record with   nd career win',
#   'compound': 0.5859,
#   'neg': 0.0,
#   'neu': 0.725,
#   'pos': 0.275},
#  {'Headline': 'Environment  Biden administration seeks to limit deadly air pollution',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': ' It s going to be dirty   Republicans gear up for attack on Hunter Biden',
#   'compound': -0.7184,
#   'neg': 0.353,
#   'neu': 0.647,
#   'pos': 0.0},
#  {'Headline': 'Paul Mescal  Normal People actor set to star in Ridley Scott s Gladiator sequel',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'US Mexico  Biden visits border for first time as critics condemn his migrant '
#               'crackdown',
#   'compound': -0.5859,
#   'neg': 0.286,
#   'neu': 0.714,
#   'pos': 0.0},
#  {'Headline': 'Pope Benedict XVI  Time lapse shows thousands of people gathering to attend funeral',
#   'compound': -0.3612,
#   'neg': 0.172,
#   'neu': 0.828,
#   'pos': 0.0},
#  {'Headline': 'Europe  Record high temperatures leave Alps without snow',
#   'compound': -0.0516,
#   'neg': 0.146,
#   'neu': 0.854,
#   'pos': 0.0},
#  {'Headline': 'Nigel Slater s recipes  Breakfast muffins  and kipper cakes with dill sauce',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Blind date   I fired half a baklava across the table  but I think I styled it out ',
#   'compound': -0.4854,
#   'neg': 0.274,
#   'neu': 0.726,
#   'pos': 0.0},
#  {'Headline': ' It altered my entire worldview   Leading authors pick eight nonfiction books to '
#               'change your mind',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Jair Bolsonaro supporters storm Brazil s presidential palace and supreme court',
#   'compound': 0.7579,
#   'neg': 0.0,
#   'neu': 0.552,
#   'pos': 0.448},
#  {'Headline': 'Man City     Chelsea  Mahrez stunner sparks FA Cup cruise against pitiful Blues',
#   'compound': -0.4939,
#   'neg': 0.225,
#   'neu': 0.775,
#   'pos': 0.0},
#  {'Headline': 'Documentary thrasher', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': ' This is no way to live   Mississippians struggle with another water crisis',
#   'compound': -0.8225,
#   'neg': 0.489,
#   'neu': 0.511,
#   'pos': 0.0},
#  {'Headline': ' It s my Mousetrap   Michael Frayn on Noises Off  a farce to be reckoned with',
#   'compound': -0.4019,
#   'neg': 0.184,
#   'neu': 0.816,
#   'pos': 0.0},
#  {'Headline': 'Harry  The Interview review  So horribly sad it could have turned the Queen anti '
#               'monarchy',
#   'compound': -0.8545,
#   'neg': 0.439,
#   'neu': 0.561,
#   'pos': 0.0},
#  {'Headline': 'ADHD  What does the Adderall shortage in the US mean for ADHD patients ',
#   'compound': -0.25,
#   'neg': 0.143,
#   'neu': 0.857,
#   'pos': 0.0},
#  {'Headline': ' No rational reason   Zelenskiy criticises west sending armoured vehicles instead '
#               'of tanks',
#   'compound': -0.5423,
#   'neg': 0.31,
#   'neu': 0.69,
#   'pos': 0.0},
#  {'Headline': 'Immigration Biden s  carrot and stick  approach met with anger',
#   'compound': -0.5719,
#   'neg': 0.316,
#   'neu': 0.684,
#   'pos': 0.0},
#  {'Headline': 'Cellphones  cameras  DNA  How police caught Idaho student killings suspect',
#   'compound': -0.7717,
#   'neg': 0.456,
#   'neu': 0.544,
#   'pos': 0.0},
#  {'Headline': 'Wordiply thrasher', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Sri Lanka  Hedge funds holding up vital debt relief for crisis hit country  warn '
#               'economists',
#   'compound': -0.4019,
#   'neg': 0.343,
#   'neu': 0.429,
#   'pos': 0.227},
#  {'Headline': 'First Thing email newsletter', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': ' Feeling betrayed   The reaction in George Santos s district to brazen lies',
#   'compound': -0.743,
#   'neg': 0.417,
#   'neu': 0.491,
#   'pos': 0.092},
#  {'Headline': 'Across the country', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'Naomi Osaka  Concerns mount as former No   withdraws from Australian Open',
#   'compound': -0.296,
#   'neg': 0.18,
#   'neu': 0.82,
#   'pos': 0.0},
#  {'Headline': 'X marks the spot  Newly released map sparks hunt for    m Nazi hoard',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Live      arrested in Bras lia as Lula condemns  barbarism  after storming of '
#               'presidential palace and supreme court   live',
#   'compound': -0.4215,
#   'neg': 0.256,
#   'neu': 0.6,
#   'pos': 0.144},
#  {'Headline': 'Rising MMA star Victoria  The Prodigy  Lee dies at age of   ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Mexico City  At least one dead and    injured in collision on metro',
#   'compound': -0.8591,
#   'neg': 0.514,
#   'neu': 0.486,
#   'pos': 0.0},
#  {'Headline': 'Brutalised  broken  mended  Inside Ukraine s rehabilitation centre for wounded '
#               'veterans',
#   'compound': -0.7906,
#   'neg': 0.467,
#   'neu': 0.533,
#   'pos': 0.0},
#  {'Headline': 'Ana Bel n Montes  US releases top Cuba spy after    years in prison',
#   'compound': -0.3612,
#   'neg': 0.219,
#   'neu': 0.662,
#   'pos': 0.119},
#  {'Headline': ' Touched by the welcome   Messi given guard of honour on PSG return',
#   'compound': 0.7717,
#   'neg': 0.0,
#   'neu': 0.599,
#   'pos': 0.401},
#  {'Headline': 'Ukraine and Pope Benedict s funeral  The week around the world in    pictures',
#   'compound': -0.3612,
#   'neg': 0.185,
#   'neu': 0.815,
#   'pos': 0.0},
#  {'Headline': 'Russell Banks  Award winning fiction writer dies at   ',
#   'compound': 0.7845,
#   'neg': 0.0,
#   'neu': 0.465,
#   'pos': 0.535},
#  {'Headline': 'New Mexico  Police investigate shootings at officials  homes and offices',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Search for Texas vigilante who fatally shot robbery suspect carrying fake gun',
#   'compound': -0.8979,
#   'neg': 0.598,
#   'neu': 0.402,
#   'pos': 0.0},
#  {'Headline': 'Iran  Regime condemned for executing two men over alleged protest crimes',
#   'compound': -0.5994,
#   'neg': 0.353,
#   'neu': 0.647,
#   'pos': 0.0},
#  {'Headline': ' I own multiple vacuum cleaners   he litters indoors   What happened when four '
#               'writers swapped chores with their partners ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'NFL  Trainer who rushed to Damar Hamlin s aid lauded as  real hero ',
#   'compound': 0.5574,
#   'neg': 0.0,
#   'neu': 0.753,
#   'pos': 0.247},
#  {'Headline': 'At a glance What we know on day     of the invasion',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Prince Harry  Prince Harry defends tell all memoir in furious ITV interview',
#   'compound': -0.5719,
#   'neg': 0.252,
#   'neu': 0.748,
#   'pos': 0.0},
#  {'Headline': 'Monkeys  Revealed  US allowing long tailed macaque imports despite risk of disease',
#   'compound': 0.2057,
#   'neg': 0.0,
#   'neu': 0.858,
#   'pos': 0.142},
#  {'Headline': 'Cellphones  cameras  DNA  how police caught Idaho student killings suspect',
#   'compound': -0.7717,
#   'neg': 0.456,
#   'neu': 0.544,
#   'pos': 0.0},
#  {'Headline': 'House speaker McCarthy clinches gavel at   th attempt',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Sculpture  Balloon animals beyond the poodle',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'NFL  Dolphins pip Pats and Steelers to playoff spot as Bills honor Hamlin',
#   'compound': 0.4939,
#   'neg': 0.0,
#   'neu': 0.789,
#   'pos': 0.211},
#  {'Headline': 'Boxing  Davis stops Garcia in eight to retain WBA lightweight title',
#   'compound': -0.1531,
#   'neg': 0.138,
#   'neu': 0.862,
#   'pos': 0.0},
#  {'Headline': 'News  sport and opinion from the Guardian s US edition',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Putin  President attends Orthodox Christmas service alone',
#   'compound': -0.25,
#   'neg': 0.25,
#   'neu': 0.75,
#   'pos': 0.0},
#  {'Headline': 'Myanmar  On the frontline with the rebel army fighting brutal junta',
#   'compound': -0.802,
#   'neg': 0.506,
#   'neu': 0.494,
#   'pos': 0.0},
#  {'Headline': 'Virginia shooting of teacher by six year old  not accidental   authorities say',
#   'compound': 0.0572,
#   'neg': 0.0,
#   'neu': 0.9,
#   'pos': 0.1},
#  {'Headline': 'If Harry sounds callous about killing  he is  All of us who served were   at least '
#               'he knows why',
#   'compound': -0.6597,
#   'neg': 0.196,
#   'neu': 0.804,
#   'pos': 0.0},
#  {'Headline': ' You re my hero   How Zelenskiy became Hollywood s man of the hour',
#   'compound': 0.5574,
#   'neg': 0.0,
#   'neu': 0.753,
#   'pos': 0.247},
#  {'Headline': 'The Shards by Bret Easton Ellis review  An inspired fever dream of a book',
#   'compound': 0.6369,
#   'neg': 0.0,
#   'neu': 0.679,
#   'pos': 0.321},
#  {'Headline': 'Minsk  Russia and Belarus extend military drills amid fears of new push into '
#               'Ukraine',
#   'compound': -0.2732,
#   'neg': 0.17,
#   'neu': 0.727,
#   'pos': 0.103},
#  {'Headline': 'Brazil Bolsonaro supporters storm presidential palace',
#   'compound': 0.4404,
#   'neg': 0.0,
#   'neu': 0.633,
#   'pos': 0.367},
#  {'Headline': 'Tesla  Musk seeks to move trial out of San Francisco  claiming he can t get fair '
#               'trial',
#   'compound': 0.3182,
#   'neg': 0.0,
#   'neu': 0.867,
#   'pos': 0.133},
#  {'Headline': 'Live      arrested in Bras lia as Lula condemns  barbarism  after storming of '
#               'Brazil s political buildings',
#   'compound': -0.7506,
#   'neg': 0.33,
#   'neu': 0.67,
#   'pos': 0.0},
#  {'Headline': ' Love is overwhelming   Recovering Hamlin posts update on social media',
#   'compound': 0.6369,
#   'neg': 0.0,
#   'neu': 0.682,
#   'pos': 0.318},
#  {'Headline': 'Italo Calvino  The Written World and the Unwritten World review   a box of delights',
#   'compound': 0.4588,
#   'neg': 0.0,
#   'neu': 0.8,
#   'pos': 0.2},
#  {'Headline': 'Chicago  New report details sexual misconduct allegations in public school system',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Virginia Shooting a red flag for US  says mayor',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Victoria Lee  Rising MMA star dies at age of   ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'US politics  McCarthy takes vote losses to six as US House of Representatives '
#               'adjourns again',
#   'compound': -0.4019,
#   'neg': 0.162,
#   'neu': 0.838,
#   'pos': 0.0},
#  {'Headline': 'Racism rebranded  How far right ideology feeds off identity politics',
#   'compound': -0.6249,
#   'neg': 0.313,
#   'neu': 0.687,
#   'pos': 0.0},
#  {'Headline': 'US coronavirus data', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'Headline': 'H bombs or chicken bones  The race to define the start of the Anthropocene',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': ' It s going to be dirty  Republicans gear up to attack Hunter Biden',
#   'compound': -0.7184,
#   'neg': 0.375,
#   'neu': 0.625,
#   'pos': 0.0},
#  {'Headline': 'A new start after     I became a naturist at      and it felt like freedom',
#   'compound': 0.7717,
#   'neg': 0.0,
#   'neu': 0.573,
#   'pos': 0.427},
#  {'Headline': 'Young people don t hate their bodies because they are weak   but because capitalism '
#               'demands it',
#   'compound': -0.5106,
#   'neg': 0.249,
#   'neu': 0.751,
#   'pos': 0.0},
#  {'Headline': 'Texas  Search for vigilante who fatally shot robbery suspect carrying fake gun',
#   'compound': -0.8979,
#   'neg': 0.598,
#   'neu': 0.402,
#   'pos': 0.0},
#  {'Headline': 'Virginia  Shooting of teacher by six year old  not accidental   authorities say',
#   'compound': 0.0572,
#   'neg': 0.0,
#   'neu': 0.9,
#   'pos': 0.1},
#  {'Headline': ' A landmark step   How pioneering foetal surgery is transforming lives',
#   'compound': 0.0516,
#   'neg': 0.117,
#   'neu': 0.745,
#   'pos': 0.138},
#  {'Headline': 'Louisiana  Ex police deputy given     year sentence for sex crimes',
#   'compound': 0.0772,
#   'neg': 0.0,
#   'neu': 0.874,
#   'pos': 0.126},
#  {'Headline': 'Einstein  Piaf  Twiggy  Marilyn Stafford s extraordinary life behind the lens',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Alex Jones   Lawyer s license is suspended for releasing sensitive records',
#   'compound': -0.4767,
#   'neg': 0.256,
#   'neu': 0.744,
#   'pos': 0.0},
#  {'Headline': 'Germany  Police arrest Iranian man suspected of planning chemical attack',
#   'compound': -0.7506,
#   'neg': 0.514,
#   'neu': 0.486,
#   'pos': 0.0},
#  {'Headline': 'Books  Meet the    best new novelists for     ',
#   'compound': 0.6369,
#   'neg': 0.0,
#   'neu': 0.588,
#   'pos': 0.412},
#  {'Headline': 'Under the  we pay  you entertain  deal  Harry is now the hardest working royal',
#   'compound': 0.2263,
#   'neg': 0.089,
#   'neu': 0.764,
#   'pos': 0.146},
#  {'Headline': 'Palette styles new do not delete',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'The writing s on the wall for the paper check   but I m still going to miss it',
#   'compound': -0.2263,
#   'neg': 0.119,
#   'neu': 0.881,
#   'pos': 0.0},
#  {'Headline': ' Disability is not a tragedy   The remarkable life of activist and rebel Hale Zukas',
#   'compound': -0.0021,
#   'neg': 0.251,
#   'neu': 0.554,
#   'pos': 0.195},
#  {'Headline': ' Profoundly troubling   Harvard Kennedy School condemned for denying fellowship to '
#               'Israel critic',
#   'compound': -0.872,
#   'neg': 0.577,
#   'neu': 0.423,
#   'pos': 0.0},
#  {'Headline': ' One more embarrassment   McCarthy debacle wearily received in California home town',
#   'compound': -0.4927,
#   'neg': 0.242,
#   'neu': 0.758,
#   'pos': 0.0},
#  {'Headline': 'China  Borders reopen as lunar new year travel kicks off amid Covid surge',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Who wants to live for ever  Only billionaires like Jeff Bezos',
#   'compound': 0.3612,
#   'neg': 0.0,
#   'neu': 0.8,
#   'pos': 0.2},
#  {'Headline': 'In brief  A Writer s Diary  The Race Against Time  Price Wars   reviews',
#   'compound': -0.5574,
#   'neg': 0.265,
#   'neu': 0.735,
#   'pos': 0.0},
#  {'Headline': 'Play the Guardian s new daily word game and share your score with your friends',
#   'compound': 0.7717,
#   'neg': 0.0,
#   'neu': 0.588,
#   'pos': 0.412},
#  {'Headline': 'Israel  Palestinian foreign minister says travel permit has been revoked',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'California  Thousands without power as state braces for next onslaught of storms',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'A day at the beach   Quicksand had never felt real as a concept until this moment ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'Travel     of the best secret retreats in the Canary Islands',
#   'compound': 0.6369,
#   'neg': 0.0,
#   'neu': 0.682,
#   'pos': 0.318},
#  {'Headline': 'Alcarr s director Carla Sim n   I have feelings for Spanish culture and Catalan '
#               'culture ',
#   'compound': 0.0,
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'Headline': 'The US should break up monopolies   not punish working Americans for rising prices',
#   'compound': 0.4168,
#   'neg': 0.0,
#   'neu': 0.812,
#   'pos': 0.188},
#  {'Headline': 'The weekend s best photos  Delhi Pride and Peru protests',
#   'compound': 0.6908,
#   'neg': 0.131,
#   'neu': 0.414,
#   'pos': 0.455},
#  {'Headline': ' A fearless preacher   Pope Francis leads Catholics at Benedict s funeral',
#   'compound': 0.1027,
#   'neg': 0.202,
#   'neu': 0.565,
#   'pos': 0.234},
#  {'Headline': 'Abortion  The US government just took two big steps  Will they matter ',
#   'compound': 0.0258,
#   'neg': 0.0,
#   'neu': 0.909,
#   'pos': 0.091},
#  {'Headline': 'Water  Fears US supreme court could radically reshape clean water rules',
#   'compound': 0.5423,
#   'neg': 0.164,
#   'neu': 0.468,
#   'pos': 0.368},
#  {'Headline': 'Louisiana   Officer arrested after car crash kills two innocent teenagers during '
#               'police chase',
#   'compound': -0.7845,
#   'neg': 0.449,
#   'neu': 0.435,
#   'pos': 0.116},
#  {'Headline': 'Kevin McCarthy   After chaotic week  speaker faces next battle as House votes on '
#               'rules package',
#   'compound': -0.7003,
#   'neg': 0.309,
#   'neu': 0.691,
#   'pos': 0.0},
#  {'Headline': 'Seattle  Public schools sue social media platforms for youth  mental health crisis ',
#   'compound': -0.6249,
#   'neg': 0.272,
#   'neu': 0.728,
#   'pos': 0.0},
#  {'Headline': 'Ask Philippa  I hate my ageing body  Why do I look at myself with disgust ',
#   'compound': -0.8225,
#   'neg': 0.409,
#   'neu': 0.591,
#   'pos': 0.0},
#  {'Headline': 'Rohingya  Refugees bet lives on boat crossings despite rising death toll',
#   'compound': 0.4847,
#   'neg': 0.0,
#   'neu': 0.761,
#   'pos': 0.239},
#  {'Headline': 'Aston Villa     Stevenage  Campbell s late stunner causes FA Cup upset',
#   'compound': -0.3818,
#   'neg': 0.224,
#   'neu': 0.776,
#   'pos': 0.0},
#  {'Headline': 'Contact the Guardian', 'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}]

# %% [markdown]
# <h3>Now we can create Pandas data frame to visualize some of the headlines and scores.</h3>

# %%
df = pd.DataFrame.from_records(score_data)
df
# Out:
#        neg    neu    pos  compound  \
# 0    0.104  0.896  0.000   -0.1027
# 1    0.000  1.000  0.000    0.0000
# 2    0.259  0.741  0.000   -0.5423
# 3    0.000  1.000  0.000    0.0000
# 4    0.338  0.662  0.000   -0.6249
# ..     ...    ...    ...       ...
# 111  0.272  0.728  0.000   -0.6249
# 112  0.409  0.591  0.000   -0.8225
# 113  0.000  0.761  0.239    0.4847
# 114  0.224  0.776  0.000   -0.3818
# 115  0.000  1.000  0.000    0.0000
#
#                                               Headline
# 0    Prince Harry s book could be  beginning of end...
# 1    Immigration  Biden tells migrants not to  show...
# 2    Andrew Tate isn t feminism s inadvertent basta...
# 3    In his own write  Prince Harry s ghostwriter i...
# 4     Vulnerable boys are drawn in   Schools fear s...
# ..                                                 ...
# 111  Seattle  Public schools sue social media platf...
# 112  Ask Philippa  I hate my ageing body  Why do I ...
# 113  Rohingya  Refugees bet lives on boat crossings...
# 114  Aston Villa     Stevenage  Campbell s late stu...
# 115                               Contact the Guardian
#
# [116 rows x 5 columns]

# %%
df['label'] = 0
df.loc[df['compound'] > 0.2, 'label'] = 1
df.loc[df['compound'] < -0.2, 'label'] = -1
df
# Out:
#        neg    neu    pos  compound  \
# 0    0.104  0.896  0.000   -0.1027
# 1    0.000  1.000  0.000    0.0000
# 2    0.259  0.741  0.000   -0.5423
# 3    0.000  1.000  0.000    0.0000
# 4    0.338  0.662  0.000   -0.6249
# ..     ...    ...    ...       ...
# 111  0.272  0.728  0.000   -0.6249
# 112  0.409  0.591  0.000   -0.8225
# 113  0.000  0.761  0.239    0.4847
# 114  0.224  0.776  0.000   -0.3818
# 115  0.000  1.000  0.000    0.0000
#
#                                               Headline  label
# 0    Prince Harry s book could be  beginning of end...      0
# 1    Immigration  Biden tells migrants not to  show...      0
# 2    Andrew Tate isn t feminism s inadvertent basta...     -1
# 3    In his own write  Prince Harry s ghostwriter i...      0
# 4     Vulnerable boys are drawn in   Schools fear s...     -1
# ..                                                 ...    ...
# 111  Seattle  Public schools sue social media platf...     -1
# 112  Ask Philippa  I hate my ageing body  Why do I ...     -1
# 113  Rohingya  Refugees bet lives on boat crossings...      1
# 114  Aston Villa     Stevenage  Campbell s late stu...     -1
# 115                               Contact the Guardian      0
#
# [116 rows x 6 columns]

# %%
df2 = df[['Headline', 'label']] #save CSV of data with labels for future processing
df2.to_csv(filename +'.csv', mode='a', encoding='utf-8', index=False)

# %%
print("Positive headlines:\n") #print a sample of categorized headlines
pprint(list(df[df['label'] == 1].Headline)[:10], width=200)

print("\nNegative headlines:\n")
pprint(list(df[df['label'] == -1].Headline)[:10], width=200)
# Out:
# Positive headlines:
#
# ['Margaret Cho   I was never in doubt that I d do standup ',
#  'Skiing  Shiffrin ties Vonn s World Cup record with   nd career win',
#  'Jair Bolsonaro supporters storm Brazil s presidential palace and supreme court',
#  ' Touched by the welcome   Messi given guard of honour on PSG return',
#  'Russell Banks  Award winning fiction writer dies at   ',
#  'NFL  Trainer who rushed to Damar Hamlin s aid lauded as  real hero ',
#  'Monkeys  Revealed  US allowing long tailed macaque imports despite risk of disease',
#  'NFL  Dolphins pip Pats and Steelers to playoff spot as Bills honor Hamlin',
#  ' You re my hero   How Zelenskiy became Hollywood s man of the hour',
#  'The Shards by Bret Easton Ellis review  An inspired fever dream of a book']
#
# Negative headlines:
#
# ['Andrew Tate isn t feminism s inadvertent bastard child  He s sexism s last gasp',
#  ' Vulnerable boys are drawn in   Schools fear spread of Andrew Tate s misogyny',
#  'Publishing  Man pleads guilty to stealing more than       manuscripts',
#  'California  Back to back storms drop deluge of rain and snow with more ahead',
#  ' A search for ourselves   Shipwreck becomes focus of slavery debate',
#  ' It s going to be dirty   Republicans gear up for attack on Hunter Biden',
#  'US Mexico  Biden visits border for first time as critics condemn his migrant crackdown',
#  'Pope Benedict XVI  Time lapse shows thousands of people gathering to attend funeral',
#  'Blind date   I fired half a baklava across the table  but I think I styled it out ',
#  'Man City     Chelsea  Mahrez stunner sparks FA Cup cruise against pitiful Blues']

# %%
print(df.label.value_counts())

print(df.label.value_counts(normalize=True) * 100) #normalize data
# Out:
# -1    50
#  0    42
#  1    24
# Name: label, dtype: int64
# -1    43.103448
#  0    36.206897
#  1    20.689655
# Name: label, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 8)) #create a bar graph of sentiment distributions

counts = df.label.value_counts(normalize=True) * 100

sns.barplot(x=counts.index, y=counts, ax=ax)

ax.set_xticklabels(['Negative', 'Neutral', 'Positive'])
ax.set_ylabel("Percentage")

plt.show()

# %%
textblob_sentiment=[]
for s in saved_text:
    txt= TextBlob(s)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([s,a,b])

# %%
df_textblob = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_textblob
# Out:
#                                               Sentence  Polarity  Subjectivity
# 0    Prince Harry s book could be  beginning of end...  0.000000      0.000000
# 1    Immigration  Biden tells migrants not to  show...  0.136364      0.454545
# 2    Andrew Tate isn t feminism s inadvertent basta...  0.000000      0.066667
# 3    In his own write  Prince Harry s ghostwriter i...  0.550000      1.000000
# 4     Vulnerable boys are drawn in   Schools fear s... -0.500000      0.500000
# ..                                                 ...       ...           ...
# 111  Seattle  Public schools sue social media platf... -0.022222      0.111111
# 112  Ask Philippa  I hate my ageing body  Why do I ... -0.800000      0.900000
# 113  Rohingya  Refugees bet lives on boat crossings...  0.000000      0.000000
# 114  Aston Villa     Stevenage  Campbell s late stu... -0.300000      0.600000
# 115                               Contact the Guardian  0.000000      0.000000
#
# [116 rows x 3 columns]

# %%
df_textblob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      116 non-null    object
#  1   Polarity      116 non-null    float64
#  2   Subjectivity  116 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 2.8+ KB

# %%
sns.displot(df_textblob["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Textblob)")
# Out:
# Text(0.5, 15.439999999999998, 'Sentence Polarity (Textblob)')

# %%
sns.displot(df_textblob["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Textblob)")
# Out:
# Text(0.5, 15.439999999999998, 'Sentence Subjectivity (Textblob)')

# %%
pos_lines = list(df[df.label == 1].Headline)

pos_tokens = process_text(pos_lines)
pos_freq = nltk.FreqDist(pos_tokens)

pos_freq.most_common(20)
# Out:
# [('us', 16),
#  ('new', 13),
#  ('harry', 8),
#  ('police', 8),
#  ('world', 7),
#  ('live', 6),
#  ('rising', 6),
#  ('hamlin', 6),
#  ('best', 6),
#  ('biden', 5),
#  ('man', 5),
#  ('mccarthy', 5),
#  ('water', 5),
#  ('review', 5),
#  ('prince', 4),
#  ('could', 4),
#  ('cup', 4),
#  ('house', 4),
#  ('rules', 4),
#  ('bolsonaro', 4)]

# %%
y_val = [x[1] for x in pos_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Positive Word Frequency Distribution")
plt.show()

# %%
y_final = []
for i, k, z, t in zip(y_val[0::4], y_val[1::4], y_val[2::4], y_val[3::4]):
    y_final.append(math.log(i + k + z + t))

x_val = [math.log(i + 1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Positive Word Frequency Distribution")
plt.plot(x_val, y_final)
plt.show()

# %%
neg_lines = list(df2[df2.label == -1].Headline)

neg_tokens = process_text(neg_lines)
neg_freq = nltk.FreqDist(neg_tokens)

neg_freq.most_common(20)
# Out:
# [('us', 22),
#  ('new', 14),
#  ('harry', 12),
#  ('police', 12),
#  ('live', 10),
#  ('biden', 9),
#  ('man', 8),
#  ('world', 8),
#  ('mccarthy', 8),
#  ('suspect', 8),
#  ('prince', 6),
#  ('search', 6),
#  ('cup', 6),
#  ('time', 6),
#  ('house', 6),
#  ('water', 6),
#  ('crisis', 6),
#  ('review', 6),
#  ('rising', 6),
#  ('ukraine', 6)]

# %%
y_val = [x[1] for x in neg_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Negative Word Frequency Distribution")
plt.show()

# %%
y_final = []
for i, k, z in zip(y_val[0::3], y_val[1::3], y_val[2::3]):
    if i + k + z == 0:
        break
    y_final.append(math.log(i + k + z))

x_val = [math.log(i+1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Negative Word Frequency Distribution Negative")
plt.plot(x_val, y_final)
plt.show()

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer #tokenize and remove stop words from corpus
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

stop_tokens = []

def process_text(headlines):
    for line in headlines:
        toks = word_tokenize(line)
        toks = [t.lower() for t in toks if t.lower() not in stop_words]
        stop_tokens.extend(toks)
    
    return stop_tokens

process_text(saved_text)
# Out:
# ['prince',
#  'harry',
#  'book',
#  'could',
#  'beginning',
#  'end',
#  'royals',
#  'warns',
#  'charles',
#  'biographer',
#  'immigration',
#  'biden',
#  'tells',
#  'migrants',
#  'show',
#  'border',
#  'new',
#  'policy',
#  'announcement',
#  'andrew',
#  'tate',
#  'feminism',
#  'inadvertent',
#  'bastard',
#  'child',
#  'sexism',
#  'last',
#  'gasp',
#  'write',
#  'prince',
#  'harry',
#  'ghostwriter',
#  'famous',
#  'george',
#  'clooney',
#  'made',
#  'film',
#  'life',
#  'vulnerable',
#  'boys',
#  'drawn',
#  'schools',
#  'fear',
#  'spread',
#  'andrew',
#  'tate',
#  'misogyny',
#  'art',
#  'treasure',
#  'long',
#  'cherished',
#  'muslims',
#  'deemed',
#  'offensive',
#  'publishing',
#  'man',
#  'pleads',
#  'guilty',
#  'stealing',
#  'manuscripts',
#  'california',
#  'back',
#  'back',
#  'storms',
#  'drop',
#  'deluge',
#  'rain',
#  'snow',
#  'ahead',
#  'margaret',
#  'cho',
#  'never',
#  'doubt',
#  'standup',
#  'search',
#  'shipwreck',
#  'becomes',
#  'focus',
#  'slavery',
#  'debate',
#  'skiing',
#  'shiffrin',
#  'ties',
#  'vonn',
#  'world',
#  'cup',
#  'record',
#  'nd',
#  'career',
#  'win',
#  'environment',
#  'biden',
#  'administration',
#  'seeks',
#  'limit',
#  'deadly',
#  'air',
#  'pollution',
#  'going',
#  'dirty',
#  'republicans',
#  'gear',
#  'attack',
#  'hunter',
#  'biden',
#  'paul',
#  'mescal',
#  'normal',
#  'people',
#  'actor',
#  'set',
#  'star',
#  'ridley',
#  'scott',
#  'gladiator',
#  'sequel',
#  'us',
#  'mexico',
#  'biden',
#  'visits',
#  'border',
#  'first',
#  'time',
#  'critics',
#  'condemn',
#  'migrant',
#  'crackdown',
#  'pope',
#  'benedict',
#  'xvi',
#  'time',
#  'lapse',
#  'shows',
#  'thousands',
#  'people',
#  'gathering',
#  'attend',
#  'funeral',
#  'europe',
#  'record',
#  'high',
#  'temperatures',
#  'leave',
#  'alps',
#  'without',
#  'snow',
#  'nigel',
#  'slater',
#  'recipes',
#  'breakfast',
#  'muffins',
#  'kipper',
#  'cakes',
#  'dill',
#  'sauce',
#  'blind',
#  'date',
#  'fired',
#  'half',
#  'baklava',
#  'across',
#  'table',
#  'think',
#  'styled',
#  'altered',
#  'entire',
#  'worldview',
#  'leading',
#  'authors',
#  'pick',
#  'eight',
#  'nonfiction',
#  'books',
#  'change',
#  'mind',
#  'jair',
#  'bolsonaro',
#  'supporters',
#  'storm',
#  'brazil',
#  'presidential',
#  'palace',
#  'supreme',
#  'court',
#  'man',
#  'city',
#  'chelsea',
#  'mahrez',
#  'stunner',
#  'sparks',
#  'fa',
#  'cup',
#  'cruise',
#  'pitiful',
#  'blues',
#  'documentary',
#  'thrasher',
#  'way',
#  'live',
#  'mississippians',
#  'struggle',
#  'another',
#  'water',
#  'crisis',
#  'mousetrap',
#  'michael',
#  'frayn',
#  'noises',
#  'farce',
#  'reckoned',
#  'harry',
#  'interview',
#  'review',
#  'horribly',
#  'sad',
#  'could',
#  'turned',
#  'queen',
#  'anti',
#  'monarchy',
#  'adhd',
#  'adderall',
#  'shortage',
#  'us',
#  'mean',
#  'adhd',
#  'patients',
#  'rational',
#  'reason',
#  'zelenskiy',
#  'criticises',
#  'west',
#  'sending',
#  'armoured',
#  'vehicles',
#  'instead',
#  'tanks',
#  'immigration',
#  'biden',
#  'carrot',
#  'stick',
#  'approach',
#  'met',
#  'anger',
#  'cellphones',
#  'cameras',
#  'dna',
#  'police',
#  'caught',
#  'idaho',
#  'student',
#  'killings',
#  'suspect',
#  'wordiply',
#  'thrasher',
#  'sri',
#  'lanka',
#  'hedge',
#  'funds',
#  'holding',
#  'vital',
#  'debt',
#  'relief',
#  'crisis',
#  'hit',
#  'country',
#  'warn',
#  'economists',
#  'first',
#  'thing',
#  'email',
#  'newsletter',
#  'feeling',
#  'betrayed',
#  'reaction',
#  'george',
#  'santos',
#  'district',
#  'brazen',
#  'lies',
#  'across',
#  'country',
#  'naomi',
#  'osaka',
#  'concerns',
#  'mount',
#  'former',
#  'withdraws',
#  'australian',
#  'open',
#  'x',
#  'marks',
#  'spot',
#  'newly',
#  'released',
#  'map',
#  'sparks',
#  'hunt',
#  'nazi',
#  'hoard',
#  'live',
#  'arrested',
#  'bras',
#  'lia',
#  'lula',
#  'condemns',
#  'barbarism',
#  'storming',
#  'presidential',
#  'palace',
#  'supreme',
#  'court',
#  'live',
#  'rising',
#  'mma',
#  'star',
#  'victoria',
#  'prodigy',
#  'lee',
#  'dies',
#  'age',
#  'mexico',
#  'city',
#  'least',
#  'one',
#  'dead',
#  'injured',
#  'collision',
#  'metro',
#  'brutalised',
#  'broken',
#  'mended',
#  'inside',
#  'ukraine',
#  'rehabilitation',
#  'centre',
#  'wounded',
#  'veterans',
#  'ana',
#  'bel',
#  'n',
#  'montes',
#  'us',
#  'releases',
#  'top',
#  'cuba',
#  'spy',
#  'years',
#  'prison',
#  'touched',
#  'welcome',
#  'messi',
#  'given',
#  'guard',
#  'honour',
#  'psg',
#  'return',
#  'ukraine',
#  'pope',
#  'benedict',
#  'funeral',
#  'week',
#  'around',
#  'world',
#  'pictures',
#  'russell',
#  'banks',
#  'award',
#  'winning',
#  'fiction',
#  'writer',
#  'dies',
#  'new',
#  'mexico',
#  'police',
#  'investigate',
#  'shootings',
#  'officials',
#  'homes',
#  'offices',
#  'search',
#  'texas',
#  'vigilante',
#  'fatally',
#  'shot',
#  'robbery',
#  'suspect',
#  'carrying',
#  'fake',
#  'gun',
#  'iran',
#  'regime',
#  'condemned',
#  'executing',
#  'two',
#  'men',
#  'alleged',
#  'protest',
#  'crimes',
#  'multiple',
#  'vacuum',
#  'cleaners',
#  'litters',
#  'indoors',
#  'happened',
#  'four',
#  'writers',
#  'swapped',
#  'chores',
#  'partners',
#  'nfl',
#  'trainer',
#  'rushed',
#  'damar',
#  'hamlin',
#  'aid',
#  'lauded',
#  'real',
#  'hero',
#  'glance',
#  'know',
#  'day',
#  'invasion',
#  'prince',
#  'harry',
#  'prince',
#  'harry',
#  'defends',
#  'tell',
#  'memoir',
#  'furious',
#  'itv',
#  'interview',
#  'monkeys',
#  'revealed',
#  'us',
#  'allowing',
#  'long',
#  'tailed',
#  'macaque',
#  'imports',
#  'despite',
#  'risk',
#  'disease',
#  'cellphones',
#  'cameras',
#  'dna',
#  'police',
#  'caught',
#  'idaho',
#  'student',
#  'killings',
#  'suspect',
#  'house',
#  'speaker',
#  'mccarthy',
#  'clinches',
#  'gavel',
#  'th',
#  'attempt',
#  'sculpture',
#  'balloon',
#  'animals',
#  'beyond',
#  'poodle',
#  'nfl',
#  'dolphins',
#  'pip',
#  'pats',
#  'steelers',
#  'playoff',
#  'spot',
#  'bills',
#  'honor',
#  'hamlin',
#  'boxing',
#  'davis',
#  'stops',
#  'garcia',
#  'eight',
#  'retain',
#  'wba',
#  'lightweight',
#  'title',
#  'news',
#  'sport',
#  'opinion',
#  'guardian',
#  'us',
#  'edition',
#  'putin',
#  'president',
#  'attends',
#  'orthodox',
#  'christmas',
#  'service',
#  'alone',
#  'myanmar',
#  'frontline',
#  'rebel',
#  'army',
#  'fighting',
#  'brutal',
#  'junta',
#  'virginia',
#  'shooting',
#  'teacher',
#  'six',
#  'year',
#  'old',
#  'accidental',
#  'authorities',
#  'say',
#  'harry',
#  'sounds',
#  'callous',
#  'killing',
#  'us',
#  'served',
#  'least',
#  'knows',
#  'hero',
#  'zelenskiy',
#  'became',
#  'hollywood',
#  'man',
#  'hour',
#  'shards',
#  'bret',
#  'easton',
#  'ellis',
#  'review',
#  'inspired',
#  'fever',
#  'dream',
#  'book',
#  'minsk',
#  'russia',
#  'belarus',
#  'extend',
#  'military',
#  'drills',
#  'amid',
#  'fears',
#  'new',
#  'push',
#  'ukraine',
#  'brazil',
#  'bolsonaro',
#  'supporters',
#  'storm',
#  'presidential',
#  'palace',
#  'tesla',
#  'musk',
#  'seeks',
#  'move',
#  'trial',
#  'san',
#  'francisco',
#  'claiming',
#  'get',
#  'fair',
#  'trial',
#  'live',
#  'arrested',
#  'bras',
#  'lia',
#  'lula',
#  'condemns',
#  'barbarism',
#  'storming',
#  'brazil',
#  'political',
#  'buildings',
#  'love',
#  'overwhelming',
#  'recovering',
#  'hamlin',
#  'posts',
#  'update',
#  'social',
#  'media',
#  'italo',
#  'calvino',
#  'written',
#  'world',
#  'unwritten',
#  'world',
#  'review',
#  'box',
#  'delights',
#  'chicago',
#  'new',
#  'report',
#  'details',
#  'sexual',
#  'misconduct',
#  'allegations',
#  'public',
#  'school',
#  'system',
#  'virginia',
#  'shooting',
#  'red',
#  'flag',
#  'us',
#  'says',
#  'mayor',
#  'victoria',
#  'lee',
#  'rising',
#  'mma',
#  'star',
#  'dies',
#  'age',
#  'us',
#  'politics',
#  'mccarthy',
#  'takes',
#  'vote',
#  'losses',
#  'six',
#  'us',
#  'house',
#  'representatives',
#  'adjourns',
#  'racism',
#  'rebranded',
#  'far',
#  'right',
#  'ideology',
#  'feeds',
#  'identity',
#  'politics',
#  'us',
#  'coronavirus',
#  'data',
#  'h',
#  'bombs',
#  'chicken',
#  'bones',
#  'race',
#  'define',
#  'start',
#  'anthropocene',
#  'going',
#  'dirty',
#  'republicans',
#  'gear',
#  'attack',
#  'hunter',
#  'biden',
#  'new',
#  'start',
#  'became',
#  'naturist',
#  'felt',
#  'like',
#  'freedom',
#  'young',
#  'people',
#  'hate',
#  'bodies',
#  'weak',
#  'capitalism',
#  'demands',
#  'texas',
#  'search',
#  'vigilante',
#  'fatally',
#  'shot',
#  'robbery',
#  'suspect',
#  'carrying',
#  'fake',
#  'gun',
#  'virginia',
#  'shooting',
#  'teacher',
#  'six',
#  'year',
#  'old',
#  'accidental',
#  'authorities',
#  'say',
#  'landmark',
#  'step',
#  'pioneering',
#  'foetal',
#  'surgery',
#  'transforming',
#  'lives',
#  'louisiana',
#  'ex',
#  'police',
#  'deputy',
#  'given',
#  'year',
#  'sentence',
#  'sex',
#  'crimes',
#  'einstein',
#  'piaf',
#  'twiggy',
#  'marilyn',
#  'stafford',
#  'extraordinary',
#  'life',
#  'behind',
#  'lens',
#  'alex',
#  'jones',
#  'lawyer',
#  'license',
#  'suspended',
#  'releasing',
#  'sensitive',
#  'records',
#  'germany',
#  'police',
#  'arrest',
#  'iranian',
#  'man',
#  'suspected',
#  'planning',
#  'chemical',
#  'attack',
#  'books',
#  'meet',
#  'best',
#  'new',
#  'novelists',
#  'pay',
#  'entertain',
#  'deal',
#  'harry',
#  'hardest',
#  'working',
#  'royal',
#  'palette',
#  'styles',
#  'new',
#  'delete',
#  'writing',
#  'wall',
#  'paper',
#  'check',
#  'still',
#  'going',
#  'miss',
#  'disability',
#  'tragedy',
#  'remarkable',
#  'life',
#  'activist',
#  'rebel',
#  'hale',
#  'zukas',
#  'profoundly',
#  'troubling',
#  'harvard',
#  'kennedy',
#  'school',
#  'condemned',
#  'denying',
#  'fellowship',
#  'israel',
#  'critic',
#  'one',
#  'embarrassment',
#  'mccarthy',
#  'debacle',
#  'wearily',
#  'received',
#  'california',
#  'home',
#  'town',
#  'china',
#  'borders',
#  'reopen',
#  'lunar',
#  'new',
#  'year',
#  'travel',
#  'kicks',
#  'amid',
#  'covid',
#  'surge',
#  'wants',
#  'live',
#  'ever',
#  'billionaires',
#  'like',
#  'jeff',
#  'bezos',
#  'brief',
#  'writer',
#  'diary',
#  'race',
#  'time',
#  'price',
#  'wars',
#  'reviews',
#  'play',
#  'guardian',
#  'new',
#  'daily',
#  'word',
#  'game',
#  'share',
#  'score',
#  'friends',
#  'israel',
#  'palestinian',
#  'foreign',
#  'minister',
#  'says',
#  'travel',
#  'permit',
#  'revoked',
#  'california',
#  'thousands',
#  'without',
#  'power',
#  'state',
#  'braces',
#  'next',
#  'onslaught',
#  'storms',
#  'day',
#  'beach',
#  'quicksand',
#  'never',
#  'felt',
#  'real',
#  'concept',
#  'moment',
#  'travel',
#  'best',
#  'secret',
#  'retreats',
#  'canary',
#  'islands',
#  'alcarr',
#  'director',
#  'carla',
#  'sim',
#  'n',
#  'feelings',
#  'spanish',
#  'culture',
#  'catalan',
#  'culture',
#  'us',
#  'break',
#  'monopolies',
#  'punish',
#  'working',
#  'americans',
#  'rising',
#  'prices',
#  'weekend',
#  'best',
#  'photos',
#  'delhi',
#  'pride',
#  'peru',
#  'protests',
#  'fearless',
#  'preacher',
#  'pope',
#  'francis',
#  'leads',
#  'catholics',
#  'benedict',
#  'funeral',
#  'abortion',
#  'us',
#  'government',
#  'took',
#  'two',
#  'big',
#  'steps',
#  'matter',
#  'water',
#  'fears',
#  'us',
#  'supreme',
#  'court',
#  'could',
#  'radically',
#  'reshape',
#  'clean',
#  'water',
#  'rules',
#  'louisiana',
#  'officer',
#  'arrested',
#  'car',
#  'crash',
#  'kills',
#  'two',
#  'innocent',
#  'teenagers',
#  'police',
#  'chase',
#  'kevin',
#  'mccarthy',
#  'chaotic',
#  'week',
#  'speaker',
#  'faces',
#  'next',
#  'battle',
#  'house',
#  'votes',
#  'rules',
#  'package',
#  'seattle',
#  'public',
#  'schools',
#  'sue',
#  'social',
#  'media',
#  'platforms',
#  'youth',
#  'mental',
#  'health',
#  'crisis',
#  'ask',
#  'philippa',
#  'hate',
#  'ageing',
#  'body',
#  'look',
#  'disgust',
#  'rohingya',
#  'refugees',
#  'bet',
#  'lives',
#  'boat',
#  'crossings',
#  'despite',
#  'rising',
#  'death',
#  'toll',
#  'aston',
#  'villa',
#  'stevenage',
#  'campbell',
#  'late',
#  'stunner',
#  'causes',
#  'fa',
#  'cup',
#  'upset',
#  'contact',
#  'guardian']

# %%
from nltk.stem import WordNetLemmatizer #Lemmatize the words with stopwords removed
ls = WordNetLemmatizer()
lem_tokens = []
for t in stop_tokens:
    lemma = ls.lemmatize(t) 
    if len(lemma) > 1: #remove random single charcters from lemmatizing
        lem_tokens.append(lemma)

# %%
lem_tokens #uncomment to see ouput of stemmed tokens
# Out:
# ['prince',
#  'harry',
#  'book',
#  'could',
#  'beginning',
#  'end',
#  'royal',
#  'warns',
#  'charles',
#  'biographer',
#  'immigration',
#  'biden',
#  'tell',
#  'migrant',
#  'show',
#  'border',
#  'new',
#  'policy',
#  'announcement',
#  'andrew',
#  'tate',
#  'feminism',
#  'inadvertent',
#  'bastard',
#  'child',
#  'sexism',
#  'last',
#  'gasp',
#  'write',
#  'prince',
#  'harry',
#  'ghostwriter',
#  'famous',
#  'george',
#  'clooney',
#  'made',
#  'film',
#  'life',
#  'vulnerable',
#  'boy',
#  'drawn',
#  'school',
#  'fear',
#  'spread',
#  'andrew',
#  'tate',
#  'misogyny',
#  'art',
#  'treasure',
#  'long',
#  'cherished',
#  'muslim',
#  'deemed',
#  'offensive',
#  'publishing',
#  'man',
#  'pleads',
#  'guilty',
#  'stealing',
#  'manuscript',
#  'california',
#  'back',
#  'back',
#  'storm',
#  'drop',
#  'deluge',
#  'rain',
#  'snow',
#  'ahead',
#  'margaret',
#  'cho',
#  'never',
#  'doubt',
#  'standup',
#  'search',
#  'shipwreck',
#  'becomes',
#  'focus',
#  'slavery',
#  'debate',
#  'skiing',
#  'shiffrin',
#  'tie',
#  'vonn',
#  'world',
#  'cup',
#  'record',
#  'nd',
#  'career',
#  'win',
#  'environment',
#  'biden',
#  'administration',
#  'seek',
#  'limit',
#  'deadly',
#  'air',
#  'pollution',
#  'going',
#  'dirty',
#  'republican',
#  'gear',
#  'attack',
#  'hunter',
#  'biden',
#  'paul',
#  'mescal',
#  'normal',
#  'people',
#  'actor',
#  'set',
#  'star',
#  'ridley',
#  'scott',
#  'gladiator',
#  'sequel',
#  'mexico',
#  'biden',
#  'visit',
#  'border',
#  'first',
#  'time',
#  'critic',
#  'condemn',
#  'migrant',
#  'crackdown',
#  'pope',
#  'benedict',
#  'xvi',
#  'time',
#  'lapse',
#  'show',
#  'thousand',
#  'people',
#  'gathering',
#  'attend',
#  'funeral',
#  'europe',
#  'record',
#  'high',
#  'temperature',
#  'leave',
#  'alp',
#  'without',
#  'snow',
#  'nigel',
#  'slater',
#  'recipe',
#  'breakfast',
#  'muffin',
#  'kipper',
#  'cake',
#  'dill',
#  'sauce',
#  'blind',
#  'date',
#  'fired',
#  'half',
#  'baklava',
#  'across',
#  'table',
#  'think',
#  'styled',
#  'altered',
#  'entire',
#  'worldview',
#  'leading',
#  'author',
#  'pick',
#  'eight',
#  'nonfiction',
#  'book',
#  'change',
#  'mind',
#  'jair',
#  'bolsonaro',
#  'supporter',
#  'storm',
#  'brazil',
#  'presidential',
#  'palace',
#  'supreme',
#  'court',
#  'man',
#  'city',
#  'chelsea',
#  'mahrez',
#  'stunner',
#  'spark',
#  'fa',
#  'cup',
#  'cruise',
#  'pitiful',
#  'blue',
#  'documentary',
#  'thrasher',
#  'way',
#  'live',
#  'mississippian',
#  'struggle',
#  'another',
#  'water',
#  'crisis',
#  'mousetrap',
#  'michael',
#  'frayn',
#  'noise',
#  'farce',
#  'reckoned',
#  'harry',
#  'interview',
#  'review',
#  'horribly',
#  'sad',
#  'could',
#  'turned',
#  'queen',
#  'anti',
#  'monarchy',
#  'adhd',
#  'adderall',
#  'shortage',
#  'mean',
#  'adhd',
#  'patient',
#  'rational',
#  'reason',
#  'zelenskiy',
#  'criticises',
#  'west',
#  'sending',
#  'armoured',
#  'vehicle',
#  'instead',
#  'tank',
#  'immigration',
#  'biden',
#  'carrot',
#  'stick',
#  'approach',
#  'met',
#  'anger',
#  'cellphone',
#  'camera',
#  'dna',
#  'police',
#  'caught',
#  'idaho',
#  'student',
#  'killing',
#  'suspect',
#  'wordiply',
#  'thrasher',
#  'sri',
#  'lanka',
#  'hedge',
#  'fund',
#  'holding',
#  'vital',
#  'debt',
#  'relief',
#  'crisis',
#  'hit',
#  'country',
#  'warn',
#  'economist',
#  'first',
#  'thing',
#  'email',
#  'newsletter',
#  'feeling',
#  'betrayed',
#  'reaction',
#  'george',
#  'santos',
#  'district',
#  'brazen',
#  'lie',
#  'across',
#  'country',
#  'naomi',
#  'osaka',
#  'concern',
#  'mount',
#  'former',
#  'withdraws',
#  'australian',
#  'open',
#  'mark',
#  'spot',
#  'newly',
#  'released',
#  'map',
#  'spark',
#  'hunt',
#  'nazi',
#  'hoard',
#  'live',
#  'arrested',
#  'bra',
#  'lia',
#  'lula',
#  'condemns',
#  'barbarism',
#  'storming',
#  'presidential',
#  'palace',
#  'supreme',
#  'court',
#  'live',
#  'rising',
#  'mma',
#  'star',
#  'victoria',
#  'prodigy',
#  'lee',
#  'dy',
#  'age',
#  'mexico',
#  'city',
#  'least',
#  'one',
#  'dead',
#  'injured',
#  'collision',
#  'metro',
#  'brutalised',
#  'broken',
#  'mended',
#  'inside',
#  'ukraine',
#  'rehabilitation',
#  'centre',
#  'wounded',
#  'veteran',
#  'ana',
#  'bel',
#  'monte',
#  'release',
#  'top',
#  'cuba',
#  'spy',
#  'year',
#  'prison',
#  'touched',
#  'welcome',
#  'messi',
#  'given',
#  'guard',
#  'honour',
#  'psg',
#  'return',
#  'ukraine',
#  'pope',
#  'benedict',
#  'funeral',
#  'week',
#  'around',
#  'world',
#  'picture',
#  'russell',
#  'bank',
#  'award',
#  'winning',
#  'fiction',
#  'writer',
#  'dy',
#  'new',
#  'mexico',
#  'police',
#  'investigate',
#  'shooting',
#  'official',
#  'home',
#  'office',
#  'search',
#  'texas',
#  'vigilante',
#  'fatally',
#  'shot',
#  'robbery',
#  'suspect',
#  'carrying',
#  'fake',
#  'gun',
#  'iran',
#  'regime',
#  'condemned',
#  'executing',
#  'two',
#  'men',
#  'alleged',
#  'protest',
#  'crime',
#  'multiple',
#  'vacuum',
#  'cleaner',
#  'litter',
#  'indoors',
#  'happened',
#  'four',
#  'writer',
#  'swapped',
#  'chore',
#  'partner',
#  'nfl',
#  'trainer',
#  'rushed',
#  'damar',
#  'hamlin',
#  'aid',
#  'lauded',
#  'real',
#  'hero',
#  'glance',
#  'know',
#  'day',
#  'invasion',
#  'prince',
#  'harry',
#  'prince',
#  'harry',
#  'defends',
#  'tell',
#  'memoir',
#  'furious',
#  'itv',
#  'interview',
#  'monkey',
#  'revealed',
#  'allowing',
#  'long',
#  'tailed',
#  'macaque',
#  'import',
#  'despite',
#  'risk',
#  'disease',
#  'cellphone',
#  'camera',
#  'dna',
#  'police',
#  'caught',
#  'idaho',
#  'student',
#  'killing',
#  'suspect',
#  'house',
#  'speaker',
#  'mccarthy',
#  'clinch',
#  'gavel',
#  'th',
#  'attempt',
#  'sculpture',
#  'balloon',
#  'animal',
#  'beyond',
#  'poodle',
#  'nfl',
#  'dolphin',
#  'pip',
#  'pat',
#  'steelers',
#  'playoff',
#  'spot',
#  'bill',
#  'honor',
#  'hamlin',
#  'boxing',
#  'davis',
#  'stop',
#  'garcia',
#  'eight',
#  'retain',
#  'wba',
#  'lightweight',
#  'title',
#  'news',
#  'sport',
#  'opinion',
#  'guardian',
#  'edition',
#  'putin',
#  'president',
#  'attends',
#  'orthodox',
#  'christmas',
#  'service',
#  'alone',
#  'myanmar',
#  'frontline',
#  'rebel',
#  'army',
#  'fighting',
#  'brutal',
#  'junta',
#  'virginia',
#  'shooting',
#  'teacher',
#  'six',
#  'year',
#  'old',
#  'accidental',
#  'authority',
#  'say',
#  'harry',
#  'sound',
#  'callous',
#  'killing',
#  'served',
#  'least',
#  'know',
#  'hero',
#  'zelenskiy',
#  'became',
#  'hollywood',
#  'man',
#  'hour',
#  'shard',
#  'bret',
#  'easton',
#  'elli',
#  'review',
#  'inspired',
#  'fever',
#  'dream',
#  'book',
#  'minsk',
#  'russia',
#  'belarus',
#  'extend',
#  'military',
#  'drill',
#  'amid',
#  'fear',
#  'new',
#  'push',
#  'ukraine',
#  'brazil',
#  'bolsonaro',
#  'supporter',
#  'storm',
#  'presidential',
#  'palace',
#  'tesla',
#  'musk',
#  'seek',
#  'move',
#  'trial',
#  'san',
#  'francisco',
#  'claiming',
#  'get',
#  'fair',
#  'trial',
#  'live',
#  'arrested',
#  'bra',
#  'lia',
#  'lula',
#  'condemns',
#  'barbarism',
#  'storming',
#  'brazil',
#  'political',
#  'building',
#  'love',
#  'overwhelming',
#  'recovering',
#  'hamlin',
#  'post',
#  'update',
#  'social',
#  'medium',
#  'italo',
#  'calvino',
#  'written',
#  'world',
#  'unwritten',
#  'world',
#  'review',
#  'box',
#  'delight',
#  'chicago',
#  'new',
#  'report',
#  'detail',
#  'sexual',
#  'misconduct',
#  'allegation',
#  'public',
#  'school',
#  'system',
#  'virginia',
#  'shooting',
#  'red',
#  'flag',
#  'say',
#  'mayor',
#  'victoria',
#  'lee',
#  'rising',
#  'mma',
#  'star',
#  'dy',
#  'age',
#  'politics',
#  'mccarthy',
#  'take',
#  'vote',
#  'loss',
#  'six',
#  'house',
#  'representative',
#  'adjourns',
#  'racism',
#  'rebranded',
#  'far',
#  'right',
#  'ideology',
#  'feed',
#  'identity',
#  'politics',
#  'coronavirus',
#  'data',
#  'bomb',
#  'chicken',
#  'bone',
#  'race',
#  'define',
#  'start',
#  'anthropocene',
#  'going',
#  'dirty',
#  'republican',
#  'gear',
#  'attack',
#  'hunter',
#  'biden',
#  'new',
#  'start',
#  'became',
#  'naturist',
#  'felt',
#  'like',
#  'freedom',
#  'young',
#  'people',
#  'hate',
#  'body',
#  'weak',
#  'capitalism',
#  'demand',
#  'texas',
#  'search',
#  'vigilante',
#  'fatally',
#  'shot',
#  'robbery',
#  'suspect',
#  'carrying',
#  'fake',
#  'gun',
#  'virginia',
#  'shooting',
#  'teacher',
#  'six',
#  'year',
#  'old',
#  'accidental',
#  'authority',
#  'say',
#  'landmark',
#  'step',
#  'pioneering',
#  'foetal',
#  'surgery',
#  'transforming',
#  'life',
#  'louisiana',
#  'ex',
#  'police',
#  'deputy',
#  'given',
#  'year',
#  'sentence',
#  'sex',
#  'crime',
#  'einstein',
#  'piaf',
#  'twiggy',
#  'marilyn',
#  'stafford',
#  'extraordinary',
#  'life',
#  'behind',
#  'lens',
#  'alex',
#  'jones',
#  'lawyer',
#  'license',
#  'suspended',
#  'releasing',
#  'sensitive',
#  'record',
#  'germany',
#  'police',
#  'arrest',
#  'iranian',
#  'man',
#  'suspected',
#  'planning',
#  'chemical',
#  'attack',
#  'book',
#  'meet',
#  'best',
#  'new',
#  'novelist',
#  'pay',
#  'entertain',
#  'deal',
#  'harry',
#  'hardest',
#  'working',
#  'royal',
#  'palette',
#  'style',
#  'new',
#  'delete',
#  'writing',
#  'wall',
#  'paper',
#  'check',
#  'still',
#  'going',
#  'miss',
#  'disability',
#  'tragedy',
#  'remarkable',
#  'life',
#  'activist',
#  'rebel',
#  'hale',
#  'zukas',
#  'profoundly',
#  'troubling',
#  'harvard',
#  'kennedy',
#  'school',
#  'condemned',
#  'denying',
#  'fellowship',
#  'israel',
#  'critic',
#  'one',
#  'embarrassment',
#  'mccarthy',
#  'debacle',
#  'wearily',
#  'received',
#  'california',
#  'home',
#  'town',
#  'china',
#  'border',
#  'reopen',
#  'lunar',
#  'new',
#  'year',
#  'travel',
#  'kick',
#  'amid',
#  'covid',
#  'surge',
#  'want',
#  'live',
#  'ever',
#  'billionaire',
#  'like',
#  'jeff',
#  'bezos',
#  'brief',
#  'writer',
#  'diary',
#  'race',
#  'time',
#  'price',
#  'war',
#  'review',
#  'play',
#  'guardian',
#  'new',
#  'daily',
#  'word',
#  'game',
#  'share',
#  'score',
#  'friend',
#  'israel',
#  'palestinian',
#  'foreign',
#  'minister',
#  'say',
#  'travel',
#  'permit',
#  'revoked',
#  'california',
#  'thousand',
#  'without',
#  'power',
#  'state',
#  'brace',
#  'next',
#  'onslaught',
#  'storm',
#  'day',
#  'beach',
#  'quicksand',
#  'never',
#  'felt',
#  'real',
#  'concept',
#  'moment',
#  'travel',
#  'best',
#  'secret',
#  'retreat',
#  'canary',
#  'island',
#  'alcarr',
#  'director',
#  'carla',
#  'sim',
#  'feeling',
#  'spanish',
#  'culture',
#  'catalan',
#  'culture',
#  'break',
#  'monopoly',
#  'punish',
#  'working',
#  'american',
#  'rising',
#  'price',
#  'weekend',
#  'best',
#  'photo',
#  'delhi',
#  'pride',
#  'peru',
#  'protest',
#  'fearless',
#  'preacher',
#  'pope',
#  'francis',
#  'lead',
#  'catholic',
#  'benedict',
#  'funeral',
#  'abortion',
#  'government',
#  'took',
#  'two',
#  'big',
#  'step',
#  'matter',
#  'water',
#  'fear',
#  'supreme',
#  'court',
#  'could',
#  'radically',
#  'reshape',
#  'clean',
#  'water',
#  'rule',
#  'louisiana',
#  'officer',
#  'arrested',
#  'car',
#  'crash',
#  'kill',
#  'two',
#  'innocent',
#  'teenager',
#  'police',
#  'chase',
#  'kevin',
#  'mccarthy',
#  'chaotic',
#  'week',
#  'speaker',
#  'face',
#  'next',
#  'battle',
#  'house',
#  'vote',
#  'rule',
#  'package',
#  'seattle',
#  'public',
#  'school',
#  'sue',
#  'social',
#  'medium',
#  'platform',
#  'youth',
#  'mental',
#  'health',
#  'crisis',
#  'ask',
#  'philippa',
#  'hate',
#  'ageing',
#  'body',
#  'look',
#  'disgust',
#  'rohingya',
#  'refugee',
#  'bet',
#  'life',
#  'boat',
#  'crossing',
#  'despite',
#  'rising',
#  'death',
#  'toll',
#  'aston',
#  'villa',
#  'stevenage',
#  'campbell',
#  'late',
#  'stunner',
#  'cause',
#  'fa',
#  'cup',
#  'upset',
#  'contact',
#  'guardian']

# %%
from collections import Counter     #get the top 30 words to make a data frame
my_counter = Counter(lem_tokens)
# my_counter.most_common(25)

word_freq = pd.DataFrame(my_counter.most_common(30),
                             columns=['Words', 'count'])
word_freq
# Out:
#          Words  count
# 0          new      9
# 1        harry      7
# 2        biden      6
# 3       police      6
# 4         life      5
# 5         live      5
# 6         year      5
# 7       prince      4
# 8         book      4
# 9       school      4
# 10         man      4
# 11       storm      4
# 12       world      4
# 13      review      4
# 14     suspect      4
# 15      rising      4
# 16    shooting      4
# 17    mccarthy      4
# 18         say      4
# 19       could      3
# 20      border      3
# 21        fear      3
# 22  california      3
# 23      search      3
# 24         cup      3
# 25      record      3
# 26       going      3
# 27      attack      3
# 28      people      3
# 29        star      3

# %%
fig, ax = plt.subplots(figsize=(12, 12))  #make a bar graph ot the top 3- words from the data frame

# Plot horizontal bar graph
word_freq.sort_values(by='count').plot.barh(x='Words',
                      y='count',
                      ax=ax,
                      color="blue")
ax.set_title("Common Words Found")
plt.show()

# %%
tokens = []

tokenizer = RegexpTokenizer(r'\w+')
for i in saved_text:
    tokens.append(tokenizer.tokenize(i))
flat_tokens = [item for sublist in stem_tokens for item in sublist] #flatten list of lists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 6>()
#       4 for i in saved_text:
#       5     tokens.append(tokenizer.tokenize(i))
# ----> 6 flat_tokens = [item for sublist in stem_tokens for item in sublist]
#
# NameError: name 'stem_tokens' is not defined

# %%
flat_tokens = [item for sublist in stop_tokens_plot for item in sublist] 
flat_tokens
