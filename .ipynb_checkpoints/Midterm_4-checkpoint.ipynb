# %%
# Python program to scrape heading tags
import pickle
from IPython import display
import math
from pprint import pprint
import requests
import nltk
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import random
from wordcloud import WordCloud
import os
import spacy
from textblob import TextBlob
from pattern.en import sentiment
import urllib3 
import re
import datetime
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

nlp = spacy.load('en_core_web_sm')
# %matplotlib inline
sns.set(style='darkgrid', context='talk', palette='Dark2')

cleanData = []
tag_words = []
regex = re.compile('[^a-zA-Z]')

headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"} 
#find what headers you are sending here: https://www.whatismybrowser.com/detect/what-http-headers-is-my-browser-sending

url_link = 'https://foxnews.com' #define URL to scrape
utc_datetime = datetime.datetime.utcnow()
date_string = utc_datetime.strftime("%Y-%m-%d-%H%M_UTC")
filename = f'{url_link[12:-5]}_{date_string}'


# scrape a chosen URL
request = requests.get(url_link, headers=headers)
Soup = BeautifulSoup(request.text, 'lxml') #create soup obejct

if request.status_code == 200: #error handling for URL request
    print('Request successful.')
elif request.status_code == 404:
    print('Error 404: Not Found.')
    

# creating a list by type of heading tags
heading_tags = ["h1","h2","h3"] #the user will have to determine what "h" tags are valid for given URL
for tags in Soup.find_all(heading_tags):
    tag_words.append(tags.text.strip())
#     lower_words = [strg.lower() for strg in tag_words] #some sentiment analyzers analyze case
    
for i in tag_words:  #slice based on data you want to include. Some junk data can be removed
    if len(i)>16:    #Fliter a composite length of strings based on targeted threshold
        cleanData.append(regex.sub(' ', i))

deDup = list(set(cleanData))

with open(filename, "wb") as fp: #Pickling data as list with UTC time stamp
    pickle.dump(deDup, fp)

# with open(filename,'w') as a: # uncomment if you want to save a text copy to avoid utf-8 error message
#     a.write('\n'.join(cleanData))
# Out:
# Request successful.

# %%
with open(filename, "rb") as fp: #Either load stored variable value for "filename" or saved pickled "example_1_0_23"
    saved_text = pickle.load(fp)

saved_text[0:5] #confirm your expected text is correct
# Out:
# ['Subway train collision in Mexico City kills    injures   ',
#  'Former school district employee arrested for  multiple sexual encounters  with students',
#  'UK palace allies fire back against bombshell claims in tell all book',
#  'Damar Hamlin s recovery shows  we re seeing God answer prayer in real time ',
#  'Jessie James Decker lifts up former NFL star husband Eric Decker in PDA filled video   I like big boys ']

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA 

sia = SIA() 
results = []

for line in saved_text:
    pol_score = sia.polarity_scores(line)
    pol_score['headline'] = line
    results.append(pol_score)

pprint(results, width=100) #print textual composite sentiment scores
# Out:
# [{'compound': -0.7184,
#   'headline': 'Subway train collision in Mexico City kills    injures   ',
#   'neg': 0.5,
#   'neu': 0.5,
#   'pos': 0.0},
#  {'compound': -0.4767,
#   'headline': 'Former school district employee arrested for  multiple sexual encounters  with '
#               'students',
#   'neg': 0.237,
#   'neu': 0.763,
#   'pos': 0.0},
#  {'compound': -0.34,
#   'headline': 'UK palace allies fire back against bombshell claims in tell all book',
#   'neg': 0.179,
#   'neu': 0.821,
#   'pos': 0.0},
#  {'compound': 0.2732,
#   'headline': 'Damar Hamlin s recovery shows  we re seeing God answer prayer in real time ',
#   'neg': 0.0,
#   'neu': 0.851,
#   'pos': 0.149},
#  {'compound': 0.3612,
#   'headline': 'Jessie James Decker lifts up former NFL star husband Eric Decker in PDA filled '
#               'video   I like big boys ',
#   'neg': 0.0,
#   'neu': 0.872,
#   'pos': 0.128},
#  {'compound': 0.0,
#   'headline': 'Documents reveal gruesome details about how college students were slain',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.4404,
#   'headline': 'McCarthy thanks Trump after House speaker vote   He was with me from the beginning ',
#   'neg': 0.0,
#   'neu': 0.818,
#   'pos': 0.182},
#  {'compound': 0.0,
#   'headline': 'Democrats are pushing the agenda for socialism  communism  Lt  Gov  Mark Robinson',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Fox News   Night   Friday  January  ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.4019,
#   'headline': 'KFC for Christmas  How the fast food chain became a holiday hit in Japan',
#   'neg': 0.0,
#   'neu': 0.816,
#   'pos': 0.184},
#  {'compound': -0.886,
#   'headline': 'Idaho murder suspect can t  explain  this evidence  Crime analyst Sheryl McCollum',
#   'neg': 0.565,
#   'neu': 0.435,
#   'pos': 0.0},
#  {'compound': -0.4939,
#   'headline': 'America s new B    Raider has   big secrets China wants to steal',
#   'neg': 0.262,
#   'neu': 0.738,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Air fryer turkey dinner for    Try the recipe',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.34,
#   'headline': 'Damar Hamlin s life saving CPR after cardiac arrest  How to perform CPR without '
#               'training',
#   'neg': 0.156,
#   'neu': 0.844,
#   'pos': 0.0},
#  {'compound': -0.2584,
#   'headline': 'House speaker drama  Democrat reads  The Subtle Art of Not Giving A F  k  book on '
#               'floor',
#   'neg': 0.135,
#   'neu': 0.865,
#   'pos': 0.0},
#  {'compound': 0.34,
#   'headline': 'Jan    committee releases Social Security numbers of Trump officials and allies  '
#               'report',
#   'neg': 0.0,
#   'neu': 0.821,
#   'pos': 0.179},
#  {'compound': -0.7269,
#   'headline': 'Federal court strikes down Trump era bump stock ban',
#   'neg': 0.466,
#   'neu': 0.534,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'I ve been to the border and here is my message to President Biden',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.8176,
#   'headline': 'Arkansas monastery desecrated with sledgehammer  relics stolen  suspect arrested',
#   'neg': 0.586,
#   'neu': 0.414,
#   'pos': 0.0},
#  {'compound': 0.7677,
#   'headline': 'Derailing  America s most dangerous law   Sheriff hopes Illinois Supreme Court '
#               'upholds SAFE T Act decision',
#   'neg': 0.145,
#   'neu': 0.427,
#   'pos': 0.428},
#  {'compound': -0.7845,
#   'headline': 'Museum of Modern Art stabbing suspect extradited to New York  indicted for '
#               'attempted murder',
#   'neg': 0.365,
#   'neu': 0.635,
#   'pos': 0.0},
#  {'compound': -0.6908,
#   'headline': 'Teen pilot flying family to breakfast makes emergency landing on CA highway  '
#               'grandma  crying in the back ',
#   'neg': 0.275,
#   'neu': 0.725,
#   'pos': 0.0},
#  {'compound': 0.9186,
#   'headline': 'Anne Heche s son Homer Laffoon thanks fans for  love  care and support  amid late '
#               'star s memoir release',
#   'neg': 0.0,
#   'neu': 0.5,
#   'pos': 0.5},
#  {'compound': 0.4404,
#   'headline': 'Victor Davis Hanson lays out plan for a better America',
#   'neg': 0.0,
#   'neu': 0.734,
#   'pos': 0.266},
#  {'compound': -0.5719,
#   'headline': 'Market expert gives grim prediction for first months of     ',
#   'neg': 0.316,
#   'neu': 0.684,
#   'pos': 0.0},
#  {'compound': 0.4767,
#   'headline': 'FDA accelerates approval for Alzheimer s drug',
#   'neg': 0.0,
#   'neu': 0.617,
#   'pos': 0.383},
#  {'compound': 0.0,
#   'headline': 'The Ingraham Angle   Friday  January  ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.5423,
#   'headline': 'IRS targeted poorest taxpayers while millionaires went mostly unscathed in       '
#               'report',
#   'neg': 0.259,
#   'neu': 0.741,
#   'pos': 0.0},
#  {'compound': 0.4019,
#   'headline': 'Holiday gifts for last minute Christmas shopping  These are all American made',
#   'neg': 0.0,
#   'neu': 0.803,
#   'pos': 0.197},
#  {'compound': 0.4019,
#   'headline': 'Feeding America CEO asks community to help others amid today s high inflation',
#   'neg': 0.0,
#   'neu': 0.803,
#   'pos': 0.197},
#  {'compound': 0.0,
#   'headline': 'The Journal Editorial Report   Saturday  January  ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.4767,
#   'headline': 'Damar Hamlin s college teammate recovers fumble right where Bills safety s number '
#               'is painted on field',
#   'neg': 0.0,
#   'neu': 0.76,
#   'pos': 0.24},
#  {'compound': -0.296,
#   'headline': 'China acts against COVID policy critics  suspends social media accounts',
#   'neg': 0.196,
#   'neu': 0.804,
#   'pos': 0.0},
#  {'compound': -0.6597,
#   'headline': 'Tension in the Vatican revealed by top aide following death of Benedict XVI',
#   'neg': 0.344,
#   'neu': 0.556,
#   'pos': 0.1},
#  {'compound': 0.5267,
#   'headline': 'Dickens   Christmas Carol  could help Americans revitalize our spirit',
#   'neg': 0.0,
#   'neu': 0.614,
#   'pos': 0.386},
#  {'compound': 0.0,
#   'headline': 'How to unlock an Apple device when its owner dies',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.3818,
#   'headline': 'Rod Stewart says  farewell  to late brother Bob after losing eldest sibling Don   '
#               'Two of my best mates gone ',
#   'neg': 0.109,
#   'neu': 0.714,
#   'pos': 0.176},
#  {'compound': -0.2584,
#   'headline': 'December jobs report s real numbers are anemic not robust  Here s why Americans '
#               'should be wary',
#   'neg': 0.127,
#   'neu': 0.873,
#   'pos': 0.0},
#  {'compound': 0.3612,
#   'headline': 'Parents raise awareness on the importance of defibrillation',
#   'neg': 0.0,
#   'neu': 0.737,
#   'pos': 0.263},
#  {'compound': 0.0,
#   'headline': 'Police provide update on search for mom of   who vanished',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.802,
#   'headline': 'Greeks celebrate Epiphany with blessings of the water after   years of COVID '
#               'restrictions',
#   'neg': 0.0,
#   'neu': 0.604,
#   'pos': 0.396},
#  {'compound': 0.0,
#   'headline': 'New Jersey beach town sues state for     million over dune issue',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.296,
#   'headline': 'It s no yoke  Tesla brings back round steering wheels',
#   'neg': 0.216,
#   'neu': 0.784,
#   'pos': 0.0},
#  {'compound': -0.1779,
#   'headline': 'Connecticut community rallies together after Christmas food donations stolen  It s '
#               'like a  Hallmark movie ',
#   'neg': 0.192,
#   'neu': 0.659,
#   'pos': 0.15},
#  {'compound': 0.0,
#   'headline': 'One line from McCarthy speech brings GOP into uproar  leaves Dems silent',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Texas mayor speaks out on Biden s anticipated visit to the border',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.1531,
#   'headline': 'Jaguars  late scoop and score clinches AFC South over Titans',
#   'neg': 0.0,
#   'neu': 0.849,
#   'pos': 0.151},
#  {'compound': 0.0,
#   'headline': 'Dem lawmaker sends not so subtle message with book on House floor',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.4404,
#   'headline': ' INSURRECTION PLATFORM  Former congressman panics over Republican lawmakers '
#               'investigating federal agencies',
#   'neg': 0.225,
#   'neu': 0.775,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Kentucky Gov  Andy Beshear chosen to co chair Appalachian Regional Commission',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.4215,
#   'headline': '  safety tips for deep frying a Thanksgiving turkey',
#   'neg': 0.0,
#   'neu': 0.682,
#   'pos': 0.318},
#  {'compound': -0.6249,
#   'headline': 'McCarthy vows to investigate border crisis  COVID    origins',
#   'neg': 0.369,
#   'neu': 0.631,
#   'pos': 0.0},
#  {'compound': 0.3182,
#   'headline': 'Annual report says Maine s child welfare system needs improvements',
#   'neg': 0.0,
#   'neu': 0.777,
#   'pos': 0.223},
#  {'compound': 0.6808,
#   'headline': 'Reddit user asks if she was wrong to wear  colossally large  engagement ring to a '
#               'relative s engagement party',
#   'neg': 0.125,
#   'neu': 0.524,
#   'pos': 0.351},
#  {'compound': -0.1531,
#   'headline': 'White House hopeful war with China over Taiwan  never comes to pass   report',
#   'neg': 0.214,
#   'neu': 0.604,
#   'pos': 0.181},
#  {'compound': -0.6908,
#   'headline': 'American Airlines drops   cities from service  blaming pilot shortage   soft '
#               'demand ',
#   'neg': 0.456,
#   'neu': 0.544,
#   'pos': 0.0},
#  {'compound': 0.7351,
#   'headline': 'Biden administration unveils defense of student loan forgiveness plan at Supreme '
#               'Court',
#   'neg': 0.0,
#   'neu': 0.556,
#   'pos': 0.444},
#  {'compound': 0.2732,
#   'headline': 'Chiefs  one of a kind huddle results in bizarre touchdown that gets called back',
#   'neg': 0.138,
#   'neu': 0.659,
#   'pos': 0.204},
#  {'compound': 0.0,
#   'headline': 'Where is the snow  US approaches midpoint of meteorological winter',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.296, 'headline': 'Personal Freedoms', 'neg': 0.0, 'neu': 0.312, 'pos': 0.688},
#  {'compound': 0.0258,
#   'headline': 'The mysterious      Dodge Challenger  Black Ghost  is up for auction and worth a '
#               'fortune',
#   'neg': 0.146,
#   'neu': 0.637,
#   'pos': 0.217},
#  {'compound': 0.4404,
#   'headline': 'Biden signs bills to improve water access for   Arizona tribes',
#   'neg': 0.0,
#   'neu': 0.756,
#   'pos': 0.244},
#  {'compound': 0.0, 'headline': 'Digital Originals', 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'compound': 0.5267,
#   'headline': 'Here are the winning numbers for Friday s     M Mega Millions drawing',
#   'neg': 0.0,
#   'neu': 0.726,
#   'pos': 0.274},
#  {'compound': -0.34,
#   'headline': 'Arrest of Ashli Babbitt s mom on Jan    anniversary  doesn t smell right   widower',
#   'neg': 0.179,
#   'neu': 0.821,
#   'pos': 0.0},
#  {'compound': 0.0, 'headline': 'Political cartoons of the day', 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'National Spaghetti Day  A look at the history of the dish',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.2263,
#   'headline': 'Homeowner shoots suspected intruder  holds him at gunpoint until deputies arrive',
#   'neg': 0.16,
#   'neu': 0.84,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'How to watch Hawaii s Kilauea volcano eruption',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.6808,
#   'headline': 'Patrick Mahomes sets NFL record as Chiefs clinch AFC s top seed  bye week with win '
#               'over Raiders',
#   'neg': 0.0,
#   'neu': 0.728,
#   'pos': 0.272},
#  {'compound': -0.4404,
#   'headline': 'Fonda got weak in the knees after meeting NFL legend   Had to hold on ',
#   'neg': 0.182,
#   'neu': 0.818,
#   'pos': 0.0},
#  {'compound': 0.6908,
#   'headline': 'TSA says passenger attempted to bring  emotional support  boa constrictor snake '
#               'through security',
#   'neg': 0.0,
#   'neu': 0.599,
#   'pos': 0.401},
#  {'compound': -0.802,
#   'headline': 'Lawyer for surviving Idaho roommate details what she told police after horrific '
#               'night of murders',
#   'neg': 0.372,
#   'neu': 0.531,
#   'pos': 0.097},
#  {'compound': -0.3182,
#   'headline': 'Van Gogh  a one eared dog in desperate need of a new home   paints  his way to '
#               'adoption',
#   'neg': 0.133,
#   'neu': 0.867,
#   'pos': 0.0},
#  {'compound': -0.4939,
#   'headline': 'Chick fil A urges customers to take action  investigates  fraudulent activity  on '
#               'mobile app accounts',
#   'neg': 0.198,
#   'neu': 0.802,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'The Big Saturday Show   Saturday  January  ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.7506,
#   'headline': 'Noem touts South Dakota s conservative successes  can bring hope to the rest of the '
#               'country ',
#   'neg': 0.056,
#   'neu': 0.612,
#   'pos': 0.332},
#  {'compound': 0.6124,
#   'headline': 'Jane Fonda says her  knees gave way  when she met  gorgeous  Tom Brady   I had to '
#               'hold onto something ',
#   'neg': 0.0,
#   'neu': 0.81,
#   'pos': 0.19},
#  {'compound': -0.7717,
#   'headline': 'Hiker found dead in Texas national park after high wind warning on New Year s Eve',
#   'neg': 0.34,
#   'neu': 0.66,
#   'pos': 0.0},
#  {'compound': -0.3931,
#   'headline': 'McCarthy is finally speaker  But he s not weak like you think  Now he can deploy '
#               'the  crazy boss  strategy',
#   'neg': 0.232,
#   'neu': 0.643,
#   'pos': 0.125},
#  {'compound': 0.0,
#   'headline': 'Rams head coach Sean McVay weighing immediate future with team  report',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.4939,
#   'headline': 'Parade of storms will pound California through next week following deadly bomb '
#               'cyclone',
#   'neg': 0.211,
#   'neu': 0.789,
#   'pos': 0.0},
#  {'compound': 0.3818,
#   'headline': 'Kylie Jenner and Travis Scott split again after spending the holidays apart  report',
#   'neg': 0.0,
#   'neu': 0.822,
#   'pos': 0.178},
#  {'compound': 0.5574,
#   'headline': 'Bataan survivor       remembers enduring POW camps because  God sustained me ',
#   'neg': 0.0,
#   'neu': 0.635,
#   'pos': 0.365},
#  {'compound': 0.0,
#   'headline': ' FAR RIGHT INSURRECTIONISTS   Omar says McCarthy s deal means GOP will hold '
#               'Americans  futures  hostage ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.3818,
#   'headline': ' OUR GOVERNMENT IS A BUST   Americans weigh in on fight to elect speaker of the '
#               'House',
#   'neg': 0.157,
#   'neu': 0.843,
#   'pos': 0.0},
#  {'compound': 0.4019,
#   'headline': 'SHARP TURN Concealed carry holder allegedly shot ax wielding man he was trying to '
#               'help',
#   'neg': 0.0,
#   'neu': 0.838,
#   'pos': 0.162},
#  {'compound': -0.6908,
#   'headline': 'Wells Fargo VP arrested  fired for urinating on airplane passenger  report',
#   'neg': 0.401,
#   'neu': 0.479,
#   'pos': 0.12},
#  {'compound': 0.3818,
#   'headline': 'Dan Bongino hits back at  garbage narrative  on House Speaker battle  A  glorious '
#               'day  for America',
#   'neg': 0.131,
#   'neu': 0.657,
#   'pos': 0.212},
#  {'compound': 0.0,
#   'headline': 'NFL head coach reportedly weighing immediate future with team',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': ' IT S A LITTLE LATE   Border residents respond to Biden s first ever border trip  '
#               'pledge to stiffen policies',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.7845,
#   'headline': 'No way around Idaho suspect s DNA being found at crime scene  Jay Town',
#   'neg': 0.441,
#   'neu': 0.559,
#   'pos': 0.0},
#  {'compound': -0.5965,
#   'headline': 'Iran executes   more men detained amid nationwide protests',
#   'neg': 0.448,
#   'neu': 0.552,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Four seasons  One world  Epic stories  Coming Sunday  exclusively on Fox Nation ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.7783,
#   'headline': 'Oklahoma    year old stabs   year old brother to death  police say',
#   'neg': 0.43,
#   'neu': 0.57,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Texas ranchers blast Biden s obligatory border visit   A little too late ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.1531,
#   'headline': 'Michigan UPS worker  born a preemie herself  makes warming blankets for other '
#               'babies born prematurely',
#   'neg': 0.0,
#   'neu': 0.89,
#   'pos': 0.11},
#  {'compound': -0.4588,
#   'headline': 'Injured snowmobiler in Utah hoisted to safety after accident on remote peak',
#   'neg': 0.33,
#   'neu': 0.511,
#   'pos': 0.159},
#  {'compound': -0.2263,
#   'headline': 'Texas homeowner shoots suspected intruder  holds him at gunpoint until deputies '
#               'arrive',
#   'neg': 0.147,
#   'neu': 0.853,
#   'pos': 0.0},
#  {'compound': -0.6124,
#   'headline': 'Knife sheath in Idaho murders points to possible target  Expert',
#   'neg': 0.308,
#   'neu': 0.692,
#   'pos': 0.0},
#  {'compound': 0.8481,
#   'headline': 'Billy Idol honored with star on Hollywood Walk of Fame   I couldn t have imagined '
#               'something like this ',
#   'neg': 0.0,
#   'neu': 0.586,
#   'pos': 0.414},
#  {'compound': -0.0258,
#   'headline': 'Prince Harry details losing his virginity to an older woman who treated him like  a '
#               'young stallion ',
#   'neg': 0.136,
#   'neu': 0.733,
#   'pos': 0.131},
#  {'compound': 0.0258,
#   'headline': ' CORPORATE KINGDOM   DeSantis backed plan to take control of Disney s land '
#               'announced',
#   'neg': 0.0,
#   'neu': 0.909,
#   'pos': 0.091},
#  {'compound': 0.0,
#   'headline': 'Ron DeSantis activates National Guard amid migrant surge in Florida Keys',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Research uncovers secret of ancient Rome that baffled scientists',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.34,
#   'headline': 'UK palace allies fire back against Prince Harry s claims ahead of tell all memoir '
#               'release',
#   'neg': 0.146,
#   'neu': 0.854,
#   'pos': 0.0},
#  {'compound': -0.6249,
#   'headline': 'TUCKER CARLSON  Lies about January   have enabled unscrupulous people to make a '
#               'mockery of our Bill of Rights',
#   'neg': 0.254,
#   'neu': 0.746,
#   'pos': 0.0},
#  {'compound': 0.2263,
#   'headline': 'Richard Branson says Elon Musk surprised him in his kitchen at   AM last year '
#               'before spaceflight',
#   'neg': 0.0,
#   'neu': 0.888,
#   'pos': 0.112},
#  {'compound': 0.0,
#   'headline': 'On this day in history  Jan           Galileo discovers the moons of Jupiter',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.5106,
#   'headline': 'New terror groups form due to Afghanistan withdrawal',
#   'neg': 0.324,
#   'neu': 0.571,
#   'pos': 0.105},
#  {'compound': 0.3818,
#   'headline': 'Stronger limits proposed to control deadly soot pollution in the US',
#   'neg': 0.0,
#   'neu': 0.794,
#   'pos': 0.206},
#  {'compound': -0.4019,
#   'headline': 'Retired NASA satellite to crash into Earth on Sunday',
#   'neg': 0.252,
#   'neu': 0.748,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Meet the American who invented the wireless TV remote control',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.34,
#   'headline': 'Homeland Security develops new portable gunshot detection system',
#   'neg': 0.0,
#   'neu': 0.745,
#   'pos': 0.255},
#  {'compound': -0.3931,
#   'headline': 'McCarthy is finally Speaker  But he s not weak like you think  Now he can deploy '
#               'the  crazy boss  strategy',
#   'neg': 0.232,
#   'neu': 0.643,
#   'pos': 0.125},
#  {'compound': 0.6908,
#   'headline': 'The Dodge Challenger is America s best selling sports car     again',
#   'neg': 0.0,
#   'neu': 0.584,
#   'pos': 0.416},
#  {'compound': -0.7269,
#   'headline': 'Prince Harry s comments on military service may incite Taliban violence  former '
#               'commander says   Propaganda ',
#   'neg': 0.337,
#   'neu': 0.663,
#   'pos': 0.0},
#  {'compound': 0.4404,
#   'headline': 'Jeremy Renner posts hospital photo  thanks medical staff in recovery update',
#   'neg': 0.0,
#   'neu': 0.775,
#   'pos': 0.225},
#  {'compound': 0.0,
#   'headline': 'Former high ranking US official who spied for Cuba released after    years',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.5994,
#   'headline': 'Jaguars  Titans come together for group prayer for Damar Hamlin at midfield before '
#               'do or die game',
#   'neg': 0.196,
#   'neu': 0.804,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': ' Weekend brisket  for Hanukkah  Try the recipe',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.8468,
#   'headline': 'AIN T NO REST FOR THE WICKED Rock band s lead singer facing several charges after '
#               'hotel room discovery',
#   'neg': 0.396,
#   'neu': 0.604,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Do these revealing photos of your home belong here without permission ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.128,
#   'headline': 'More Americans turning to credit cards to cover basic expenses as inflation rages',
#   'neg': 0.186,
#   'neu': 0.659,
#   'pos': 0.156},
#  {'compound': -0.4939,
#   'headline': 'Saints  Pelicans donate life saving equipment in wake of Damar Hamlin s on field '
#               'collapse',
#   'neg': 0.198,
#   'neu': 0.802,
#   'pos': 0.0},
#  {'compound': -0.7783,
#   'headline': 'FAMILY S NIGHTMARE Girl stabs   year old brother to death  police say',
#   'neg': 0.43,
#   'neu': 0.57,
#   'pos': 0.0},
#  {'compound': 0.4404,
#   'headline': 'Will California s long term drought improve after atmospheric rivers hammer the '
#               'West ',
#   'neg': 0.0,
#   'neu': 0.791,
#   'pos': 0.209},
#  {'compound': 0.296,
#   'headline': 'David Malpass shares his economic outlook for        Sharp deterioration and it may '
#               'be long lasting ',
#   'neg': 0.0,
#   'neu': 0.864,
#   'pos': 0.136},
#  {'compound': -0.6124,
#   'headline': 'GOP governor squares up for fight with federal government after private information '
#               'leak',
#   'neg': 0.312,
#   'neu': 0.688,
#   'pos': 0.0},
#  {'compound': -0.128,
#   'headline': 'Conservatives pan Jefferies  rambling disaster of a speech   yet gets high praise '
#               'from left',
#   'neg': 0.219,
#   'neu': 0.588,
#   'pos': 0.193},
#  {'compound': 0.128,
#   'headline': 'Credit card debt on the rise  Here s the  best weapon in your arsenal  to fight it',
#   'neg': 0.291,
#   'neu': 0.438,
#   'pos': 0.271},
#  {'compound': 0.0, 'headline': 'Hannity   Friday  January  ', 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'compound': -0.6124,
#   'headline': 'Court documents outline timeline in Idaho murders',
#   'neg': 0.4,
#   'neu': 0.6,
#   'pos': 0.0},
#  {'compound': 0.4215,
#   'headline': 'The first GMC Hummer EV SUV could raise millions for charity',
#   'neg': 0.0,
#   'neu': 0.781,
#   'pos': 0.219},
#  {'compound': 0.0,
#   'headline': 'DAN BONGINO  Are we living in a clown world ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.875,
#   'headline': 'Item found at murder scene may reveal who killer was targeting  experts say',
#   'neg': 0.45,
#   'neu': 0.55,
#   'pos': 0.0},
#  {'compound': -0.296,
#   'headline': 'Biden border visit all about      posturing  immigration plan about  streamlining '
#               'illegality   critics',
#   'neg': 0.167,
#   'neu': 0.833,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Iowa s Bessie Hendricks  the oldest person in the US  dies at    ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.7506,
#   'headline': 'Cage the Elephant singer Matt Schultz arrested on weapon charges',
#   'neg': 0.514,
#   'neu': 0.486,
#   'pos': 0.0},
#  {'compound': 0.1027,
#   'headline': 'As COVID ravages China  US expands testing system for incoming travelers',
#   'neg': 0.0,
#   'neu': 0.877,
#   'pos': 0.123},
#  {'compound': -0.34,
#   'headline': 'Oklahoma police arrest  porch pirate  wearing  women s underwear  as mask',
#   'neg': 0.211,
#   'neu': 0.789,
#   'pos': 0.0},
#  {'compound': 0.7351,
#   'headline': 'A  sweet  friendly  dog is looking for a home in the new year',
#   'neg': 0.0,
#   'neu': 0.592,
#   'pos': 0.408},
#  {'compound': 0.1081,
#   'headline': 'Kamala Harris reveals Biden s      priorities includes inflation  job growth   '
#               'Never been more optimistic ',
#   'neg': 0.138,
#   'neu': 0.697,
#   'pos': 0.165},
#  {'compound': 0.0, 'headline': 'Travel   Outdoors', 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  {'compound': 0.0,
#   'headline': '       veterans eat from garbage cans every day  Here s how we can end veteran '
#               'homelessness',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.5423,
#   'headline': 'Glacier National Park  Exploring the world s first international peace park',
#   'neg': 0.0,
#   'neu': 0.72,
#   'pos': 0.28},
#  {'compound': -0.128,
#   'headline': 'Virginia teacher shot by   year old identified  parents demand action',
#   'neg': 0.143,
#   'neu': 0.857,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Biden closer to re election campaign announcement after St  Croix family vacation  '
#               'report',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.6059,
#   'headline': 'Armed robber shot dead by man who returned cash   but questions remain',
#   'neg': 0.331,
#   'neu': 0.669,
#   'pos': 0.0},
#  {'compound': 0.296,
#   'headline': 'Blunt hiring ad at butcher shop prompts employers to share wild employee excuses   '
#               'My cat just had puppies ',
#   'neg': 0.0,
#   'neu': 0.885,
#   'pos': 0.115},
#  {'compound': -0.9468,
#   'headline': 'Three children among five dead in suspected murder suicide',
#   'neg': 0.755,
#   'neu': 0.245,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'How to unlock an Android device and Windows PC when the owner dies',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': 0.6369,
#   'headline': 'Get the best of Fox News delivered to your inbox daily',
#   'neg': 0.0,
#   'neu': 0.704,
#   'pos': 0.296},
#  {'compound': -0.2263,
#   'headline': 'I saw a woman who needed a wheelchair drag herself across a street  Now I ve given '
#               'away   million wheelchairs',
#   'neg': 0.119,
#   'neu': 0.881,
#   'pos': 0.0},
#  {'compound': 0.3818,
#   'headline': 'Honey as an alternative to sugar  New study indicates the health benefits',
#   'neg': 0.0,
#   'neu': 0.809,
#   'pos': 0.191},
#  {'compound': -0.5106,
#   'headline': 'American Airlines pilots say  reckless  cockpit procedure changes could hurt safety',
#   'neg': 0.361,
#   'neu': 0.473,
#   'pos': 0.166},
#  {'compound': 0.3182,
#   'headline': 'Tennessee National Guard rescues stranded Appalachian Trail hikers',
#   'neg': 0.0,
#   'neu': 0.753,
#   'pos': 0.247},
#  {'compound': -0.1027,
#   'headline': 'In the face of crime and danger  Americans stepped up to help complete strangers '
#               'in        People are amazing ',
#   'neg': 0.252,
#   'neu': 0.511,
#   'pos': 0.237},
#  {'compound': 0.0,
#   'headline': 'Wild innovations coming in      despite downturn in economy',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.7125,
#   'headline': ' WORSE THAN IT ALREADY IS   Americans reveal low expectations for Biden in     ',
#   'neg': 0.372,
#   'neu': 0.628,
#   'pos': 0.0},
#  {'compound': 0.0,
#   'headline': 'Shania Twain calls performing with Harry Styles at Coachella  a full circle moment ',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0},
#  {'compound': -0.296,
#   'headline': 'Biden making pit stop at the border  White House says',
#   'neg': 0.196,
#   'neu': 0.804,
#   'pos': 0.0},
#  {'compound': -0.8689,
#   'headline': 'NYC bans AI tool ChatGPT in schools amid fears of new cheating threat',
#   'neg': 0.495,
#   'neu': 0.505,
#   'pos': 0.0},
#  {'compound': 0.4939,
#   'headline': 'Debt relief industry sees surge as credit card balances swell',
#   'neg': 0.164,
#   'neu': 0.461,
#   'pos': 0.375},
#  {'compound': -0.3818,
#   'headline': 'Shock  The electric Ram      Revolution pickup has       rows of seats ',
#   'neg': 0.224,
#   'neu': 0.776,
#   'pos': 0.0}]

# %%
df = pd.DataFrame.from_records(results)
df
# Out:
#        neg    neu    pos  compound  \
# 0    0.500  0.500  0.000   -0.7184
# 1    0.237  0.763  0.000   -0.4767
# 2    0.179  0.821  0.000   -0.3400
# 3    0.000  0.851  0.149    0.2732
# 4    0.000  0.872  0.128    0.3612
# ..     ...    ...    ...       ...
# 160  0.000  1.000  0.000    0.0000
# 161  0.196  0.804  0.000   -0.2960
# 162  0.495  0.505  0.000   -0.8689
# 163  0.164  0.461  0.375    0.4939
# 164  0.224  0.776  0.000   -0.3818
#
#                                               headline
# 0    Subway train collision in Mexico City kills   ...
# 1    Former school district employee arrested for  ...
# 2    UK palace allies fire back against bombshell c...
# 3    Damar Hamlin s recovery shows  we re seeing Go...
# 4    Jessie James Decker lifts up former NFL star h...
# ..                                                 ...
# 160  Shania Twain calls performing with Harry Style...
# 161  Biden making pit stop at the border  White Hou...
# 162  NYC bans AI tool ChatGPT in schools amid fears...
# 163  Debt relief industry sees surge as credit card...
# 164  Shock  The electric Ram      Revolution pickup...
#
# [165 rows x 5 columns]

# %%
df['label'] = 0
df.loc[df['compound'] > 0.2, 'label'] = 1
df.loc[df['compound'] < -0.2, 'label'] = -1
df
# Out:
#        neg    neu    pos  compound  \
# 0    0.500  0.500  0.000   -0.7184
# 1    0.237  0.763  0.000   -0.4767
# 2    0.179  0.821  0.000   -0.3400
# 3    0.000  0.851  0.149    0.2732
# 4    0.000  0.872  0.128    0.3612
# ..     ...    ...    ...       ...
# 160  0.000  1.000  0.000    0.0000
# 161  0.196  0.804  0.000   -0.2960
# 162  0.495  0.505  0.000   -0.8689
# 163  0.164  0.461  0.375    0.4939
# 164  0.224  0.776  0.000   -0.3818
#
#                                               headline  label
# 0    Subway train collision in Mexico City kills   ...     -1
# 1    Former school district employee arrested for  ...     -1
# 2    UK palace allies fire back against bombshell c...     -1
# 3    Damar Hamlin s recovery shows  we re seeing Go...      1
# 4    Jessie James Decker lifts up former NFL star h...      1
# ..                                                 ...    ...
# 160  Shania Twain calls performing with Harry Style...      0
# 161  Biden making pit stop at the border  White Hou...     -1
# 162  NYC bans AI tool ChatGPT in schools amid fears...     -1
# 163  Debt relief industry sees surge as credit card...      1
# 164  Shock  The electric Ram      Revolution pickup...     -1
#
# [165 rows x 6 columns]

# %%
df2 = df[['headline', 'label']]
df2.to_csv(filename +'.csv', mode='a', encoding='utf-8', index=False)

# %%
print("Positive headlines:\n")
pprint(list(df[df['label'] == 1].headline)[:10], width=200)

print("\nNegative headlines:\n")
pprint(list(df[df['label'] == -1].headline)[:10], width=200)
# Out:
# Positive headlines:
#
# ['Damar Hamlin s recovery shows  we re seeing God answer prayer in real time ',
#  'Jessie James Decker lifts up former NFL star husband Eric Decker in PDA filled video   I like big boys ',
#  'McCarthy thanks Trump after House speaker vote   He was with me from the beginning ',
#  'KFC for Christmas  How the fast food chain became a holiday hit in Japan',
#  'Jan    committee releases Social Security numbers of Trump officials and allies  report',
#  'Derailing  America s most dangerous law   Sheriff hopes Illinois Supreme Court upholds SAFE T Act decision',
#  'Anne Heche s son Homer Laffoon thanks fans for  love  care and support  amid late star s memoir release',
#  'Victor Davis Hanson lays out plan for a better America',
#  'FDA accelerates approval for Alzheimer s drug',
#  'Holiday gifts for last minute Christmas shopping  These are all American made']
#
# Negative headlines:
#
# ['Subway train collision in Mexico City kills    injures   ',
#  'Former school district employee arrested for  multiple sexual encounters  with students',
#  'UK palace allies fire back against bombshell claims in tell all book',
#  'Idaho murder suspect can t  explain  this evidence  Crime analyst Sheryl McCollum',
#  'America s new B    Raider has   big secrets China wants to steal',
#  'Damar Hamlin s life saving CPR after cardiac arrest  How to perform CPR without training',
#  'House speaker drama  Democrat reads  The Subtle Art of Not Giving A F  k  book on floor',
#  'Federal court strikes down Trump era bump stock ban',
#  'Arkansas monastery desecrated with sledgehammer  relics stolen  suspect arrested',
#  'Museum of Modern Art stabbing suspect extradited to New York  indicted for attempted murder']

# %%
print(df.label.value_counts())

print(df.label.value_counts(normalize=True) * 100) #normalize data
# Out:
# -1    61
#  0    56
#  1    48
# Name: label, dtype: int64
# -1    36.969697
#  0    33.939394
#  1    29.090909
# Name: label, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 8))

counts = df.label.value_counts(normalize=True) * 100

sns.barplot(x=counts.index, y=counts, ax=ax)

ax.set_xticklabels(['Negative', 'Neutral', 'Positive'])
ax.set_ylabel("Percentage")

plt.show()

# %%
textblob_sentiment=[]
for s in saved_text:
    txt= TextBlob(s)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([s,a,b])

# %%
df_textblob = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_textblob
# Out:
#                                               Sentence  Polarity  Subjectivity
# 0    Subway train collision in Mexico City kills   ...  0.000000      0.000000
# 1    Former school district employee arrested for  ...  0.166667      0.277778
# 2    UK palace allies fire back against bombshell c...  0.000000      0.000000
# 3    Damar Hamlin s recovery shows  we re seeing Go...  0.200000      0.300000
# 4    Jessie James Decker lifts up former NFL star h...  0.133333      0.333333
# ..                                                 ...       ...           ...
# 160  Shania Twain calls performing with Harry Style...  0.350000      0.550000
# 161  Biden making pit stop at the border  White Hou...  0.000000      0.000000
# 162  NYC bans AI tool ChatGPT in schools amid fears...  0.136364      0.454545
# 163  Debt relief industry sees surge as credit card...  0.000000      0.000000
# 164  Shock  The electric Ram      Revolution pickup...  0.000000      0.000000
#
# [165 rows x 3 columns]

# %%
df_textblob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      165 non-null    object
#  1   Polarity      165 non-null    float64
#  2   Subjectivity  165 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.0+ KB

# %%
sns.displot(df_textblob["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Textblob)")
# Out:
# Text(0.5, 15.439999999999998, 'Sentence Polarity (Textblob)')

# %%
sns.displot(df_textblob["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Textblob)")
# Out:
# Text(0.5, 15.439999999999998, 'Sentence Subjectivity (Textblob)')

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
stop_tokens = []
stop_tokens_plot = []

def process_text(headlines):
    for line in headlines:
        toks = tokenizer.tokenize(line)
        toks = [t.lower() for t in toks if t.lower() not in stop_words]
        stop_tokens.extend(toks)
        stop_tokens_plot.append(toks)
    
    return stop_tokens

process_text(saved_text)
# Out:
# ['subway',
#  'train',
#  'collision',
#  'mexico',
#  'city',
#  'kills',
#  'injures',
#  'former',
#  'school',
#  'district',
#  'employee',
#  'arrested',
#  'multiple',
#  'sexual',
#  'encounters',
#  'students',
#  'uk',
#  'palace',
#  'allies',
#  'fire',
#  'back',
#  'bombshell',
#  'claims',
#  'tell',
#  'book',
#  'damar',
#  'hamlin',
#  'recovery',
#  'shows',
#  'seeing',
#  'god',
#  'answer',
#  'prayer',
#  'real',
#  'time',
#  'jessie',
#  'james',
#  'decker',
#  'lifts',
#  'former',
#  'nfl',
#  'star',
#  'husband',
#  'eric',
#  'decker',
#  'pda',
#  'filled',
#  'video',
#  'like',
#  'big',
#  'boys',
#  'documents',
#  'reveal',
#  'gruesome',
#  'details',
#  'college',
#  'students',
#  'slain',
#  'mccarthy',
#  'thanks',
#  'trump',
#  'house',
#  'speaker',
#  'vote',
#  'beginning',
#  'democrats',
#  'pushing',
#  'agenda',
#  'socialism',
#  'communism',
#  'lt',
#  'gov',
#  'mark',
#  'robinson',
#  'fox',
#  'news',
#  'night',
#  'friday',
#  'january',
#  'kfc',
#  'christmas',
#  'fast',
#  'food',
#  'chain',
#  'became',
#  'holiday',
#  'hit',
#  'japan',
#  'idaho',
#  'murder',
#  'suspect',
#  'explain',
#  'evidence',
#  'crime',
#  'analyst',
#  'sheryl',
#  'mccollum',
#  'america',
#  'new',
#  'b',
#  'raider',
#  'big',
#  'secrets',
#  'china',
#  'wants',
#  'steal',
#  'air',
#  'fryer',
#  'turkey',
#  'dinner',
#  'try',
#  'recipe',
#  'damar',
#  'hamlin',
#  'life',
#  'saving',
#  'cpr',
#  'cardiac',
#  'arrest',
#  'perform',
#  'cpr',
#  'without',
#  'training',
#  'house',
#  'speaker',
#  'drama',
#  'democrat',
#  'reads',
#  'subtle',
#  'art',
#  'giving',
#  'f',
#  'k',
#  'book',
#  'floor',
#  'jan',
#  'committee',
#  'releases',
#  'social',
#  'security',
#  'numbers',
#  'trump',
#  'officials',
#  'allies',
#  'report',
#  'federal',
#  'court',
#  'strikes',
#  'trump',
#  'era',
#  'bump',
#  'stock',
#  'ban',
#  'border',
#  'message',
#  'president',
#  'biden',
#  'arkansas',
#  'monastery',
#  'desecrated',
#  'sledgehammer',
#  'relics',
#  'stolen',
#  'suspect',
#  'arrested',
#  'derailing',
#  'america',
#  'dangerous',
#  'law',
#  'sheriff',
#  'hopes',
#  'illinois',
#  'supreme',
#  'court',
#  'upholds',
#  'safe',
#  'act',
#  'decision',
#  'museum',
#  'modern',
#  'art',
#  'stabbing',
#  'suspect',
#  'extradited',
#  'new',
#  'york',
#  'indicted',
#  'attempted',
#  'murder',
#  'teen',
#  'pilot',
#  'flying',
#  'family',
#  'breakfast',
#  'makes',
#  'emergency',
#  'landing',
#  'ca',
#  'highway',
#  'grandma',
#  'crying',
#  'back',
#  'anne',
#  'heche',
#  'son',
#  'homer',
#  'laffoon',
#  'thanks',
#  'fans',
#  'love',
#  'care',
#  'support',
#  'amid',
#  'late',
#  'star',
#  'memoir',
#  'release',
#  'victor',
#  'davis',
#  'hanson',
#  'lays',
#  'plan',
#  'better',
#  'america',
#  'market',
#  'expert',
#  'gives',
#  'grim',
#  'prediction',
#  'first',
#  'months',
#  'fda',
#  'accelerates',
#  'approval',
#  'alzheimer',
#  'drug',
#  'ingraham',
#  'angle',
#  'friday',
#  'january',
#  'irs',
#  'targeted',
#  'poorest',
#  'taxpayers',
#  'millionaires',
#  'went',
#  'mostly',
#  'unscathed',
#  'report',
#  'holiday',
#  'gifts',
#  'last',
#  'minute',
#  'christmas',
#  'shopping',
#  'american',
#  'made',
#  'feeding',
#  'america',
#  'ceo',
#  'asks',
#  'community',
#  'help',
#  'others',
#  'amid',
#  'today',
#  'high',
#  'inflation',
#  'journal',
#  'editorial',
#  'report',
#  'saturday',
#  'january',
#  'damar',
#  'hamlin',
#  'college',
#  'teammate',
#  'recovers',
#  'fumble',
#  'right',
#  'bills',
#  'safety',
#  'number',
#  'painted',
#  'field',
#  'china',
#  'acts',
#  'covid',
#  'policy',
#  'critics',
#  'suspends',
#  'social',
#  'media',
#  'accounts',
#  'tension',
#  'vatican',
#  'revealed',
#  'top',
#  'aide',
#  'following',
#  'death',
#  'benedict',
#  'xvi',
#  'dickens',
#  'christmas',
#  'carol',
#  'could',
#  'help',
#  'americans',
#  'revitalize',
#  'spirit',
#  'unlock',
#  'apple',
#  'device',
#  'owner',
#  'dies',
#  'rod',
#  'stewart',
#  'says',
#  'farewell',
#  'late',
#  'brother',
#  'bob',
#  'losing',
#  'eldest',
#  'sibling',
#  'two',
#  'best',
#  'mates',
#  'gone',
#  'december',
#  'jobs',
#  'report',
#  'real',
#  'numbers',
#  'anemic',
#  'robust',
#  'americans',
#  'wary',
#  'parents',
#  'raise',
#  'awareness',
#  'importance',
#  'defibrillation',
#  'police',
#  'provide',
#  'update',
#  'search',
#  'mom',
#  'vanished',
#  'greeks',
#  'celebrate',
#  'epiphany',
#  'blessings',
#  'water',
#  'years',
#  'covid',
#  'restrictions',
#  'new',
#  'jersey',
#  'beach',
#  'town',
#  'sues',
#  'state',
#  'million',
#  'dune',
#  'issue',
#  'yoke',
#  'tesla',
#  'brings',
#  'back',
#  'round',
#  'steering',
#  'wheels',
#  'connecticut',
#  'community',
#  'rallies',
#  'together',
#  'christmas',
#  'food',
#  'donations',
#  'stolen',
#  'like',
#  'hallmark',
#  'movie',
#  'one',
#  'line',
#  'mccarthy',
#  'speech',
#  'brings',
#  'gop',
#  'uproar',
#  'leaves',
#  'dems',
#  'silent',
#  'texas',
#  'mayor',
#  'speaks',
#  'biden',
#  'anticipated',
#  'visit',
#  'border',
#  'jaguars',
#  'late',
#  'scoop',
#  'score',
#  'clinches',
#  'afc',
#  'south',
#  'titans',
#  'dem',
#  'lawmaker',
#  'sends',
#  'subtle',
#  'message',
#  'book',
#  'house',
#  'floor',
#  'insurrection',
#  'platform',
#  'former',
#  'congressman',
#  'panics',
#  'republican',
#  'lawmakers',
#  'investigating',
#  'federal',
#  'agencies',
#  'kentucky',
#  'gov',
#  'andy',
#  'beshear',
#  'chosen',
#  'co',
#  'chair',
#  'appalachian',
#  'regional',
#  'commission',
#  'safety',
#  'tips',
#  'deep',
#  'frying',
#  'thanksgiving',
#  'turkey',
#  'mccarthy',
#  'vows',
#  'investigate',
#  'border',
#  'crisis',
#  'covid',
#  'origins',
#  'annual',
#  'report',
#  'says',
#  'maine',
#  'child',
#  'welfare',
#  'system',
#  'needs',
#  'improvements',
#  'reddit',
#  'user',
#  'asks',
#  'wrong',
#  'wear',
#  'colossally',
#  'large',
#  'engagement',
#  'ring',
#  'relative',
#  'engagement',
#  'party',
#  'white',
#  'house',
#  'hopeful',
#  'war',
#  'china',
#  'taiwan',
#  'never',
#  'comes',
#  'pass',
#  'report',
#  'american',
#  'airlines',
#  'drops',
#  'cities',
#  'service',
#  'blaming',
#  'pilot',
#  'shortage',
#  'soft',
#  'demand',
#  'biden',
#  'administration',
#  'unveils',
#  'defense',
#  'student',
#  'loan',
#  'forgiveness',
#  'plan',
#  'supreme',
#  'court',
#  'chiefs',
#  'one',
#  'kind',
#  'huddle',
#  'results',
#  'bizarre',
#  'touchdown',
#  'gets',
#  'called',
#  'back',
#  'snow',
#  'us',
#  'approaches',
#  'midpoint',
#  'meteorological',
#  'winter',
#  'personal',
#  'freedoms',
#  'mysterious',
#  'dodge',
#  'challenger',
#  'black',
#  'ghost',
#  'auction',
#  'worth',
#  'fortune',
#  'biden',
#  'signs',
#  'bills',
#  'improve',
#  'water',
#  'access',
#  'arizona',
#  'tribes',
#  'digital',
#  'originals',
#  'winning',
#  'numbers',
#  'friday',
#  'mega',
#  'millions',
#  'drawing',
#  'arrest',
#  'ashli',
#  'babbitt',
#  'mom',
#  'jan',
#  'anniversary',
#  'smell',
#  'right',
#  'widower',
#  'political',
#  'cartoons',
#  'day',
#  'national',
#  'spaghetti',
#  'day',
#  'look',
#  'history',
#  'dish',
#  'homeowner',
#  'shoots',
#  'suspected',
#  'intruder',
#  'holds',
#  'gunpoint',
#  'deputies',
#  'arrive',
#  'watch',
#  'hawaii',
#  'kilauea',
#  'volcano',
#  'eruption',
#  'patrick',
#  'mahomes',
#  'sets',
#  'nfl',
#  'record',
#  'chiefs',
#  'clinch',
#  'afc',
#  'top',
#  'seed',
#  'bye',
#  'week',
#  'win',
#  'raiders',
#  'fonda',
#  'got',
#  'weak',
#  'knees',
#  'meeting',
#  'nfl',
#  'legend',
#  'hold',
#  'tsa',
#  'says',
#  'passenger',
#  'attempted',
#  'bring',
#  'emotional',
#  'support',
#  'boa',
#  'constrictor',
#  'snake',
#  'security',
#  'lawyer',
#  'surviving',
#  'idaho',
#  'roommate',
#  'details',
#  'told',
#  'police',
#  'horrific',
#  'night',
#  'murders',
#  'van',
#  'gogh',
#  'one',
#  'eared',
#  'dog',
#  'desperate',
#  'need',
#  'new',
#  'home',
#  'paints',
#  'way',
#  'adoption',
#  'chick',
#  'fil',
#  'urges',
#  'customers',
#  'take',
#  'action',
#  'investigates',
#  'fraudulent',
#  'activity',
#  'mobile',
#  'app',
#  'accounts',
#  'big',
#  'saturday',
#  'show',
#  'saturday',
#  'january',
#  'noem',
#  'touts',
#  'south',
#  'dakota',
#  'conservative',
#  'successes',
#  'bring',
#  'hope',
#  'rest',
#  'country',
#  'jane',
#  'fonda',
#  'says',
#  'knees',
#  'gave',
#  'way',
#  'met',
#  'gorgeous',
#  'tom',
#  'brady',
#  'hold',
#  'onto',
#  'something',
#  'hiker',
#  'found',
#  'dead',
#  'texas',
#  'national',
#  'park',
#  'high',
#  'wind',
#  'warning',
#  'new',
#  'year',
#  'eve',
#  'mccarthy',
#  'finally',
#  'speaker',
#  'weak',
#  'like',
#  'think',
#  'deploy',
#  'crazy',
#  'boss',
#  'strategy',
#  'rams',
#  'head',
#  'coach',
#  'sean',
#  'mcvay',
#  'weighing',
#  'immediate',
#  'future',
#  'team',
#  'report',
#  'parade',
#  'storms',
#  'pound',
#  'california',
#  'next',
#  'week',
#  'following',
#  'deadly',
#  'bomb',
#  'cyclone',
#  'kylie',
#  'jenner',
#  'travis',
#  'scott',
#  'split',
#  'spending',
#  'holidays',
#  'apart',
#  'report',
#  'bataan',
#  'survivor',
#  'remembers',
#  'enduring',
#  'pow',
#  'camps',
#  'god',
#  'sustained',
#  'far',
#  'right',
#  'insurrectionists',
#  'omar',
#  'says',
#  'mccarthy',
#  'deal',
#  'means',
#  'gop',
#  'hold',
#  'americans',
#  'futures',
#  'hostage',
#  'government',
#  'bust',
#  'americans',
#  'weigh',
#  'fight',
#  'elect',
#  'speaker',
#  'house',
#  'sharp',
#  'turn',
#  'concealed',
#  'carry',
#  'holder',
#  'allegedly',
#  'shot',
#  'ax',
#  'wielding',
#  'man',
#  'trying',
#  'help',
#  'wells',
#  'fargo',
#  'vp',
#  'arrested',
#  'fired',
#  'urinating',
#  'airplane',
#  'passenger',
#  'report',
#  'dan',
#  'bongino',
#  'hits',
#  'back',
#  'garbage',
#  'narrative',
#  'house',
#  'speaker',
#  'battle',
#  'glorious',
#  'day',
#  'america',
#  'nfl',
#  'head',
#  'coach',
#  'reportedly',
#  'weighing',
#  'immediate',
#  'future',
#  'team',
#  'little',
#  'late',
#  'border',
#  'residents',
#  'respond',
#  'biden',
#  'first',
#  'ever',
#  'border',
#  'trip',
#  'pledge',
#  'stiffen',
#  'policies',
#  'way',
#  'around',
#  'idaho',
#  'suspect',
#  'dna',
#  'found',
#  'crime',
#  'scene',
#  'jay',
#  'town',
#  'iran',
#  'executes',
#  'men',
#  'detained',
#  'amid',
#  'nationwide',
#  'protests',
#  'four',
#  'seasons',
#  'one',
#  'world',
#  'epic',
#  'stories',
#  'coming',
#  'sunday',
#  'exclusively',
#  'fox',
#  'nation',
#  'oklahoma',
#  'year',
#  'old',
#  'stabs',
#  'year',
#  'old',
#  'brother',
#  'death',
#  'police',
#  'say',
#  'texas',
#  'ranchers',
#  'blast',
#  'biden',
#  'obligatory',
#  'border',
#  'visit',
#  'little',
#  'late',
#  'michigan',
#  'ups',
#  'worker',
#  'born',
#  'preemie',
#  'makes',
#  'warming',
#  'blankets',
#  'babies',
#  'born',
#  'prematurely',
#  'injured',
#  'snowmobiler',
#  'utah',
#  'hoisted',
#  'safety',
#  'accident',
#  'remote',
#  'peak',
#  'texas',
#  'homeowner',
#  'shoots',
#  'suspected',
#  'intruder',
#  'holds',
#  'gunpoint',
#  'deputies',
#  'arrive',
#  'knife',
#  'sheath',
#  'idaho',
#  'murders',
#  'points',
#  'possible',
#  'target',
#  'expert',
#  'billy',
#  'idol',
#  'honored',
#  'star',
#  'hollywood',
#  'walk',
#  'fame',
#  'imagined',
#  'something',
#  'like',
#  'prince',
#  'harry',
#  'details',
#  'losing',
#  'virginity',
#  'older',
#  'woman',
#  'treated',
#  'like',
#  'young',
#  'stallion',
#  'corporate',
#  'kingdom',
#  'desantis',
#  'backed',
#  'plan',
#  'take',
#  'control',
#  'disney',
#  'land',
#  'announced',
#  'ron',
#  'desantis',
#  'activates',
#  'national',
#  'guard',
#  'amid',
#  'migrant',
#  'surge',
#  'florida',
#  'keys',
#  'research',
#  'uncovers',
#  'secret',
#  'ancient',
#  'rome',
#  'baffled',
#  'scientists',
#  'uk',
#  'palace',
#  'allies',
#  'fire',
#  'back',
#  'prince',
#  'harry',
#  'claims',
#  'ahead',
#  'tell',
#  'memoir',
#  'release',
#  'tucker',
#  'carlson',
#  'lies',
#  'january',
#  'enabled',
#  'unscrupulous',
#  'people',
#  'make',
#  'mockery',
#  'bill',
#  'rights',
#  'richard',
#  'branson',
#  'says',
#  'elon',
#  'musk',
#  'surprised',
#  'kitchen',
#  'last',
#  'year',
#  'spaceflight',
#  'day',
#  'history',
#  'jan',
#  'galileo',
#  'discovers',
#  'moons',
#  'jupiter',
#  'new',
#  'terror',
#  'groups',
#  'form',
#  'due',
#  'afghanistan',
#  'withdrawal',
#  'stronger',
#  'limits',
#  'proposed',
#  'control',
#  'deadly',
#  'soot',
#  'pollution',
#  'us',
#  'retired',
#  'nasa',
#  'satellite',
#  'crash',
#  'earth',
#  'sunday',
#  'meet',
#  'american',
#  'invented',
#  'wireless',
#  ...]

# %%
flat_tokens = [item for sublist in stop_tokens_plot for item in sublist] 
flat_tokens
# Out:
# ['subway',
#  'train',
#  'collision',
#  'mexico',
#  'city',
#  'kills',
#  'injures',
#  'former',
#  'school',
#  'district',
#  'employee',
#  'arrested',
#  'multiple',
#  'sexual',
#  'encounters',
#  'students',
#  'uk',
#  'palace',
#  'allies',
#  'fire',
#  'back',
#  'bombshell',
#  'claims',
#  'tell',
#  'book',
#  'damar',
#  'hamlin',
#  'recovery',
#  'shows',
#  'seeing',
#  'god',
#  'answer',
#  'prayer',
#  'real',
#  'time',
#  'jessie',
#  'james',
#  'decker',
#  'lifts',
#  'former',
#  'nfl',
#  'star',
#  'husband',
#  'eric',
#  'decker',
#  'pda',
#  'filled',
#  'video',
#  'like',
#  'big',
#  'boys',
#  'documents',
#  'reveal',
#  'gruesome',
#  'details',
#  'college',
#  'students',
#  'slain',
#  'mccarthy',
#  'thanks',
#  'trump',
#  'house',
#  'speaker',
#  'vote',
#  'beginning',
#  'democrats',
#  'pushing',
#  'agenda',
#  'socialism',
#  'communism',
#  'lt',
#  'gov',
#  'mark',
#  'robinson',
#  'fox',
#  'news',
#  'night',
#  'friday',
#  'january',
#  'kfc',
#  'christmas',
#  'fast',
#  'food',
#  'chain',
#  'became',
#  'holiday',
#  'hit',
#  'japan',
#  'idaho',
#  'murder',
#  'suspect',
#  'explain',
#  'evidence',
#  'crime',
#  'analyst',
#  'sheryl',
#  'mccollum',
#  'america',
#  'new',
#  'b',
#  'raider',
#  'big',
#  'secrets',
#  'china',
#  'wants',
#  'steal',
#  'air',
#  'fryer',
#  'turkey',
#  'dinner',
#  'try',
#  'recipe',
#  'damar',
#  'hamlin',
#  'life',
#  'saving',
#  'cpr',
#  'cardiac',
#  'arrest',
#  'perform',
#  'cpr',
#  'without',
#  'training',
#  'house',
#  'speaker',
#  'drama',
#  'democrat',
#  'reads',
#  'subtle',
#  'art',
#  'giving',
#  'f',
#  'k',
#  'book',
#  'floor',
#  'jan',
#  'committee',
#  'releases',
#  'social',
#  'security',
#  'numbers',
#  'trump',
#  'officials',
#  'allies',
#  'report',
#  'federal',
#  'court',
#  'strikes',
#  'trump',
#  'era',
#  'bump',
#  'stock',
#  'ban',
#  'border',
#  'message',
#  'president',
#  'biden',
#  'arkansas',
#  'monastery',
#  'desecrated',
#  'sledgehammer',
#  'relics',
#  'stolen',
#  'suspect',
#  'arrested',
#  'derailing',
#  'america',
#  'dangerous',
#  'law',
#  'sheriff',
#  'hopes',
#  'illinois',
#  'supreme',
#  'court',
#  'upholds',
#  'safe',
#  'act',
#  'decision',
#  'museum',
#  'modern',
#  'art',
#  'stabbing',
#  'suspect',
#  'extradited',
#  'new',
#  'york',
#  'indicted',
#  'attempted',
#  'murder',
#  'teen',
#  'pilot',
#  'flying',
#  'family',
#  'breakfast',
#  'makes',
#  'emergency',
#  'landing',
#  'ca',
#  'highway',
#  'grandma',
#  'crying',
#  'back',
#  'anne',
#  'heche',
#  'son',
#  'homer',
#  'laffoon',
#  'thanks',
#  'fans',
#  'love',
#  'care',
#  'support',
#  'amid',
#  'late',
#  'star',
#  'memoir',
#  'release',
#  'victor',
#  'davis',
#  'hanson',
#  'lays',
#  'plan',
#  'better',
#  'america',
#  'market',
#  'expert',
#  'gives',
#  'grim',
#  'prediction',
#  'first',
#  'months',
#  'fda',
#  'accelerates',
#  'approval',
#  'alzheimer',
#  'drug',
#  'ingraham',
#  'angle',
#  'friday',
#  'january',
#  'irs',
#  'targeted',
#  'poorest',
#  'taxpayers',
#  'millionaires',
#  'went',
#  'mostly',
#  'unscathed',
#  'report',
#  'holiday',
#  'gifts',
#  'last',
#  'minute',
#  'christmas',
#  'shopping',
#  'american',
#  'made',
#  'feeding',
#  'america',
#  'ceo',
#  'asks',
#  'community',
#  'help',
#  'others',
#  'amid',
#  'today',
#  'high',
#  'inflation',
#  'journal',
#  'editorial',
#  'report',
#  'saturday',
#  'january',
#  'damar',
#  'hamlin',
#  'college',
#  'teammate',
#  'recovers',
#  'fumble',
#  'right',
#  'bills',
#  'safety',
#  'number',
#  'painted',
#  'field',
#  'china',
#  'acts',
#  'covid',
#  'policy',
#  'critics',
#  'suspends',
#  'social',
#  'media',
#  'accounts',
#  'tension',
#  'vatican',
#  'revealed',
#  'top',
#  'aide',
#  'following',
#  'death',
#  'benedict',
#  'xvi',
#  'dickens',
#  'christmas',
#  'carol',
#  'could',
#  'help',
#  'americans',
#  'revitalize',
#  'spirit',
#  'unlock',
#  'apple',
#  'device',
#  'owner',
#  'dies',
#  'rod',
#  'stewart',
#  'says',
#  'farewell',
#  'late',
#  'brother',
#  'bob',
#  'losing',
#  'eldest',
#  'sibling',
#  'two',
#  'best',
#  'mates',
#  'gone',
#  'december',
#  'jobs',
#  'report',
#  'real',
#  'numbers',
#  'anemic',
#  'robust',
#  'americans',
#  'wary',
#  'parents',
#  'raise',
#  'awareness',
#  'importance',
#  'defibrillation',
#  'police',
#  'provide',
#  'update',
#  'search',
#  'mom',
#  'vanished',
#  'greeks',
#  'celebrate',
#  'epiphany',
#  'blessings',
#  'water',
#  'years',
#  'covid',
#  'restrictions',
#  'new',
#  'jersey',
#  'beach',
#  'town',
#  'sues',
#  'state',
#  'million',
#  'dune',
#  'issue',
#  'yoke',
#  'tesla',
#  'brings',
#  'back',
#  'round',
#  'steering',
#  'wheels',
#  'connecticut',
#  'community',
#  'rallies',
#  'together',
#  'christmas',
#  'food',
#  'donations',
#  'stolen',
#  'like',
#  'hallmark',
#  'movie',
#  'one',
#  'line',
#  'mccarthy',
#  'speech',
#  'brings',
#  'gop',
#  'uproar',
#  'leaves',
#  'dems',
#  'silent',
#  'texas',
#  'mayor',
#  'speaks',
#  'biden',
#  'anticipated',
#  'visit',
#  'border',
#  'jaguars',
#  'late',
#  'scoop',
#  'score',
#  'clinches',
#  'afc',
#  'south',
#  'titans',
#  'dem',
#  'lawmaker',
#  'sends',
#  'subtle',
#  'message',
#  'book',
#  'house',
#  'floor',
#  'insurrection',
#  'platform',
#  'former',
#  'congressman',
#  'panics',
#  'republican',
#  'lawmakers',
#  'investigating',
#  'federal',
#  'agencies',
#  'kentucky',
#  'gov',
#  'andy',
#  'beshear',
#  'chosen',
#  'co',
#  'chair',
#  'appalachian',
#  'regional',
#  'commission',
#  'safety',
#  'tips',
#  'deep',
#  'frying',
#  'thanksgiving',
#  'turkey',
#  'mccarthy',
#  'vows',
#  'investigate',
#  'border',
#  'crisis',
#  'covid',
#  'origins',
#  'annual',
#  'report',
#  'says',
#  'maine',
#  'child',
#  'welfare',
#  'system',
#  'needs',
#  'improvements',
#  'reddit',
#  'user',
#  'asks',
#  'wrong',
#  'wear',
#  'colossally',
#  'large',
#  'engagement',
#  'ring',
#  'relative',
#  'engagement',
#  'party',
#  'white',
#  'house',
#  'hopeful',
#  'war',
#  'china',
#  'taiwan',
#  'never',
#  'comes',
#  'pass',
#  'report',
#  'american',
#  'airlines',
#  'drops',
#  'cities',
#  'service',
#  'blaming',
#  'pilot',
#  'shortage',
#  'soft',
#  'demand',
#  'biden',
#  'administration',
#  'unveils',
#  'defense',
#  'student',
#  'loan',
#  'forgiveness',
#  'plan',
#  'supreme',
#  'court',
#  'chiefs',
#  'one',
#  'kind',
#  'huddle',
#  'results',
#  'bizarre',
#  'touchdown',
#  'gets',
#  'called',
#  'back',
#  'snow',
#  'us',
#  'approaches',
#  'midpoint',
#  'meteorological',
#  'winter',
#  'personal',
#  'freedoms',
#  'mysterious',
#  'dodge',
#  'challenger',
#  'black',
#  'ghost',
#  'auction',
#  'worth',
#  'fortune',
#  'biden',
#  'signs',
#  'bills',
#  'improve',
#  'water',
#  'access',
#  'arizona',
#  'tribes',
#  'digital',
#  'originals',
#  'winning',
#  'numbers',
#  'friday',
#  'mega',
#  'millions',
#  'drawing',
#  'arrest',
#  'ashli',
#  'babbitt',
#  'mom',
#  'jan',
#  'anniversary',
#  'smell',
#  'right',
#  'widower',
#  'political',
#  'cartoons',
#  'day',
#  'national',
#  'spaghetti',
#  'day',
#  'look',
#  'history',
#  'dish',
#  'homeowner',
#  'shoots',
#  'suspected',
#  'intruder',
#  'holds',
#  'gunpoint',
#  'deputies',
#  'arrive',
#  'watch',
#  'hawaii',
#  'kilauea',
#  'volcano',
#  'eruption',
#  'patrick',
#  'mahomes',
#  'sets',
#  'nfl',
#  'record',
#  'chiefs',
#  'clinch',
#  'afc',
#  'top',
#  'seed',
#  'bye',
#  'week',
#  'win',
#  'raiders',
#  'fonda',
#  'got',
#  'weak',
#  'knees',
#  'meeting',
#  'nfl',
#  'legend',
#  'hold',
#  'tsa',
#  'says',
#  'passenger',
#  'attempted',
#  'bring',
#  'emotional',
#  'support',
#  'boa',
#  'constrictor',
#  'snake',
#  'security',
#  'lawyer',
#  'surviving',
#  'idaho',
#  'roommate',
#  'details',
#  'told',
#  'police',
#  'horrific',
#  'night',
#  'murders',
#  'van',
#  'gogh',
#  'one',
#  'eared',
#  'dog',
#  'desperate',
#  'need',
#  'new',
#  'home',
#  'paints',
#  'way',
#  'adoption',
#  'chick',
#  'fil',
#  'urges',
#  'customers',
#  'take',
#  'action',
#  'investigates',
#  'fraudulent',
#  'activity',
#  'mobile',
#  'app',
#  'accounts',
#  'big',
#  'saturday',
#  'show',
#  'saturday',
#  'january',
#  'noem',
#  'touts',
#  'south',
#  'dakota',
#  'conservative',
#  'successes',
#  'bring',
#  'hope',
#  'rest',
#  'country',
#  'jane',
#  'fonda',
#  'says',
#  'knees',
#  'gave',
#  'way',
#  'met',
#  'gorgeous',
#  'tom',
#  'brady',
#  'hold',
#  'onto',
#  'something',
#  'hiker',
#  'found',
#  'dead',
#  'texas',
#  'national',
#  'park',
#  'high',
#  'wind',
#  'warning',
#  'new',
#  'year',
#  'eve',
#  'mccarthy',
#  'finally',
#  'speaker',
#  'weak',
#  'like',
#  'think',
#  'deploy',
#  'crazy',
#  'boss',
#  'strategy',
#  'rams',
#  'head',
#  'coach',
#  'sean',
#  'mcvay',
#  'weighing',
#  'immediate',
#  'future',
#  'team',
#  'report',
#  'parade',
#  'storms',
#  'pound',
#  'california',
#  'next',
#  'week',
#  'following',
#  'deadly',
#  'bomb',
#  'cyclone',
#  'kylie',
#  'jenner',
#  'travis',
#  'scott',
#  'split',
#  'spending',
#  'holidays',
#  'apart',
#  'report',
#  'bataan',
#  'survivor',
#  'remembers',
#  'enduring',
#  'pow',
#  'camps',
#  'god',
#  'sustained',
#  'far',
#  'right',
#  'insurrectionists',
#  'omar',
#  'says',
#  'mccarthy',
#  'deal',
#  'means',
#  'gop',
#  'hold',
#  'americans',
#  'futures',
#  'hostage',
#  'government',
#  'bust',
#  'americans',
#  'weigh',
#  'fight',
#  'elect',
#  'speaker',
#  'house',
#  'sharp',
#  'turn',
#  'concealed',
#  'carry',
#  'holder',
#  'allegedly',
#  'shot',
#  'ax',
#  'wielding',
#  'man',
#  'trying',
#  'help',
#  'wells',
#  'fargo',
#  'vp',
#  'arrested',
#  'fired',
#  'urinating',
#  'airplane',
#  'passenger',
#  'report',
#  'dan',
#  'bongino',
#  'hits',
#  'back',
#  'garbage',
#  'narrative',
#  'house',
#  'speaker',
#  'battle',
#  'glorious',
#  'day',
#  'america',
#  'nfl',
#  'head',
#  'coach',
#  'reportedly',
#  'weighing',
#  'immediate',
#  'future',
#  'team',
#  'little',
#  'late',
#  'border',
#  'residents',
#  'respond',
#  'biden',
#  'first',
#  'ever',
#  'border',
#  'trip',
#  'pledge',
#  'stiffen',
#  'policies',
#  'way',
#  'around',
#  'idaho',
#  'suspect',
#  'dna',
#  'found',
#  'crime',
#  'scene',
#  'jay',
#  'town',
#  'iran',
#  'executes',
#  'men',
#  'detained',
#  'amid',
#  'nationwide',
#  'protests',
#  'four',
#  'seasons',
#  'one',
#  'world',
#  'epic',
#  'stories',
#  'coming',
#  'sunday',
#  'exclusively',
#  'fox',
#  'nation',
#  'oklahoma',
#  'year',
#  'old',
#  'stabs',
#  'year',
#  'old',
#  'brother',
#  'death',
#  'police',
#  'say',
#  'texas',
#  'ranchers',
#  'blast',
#  'biden',
#  'obligatory',
#  'border',
#  'visit',
#  'little',
#  'late',
#  'michigan',
#  'ups',
#  'worker',
#  'born',
#  'preemie',
#  'makes',
#  'warming',
#  'blankets',
#  'babies',
#  'born',
#  'prematurely',
#  'injured',
#  'snowmobiler',
#  'utah',
#  'hoisted',
#  'safety',
#  'accident',
#  'remote',
#  'peak',
#  'texas',
#  'homeowner',
#  'shoots',
#  'suspected',
#  'intruder',
#  'holds',
#  'gunpoint',
#  'deputies',
#  'arrive',
#  'knife',
#  'sheath',
#  'idaho',
#  'murders',
#  'points',
#  'possible',
#  'target',
#  'expert',
#  'billy',
#  'idol',
#  'honored',
#  'star',
#  'hollywood',
#  'walk',
#  'fame',
#  'imagined',
#  'something',
#  'like',
#  'prince',
#  'harry',
#  'details',
#  'losing',
#  'virginity',
#  'older',
#  'woman',
#  'treated',
#  'like',
#  'young',
#  'stallion',
#  'corporate',
#  'kingdom',
#  'desantis',
#  'backed',
#  'plan',
#  'take',
#  'control',
#  'disney',
#  'land',
#  'announced',
#  'ron',
#  'desantis',
#  'activates',
#  'national',
#  'guard',
#  'amid',
#  'migrant',
#  'surge',
#  'florida',
#  'keys',
#  'research',
#  'uncovers',
#  'secret',
#  'ancient',
#  'rome',
#  'baffled',
#  'scientists',
#  'uk',
#  'palace',
#  'allies',
#  'fire',
#  'back',
#  'prince',
#  'harry',
#  'claims',
#  'ahead',
#  'tell',
#  'memoir',
#  'release',
#  'tucker',
#  'carlson',
#  'lies',
#  'january',
#  'enabled',
#  'unscrupulous',
#  'people',
#  'make',
#  'mockery',
#  'bill',
#  'rights',
#  'richard',
#  'branson',
#  'says',
#  'elon',
#  'musk',
#  'surprised',
#  'kitchen',
#  'last',
#  'year',
#  'spaceflight',
#  'day',
#  'history',
#  'jan',
#  'galileo',
#  'discovers',
#  'moons',
#  'jupiter',
#  'new',
#  'terror',
#  'groups',
#  'form',
#  'due',
#  'afghanistan',
#  'withdrawal',
#  'stronger',
#  'limits',
#  'proposed',
#  'control',
#  'deadly',
#  'soot',
#  'pollution',
#  'us',
#  'retired',
#  'nasa',
#  'satellite',
#  'crash',
#  'earth',
#  'sunday',
#  'meet',
#  'american',
#  'invented',
#  'wireless',
#  ...]

# %%
pos_lines = list(df[df.label == 1].headline)

pos_tokens = process_text(pos_lines)
pos_freq = nltk.FreqDist(pos_tokens)

pos_freq.most_common(20)
# Out:
# [('new', 13),
#  ('report', 13),
#  ('biden', 13),
#  ('says', 13),
#  ('america', 11),
#  ('house', 9),
#  ('year', 9),
#  ('back', 8),
#  ('like', 8),
#  ('speaker', 8),
#  ('border', 8),
#  ('americans', 8),
#  ('damar', 7),
#  ('hamlin', 7),
#  ('mccarthy', 7),
#  ('christmas', 7),
#  ('amid', 7),
#  ('late', 7),
#  ('help', 7),
#  ('best', 7)]

# %%
y_val = [x[1] for x in pos_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Positive)")
plt.show()

# %%
y_final = []
for i, k, z, t in zip(y_val[0::4], y_val[1::4], y_val[2::4], y_val[3::4]):
    y_final.append(math.log(i + k + z + t))

x_val = [math.log(i + 1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Word Frequency Distribution (Positive)")
plt.plot(x_val, y_final)
plt.show()

# %%
neg_lines = list(df2[df2.label == -1].headline)

neg_tokens = process_text(neg_lines)
neg_freq = nltk.FreqDist(neg_tokens)

neg_freq.most_common(20)
# Out:
# [('new', 19),
#  ('report', 16),
#  ('biden', 16),
#  ('says', 15),
#  ('year', 13),
#  ('back', 12),
#  ('house', 12),
#  ('speaker', 12),
#  ('america', 12),
#  ('border', 11),
#  ('americans', 11),
#  ('damar', 10),
#  ('hamlin', 10),
#  ('like', 10),
#  ('mccarthy', 10),
#  ('idaho', 10),
#  ('former', 9),
#  ('amid', 9),
#  ('police', 9),
#  ('arrested', 8)]

# %%
y_val = [x[1] for x in neg_freq.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Negative)")
plt.show()

# %%
y_final = []
for i, k, z in zip(y_val[0::3], y_val[1::3], y_val[2::3]):
    if i + k + z == 0:
        break
    y_final.append(math.log(i + k + z))

x_val = [math.log(i+1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Word Frequency Distribution (Negative)")
plt.plot(x_val, y_final)
plt.show()

# %%
from nltk.stem import WordNetLemmatizer
ls = WordNetLemmatizer()
stem_tokens = []
for t in flat_tokens:
    lemma = ls.lemmatize(t) 
    stem_tokens.append(lemma)

# %%
stem_tokens
# Out:
# ['subway',
#  'train',
#  'collision',
#  'mexico',
#  'city',
#  'kill',
#  'injures',
#  'former',
#  'school',
#  'district',
#  'employee',
#  'arrested',
#  'multiple',
#  'sexual',
#  'encounter',
#  'student',
#  'uk',
#  'palace',
#  'ally',
#  'fire',
#  'back',
#  'bombshell',
#  'claim',
#  'tell',
#  'book',
#  'damar',
#  'hamlin',
#  'recovery',
#  'show',
#  'seeing',
#  'god',
#  'answer',
#  'prayer',
#  'real',
#  'time',
#  'jessie',
#  'james',
#  'decker',
#  'lift',
#  'former',
#  'nfl',
#  'star',
#  'husband',
#  'eric',
#  'decker',
#  'pda',
#  'filled',
#  'video',
#  'like',
#  'big',
#  'boy',
#  'document',
#  'reveal',
#  'gruesome',
#  'detail',
#  'college',
#  'student',
#  'slain',
#  'mccarthy',
#  'thanks',
#  'trump',
#  'house',
#  'speaker',
#  'vote',
#  'beginning',
#  'democrat',
#  'pushing',
#  'agenda',
#  'socialism',
#  'communism',
#  'lt',
#  'gov',
#  'mark',
#  'robinson',
#  'fox',
#  'news',
#  'night',
#  'friday',
#  'january',
#  'kfc',
#  'christmas',
#  'fast',
#  'food',
#  'chain',
#  'became',
#  'holiday',
#  'hit',
#  'japan',
#  'idaho',
#  'murder',
#  'suspect',
#  'explain',
#  'evidence',
#  'crime',
#  'analyst',
#  'sheryl',
#  'mccollum',
#  'america',
#  'new',
#  'b',
#  'raider',
#  'big',
#  'secret',
#  'china',
#  'want',
#  'steal',
#  'air',
#  'fryer',
#  'turkey',
#  'dinner',
#  'try',
#  'recipe',
#  'damar',
#  'hamlin',
#  'life',
#  'saving',
#  'cpr',
#  'cardiac',
#  'arrest',
#  'perform',
#  'cpr',
#  'without',
#  'training',
#  'house',
#  'speaker',
#  'drama',
#  'democrat',
#  'read',
#  'subtle',
#  'art',
#  'giving',
#  'f',
#  'k',
#  'book',
#  'floor',
#  'jan',
#  'committee',
#  'release',
#  'social',
#  'security',
#  'number',
#  'trump',
#  'official',
#  'ally',
#  'report',
#  'federal',
#  'court',
#  'strike',
#  'trump',
#  'era',
#  'bump',
#  'stock',
#  'ban',
#  'border',
#  'message',
#  'president',
#  'biden',
#  'arkansas',
#  'monastery',
#  'desecrated',
#  'sledgehammer',
#  'relic',
#  'stolen',
#  'suspect',
#  'arrested',
#  'derailing',
#  'america',
#  'dangerous',
#  'law',
#  'sheriff',
#  'hope',
#  'illinois',
#  'supreme',
#  'court',
#  'upholds',
#  'safe',
#  'act',
#  'decision',
#  'museum',
#  'modern',
#  'art',
#  'stabbing',
#  'suspect',
#  'extradited',
#  'new',
#  'york',
#  'indicted',
#  'attempted',
#  'murder',
#  'teen',
#  'pilot',
#  'flying',
#  'family',
#  'breakfast',
#  'make',
#  'emergency',
#  'landing',
#  'ca',
#  'highway',
#  'grandma',
#  'cry',
#  'back',
#  'anne',
#  'heche',
#  'son',
#  'homer',
#  'laffoon',
#  'thanks',
#  'fan',
#  'love',
#  'care',
#  'support',
#  'amid',
#  'late',
#  'star',
#  'memoir',
#  'release',
#  'victor',
#  'davis',
#  'hanson',
#  'lay',
#  'plan',
#  'better',
#  'america',
#  'market',
#  'expert',
#  'give',
#  'grim',
#  'prediction',
#  'first',
#  'month',
#  'fda',
#  'accelerates',
#  'approval',
#  'alzheimer',
#  'drug',
#  'ingraham',
#  'angle',
#  'friday',
#  'january',
#  'irs',
#  'targeted',
#  'poorest',
#  'taxpayer',
#  'millionaire',
#  'went',
#  'mostly',
#  'unscathed',
#  'report',
#  'holiday',
#  'gift',
#  'last',
#  'minute',
#  'christmas',
#  'shopping',
#  'american',
#  'made',
#  'feeding',
#  'america',
#  'ceo',
#  'asks',
#  'community',
#  'help',
#  'others',
#  'amid',
#  'today',
#  'high',
#  'inflation',
#  'journal',
#  'editorial',
#  'report',
#  'saturday',
#  'january',
#  'damar',
#  'hamlin',
#  'college',
#  'teammate',
#  'recovers',
#  'fumble',
#  'right',
#  'bill',
#  'safety',
#  'number',
#  'painted',
#  'field',
#  'china',
#  'act',
#  'covid',
#  'policy',
#  'critic',
#  'suspends',
#  'social',
#  'medium',
#  'account',
#  'tension',
#  'vatican',
#  'revealed',
#  'top',
#  'aide',
#  'following',
#  'death',
#  'benedict',
#  'xvi',
#  'dickens',
#  'christmas',
#  'carol',
#  'could',
#  'help',
#  'american',
#  'revitalize',
#  'spirit',
#  'unlock',
#  'apple',
#  'device',
#  'owner',
#  'dy',
#  'rod',
#  'stewart',
#  'say',
#  'farewell',
#  'late',
#  'brother',
#  'bob',
#  'losing',
#  'eldest',
#  'sibling',
#  'two',
#  'best',
#  'mate',
#  'gone',
#  'december',
#  'job',
#  'report',
#  'real',
#  'number',
#  'anemic',
#  'robust',
#  'american',
#  'wary',
#  'parent',
#  'raise',
#  'awareness',
#  'importance',
#  'defibrillation',
#  'police',
#  'provide',
#  'update',
#  'search',
#  'mom',
#  'vanished',
#  'greek',
#  'celebrate',
#  'epiphany',
#  'blessing',
#  'water',
#  'year',
#  'covid',
#  'restriction',
#  'new',
#  'jersey',
#  'beach',
#  'town',
#  'sue',
#  'state',
#  'million',
#  'dune',
#  'issue',
#  'yoke',
#  'tesla',
#  'brings',
#  'back',
#  'round',
#  'steering',
#  'wheel',
#  'connecticut',
#  'community',
#  'rally',
#  'together',
#  'christmas',
#  'food',
#  'donation',
#  'stolen',
#  'like',
#  'hallmark',
#  'movie',
#  'one',
#  'line',
#  'mccarthy',
#  'speech',
#  'brings',
#  'gop',
#  'uproar',
#  'leaf',
#  'dems',
#  'silent',
#  'texas',
#  'mayor',
#  'speaks',
#  'biden',
#  'anticipated',
#  'visit',
#  'border',
#  'jaguar',
#  'late',
#  'scoop',
#  'score',
#  'clinch',
#  'afc',
#  'south',
#  'titan',
#  'dem',
#  'lawmaker',
#  'sends',
#  'subtle',
#  'message',
#  'book',
#  'house',
#  'floor',
#  'insurrection',
#  'platform',
#  'former',
#  'congressman',
#  'panic',
#  'republican',
#  'lawmaker',
#  'investigating',
#  'federal',
#  'agency',
#  'kentucky',
#  'gov',
#  'andy',
#  'beshear',
#  'chosen',
#  'co',
#  'chair',
#  'appalachian',
#  'regional',
#  'commission',
#  'safety',
#  'tip',
#  'deep',
#  'frying',
#  'thanksgiving',
#  'turkey',
#  'mccarthy',
#  'vow',
#  'investigate',
#  'border',
#  'crisis',
#  'covid',
#  'origin',
#  'annual',
#  'report',
#  'say',
#  'maine',
#  'child',
#  'welfare',
#  'system',
#  'need',
#  'improvement',
#  'reddit',
#  'user',
#  'asks',
#  'wrong',
#  'wear',
#  'colossally',
#  'large',
#  'engagement',
#  'ring',
#  'relative',
#  'engagement',
#  'party',
#  'white',
#  'house',
#  'hopeful',
#  'war',
#  'china',
#  'taiwan',
#  'never',
#  'come',
#  'pas',
#  'report',
#  'american',
#  'airline',
#  'drop',
#  'city',
#  'service',
#  'blaming',
#  'pilot',
#  'shortage',
#  'soft',
#  'demand',
#  'biden',
#  'administration',
#  'unveils',
#  'defense',
#  'student',
#  'loan',
#  'forgiveness',
#  'plan',
#  'supreme',
#  'court',
#  'chief',
#  'one',
#  'kind',
#  'huddle',
#  'result',
#  'bizarre',
#  'touchdown',
#  'get',
#  'called',
#  'back',
#  'snow',
#  'u',
#  'approach',
#  'midpoint',
#  'meteorological',
#  'winter',
#  'personal',
#  'freedom',
#  'mysterious',
#  'dodge',
#  'challenger',
#  'black',
#  'ghost',
#  'auction',
#  'worth',
#  'fortune',
#  'biden',
#  'sign',
#  'bill',
#  'improve',
#  'water',
#  'access',
#  'arizona',
#  'tribe',
#  'digital',
#  'original',
#  'winning',
#  'number',
#  'friday',
#  'mega',
#  'million',
#  'drawing',
#  'arrest',
#  'ashli',
#  'babbitt',
#  'mom',
#  'jan',
#  'anniversary',
#  'smell',
#  'right',
#  'widower',
#  'political',
#  'cartoon',
#  'day',
#  'national',
#  'spaghetti',
#  'day',
#  'look',
#  'history',
#  'dish',
#  'homeowner',
#  'shoot',
#  'suspected',
#  'intruder',
#  'hold',
#  'gunpoint',
#  'deputy',
#  'arrive',
#  'watch',
#  'hawaii',
#  'kilauea',
#  'volcano',
#  'eruption',
#  'patrick',
#  'mahomes',
#  'set',
#  'nfl',
#  'record',
#  'chief',
#  'clinch',
#  'afc',
#  'top',
#  'seed',
#  'bye',
#  'week',
#  'win',
#  'raider',
#  'fonda',
#  'got',
#  'weak',
#  'knee',
#  'meeting',
#  'nfl',
#  'legend',
#  'hold',
#  'tsa',
#  'say',
#  'passenger',
#  'attempted',
#  'bring',
#  'emotional',
#  'support',
#  'boa',
#  'constrictor',
#  'snake',
#  'security',
#  'lawyer',
#  'surviving',
#  'idaho',
#  'roommate',
#  'detail',
#  'told',
#  'police',
#  'horrific',
#  'night',
#  'murder',
#  'van',
#  'gogh',
#  'one',
#  'eared',
#  'dog',
#  'desperate',
#  'need',
#  'new',
#  'home',
#  'paint',
#  'way',
#  'adoption',
#  'chick',
#  'fil',
#  'urge',
#  'customer',
#  'take',
#  'action',
#  'investigates',
#  'fraudulent',
#  'activity',
#  'mobile',
#  'app',
#  'account',
#  'big',
#  'saturday',
#  'show',
#  'saturday',
#  'january',
#  'noem',
#  'tout',
#  'south',
#  'dakota',
#  'conservative',
#  'success',
#  'bring',
#  'hope',
#  'rest',
#  'country',
#  'jane',
#  'fonda',
#  'say',
#  'knee',
#  'gave',
#  'way',
#  'met',
#  'gorgeous',
#  'tom',
#  'brady',
#  'hold',
#  'onto',
#  'something',
#  'hiker',
#  'found',
#  'dead',
#  'texas',
#  'national',
#  'park',
#  'high',
#  'wind',
#  'warning',
#  'new',
#  'year',
#  'eve',
#  'mccarthy',
#  'finally',
#  'speaker',
#  'weak',
#  'like',
#  'think',
#  'deploy',
#  'crazy',
#  'bos',
#  'strategy',
#  'ram',
#  'head',
#  'coach',
#  'sean',
#  'mcvay',
#  'weighing',
#  'immediate',
#  'future',
#  'team',
#  'report',
#  'parade',
#  'storm',
#  'pound',
#  'california',
#  'next',
#  'week',
#  'following',
#  'deadly',
#  'bomb',
#  'cyclone',
#  'kylie',
#  'jenner',
#  'travis',
#  'scott',
#  'split',
#  'spending',
#  'holiday',
#  'apart',
#  'report',
#  'bataan',
#  'survivor',
#  'remembers',
#  'enduring',
#  'pow',
#  'camp',
#  'god',
#  'sustained',
#  'far',
#  'right',
#  'insurrectionist',
#  'omar',
#  'say',
#  'mccarthy',
#  'deal',
#  'mean',
#  'gop',
#  'hold',
#  'american',
#  'future',
#  'hostage',
#  'government',
#  'bust',
#  'american',
#  'weigh',
#  'fight',
#  'elect',
#  'speaker',
#  'house',
#  'sharp',
#  'turn',
#  'concealed',
#  'carry',
#  'holder',
#  'allegedly',
#  'shot',
#  'ax',
#  'wielding',
#  'man',
#  'trying',
#  'help',
#  'well',
#  'fargo',
#  'vp',
#  'arrested',
#  'fired',
#  'urinating',
#  'airplane',
#  'passenger',
#  'report',
#  'dan',
#  'bongino',
#  'hit',
#  'back',
#  'garbage',
#  'narrative',
#  'house',
#  'speaker',
#  'battle',
#  'glorious',
#  'day',
#  'america',
#  'nfl',
#  'head',
#  'coach',
#  'reportedly',
#  'weighing',
#  'immediate',
#  'future',
#  'team',
#  'little',
#  'late',
#  'border',
#  'resident',
#  'respond',
#  'biden',
#  'first',
#  'ever',
#  'border',
#  'trip',
#  'pledge',
#  'stiffen',
#  'policy',
#  'way',
#  'around',
#  'idaho',
#  'suspect',
#  'dna',
#  'found',
#  'crime',
#  'scene',
#  'jay',
#  'town',
#  'iran',
#  'executes',
#  'men',
#  'detained',
#  'amid',
#  'nationwide',
#  'protest',
#  'four',
#  'season',
#  'one',
#  'world',
#  'epic',
#  'story',
#  'coming',
#  'sunday',
#  'exclusively',
#  'fox',
#  'nation',
#  'oklahoma',
#  'year',
#  'old',
#  'stab',
#  'year',
#  'old',
#  'brother',
#  'death',
#  'police',
#  'say',
#  'texas',
#  'rancher',
#  'blast',
#  'biden',
#  'obligatory',
#  'border',
#  'visit',
#  'little',
#  'late',
#  'michigan',
#  'ups',
#  'worker',
#  'born',
#  'preemie',
#  'make',
#  'warming',
#  'blanket',
#  'baby',
#  'born',
#  'prematurely',
#  'injured',
#  'snowmobiler',
#  'utah',
#  'hoisted',
#  'safety',
#  'accident',
#  'remote',
#  'peak',
#  'texas',
#  'homeowner',
#  'shoot',
#  'suspected',
#  'intruder',
#  'hold',
#  'gunpoint',
#  'deputy',
#  'arrive',
#  'knife',
#  'sheath',
#  'idaho',
#  'murder',
#  'point',
#  'possible',
#  'target',
#  'expert',
#  'billy',
#  'idol',
#  'honored',
#  'star',
#  'hollywood',
#  'walk',
#  'fame',
#  'imagined',
#  'something',
#  'like',
#  'prince',
#  'harry',
#  'detail',
#  'losing',
#  'virginity',
#  'older',
#  'woman',
#  'treated',
#  'like',
#  'young',
#  'stallion',
#  'corporate',
#  'kingdom',
#  'desantis',
#  'backed',
#  'plan',
#  'take',
#  'control',
#  'disney',
#  'land',
#  'announced',
#  'ron',
#  'desantis',
#  'activates',
#  'national',
#  'guard',
#  'amid',
#  'migrant',
#  'surge',
#  'florida',
#  'key',
#  'research',
#  'uncovers',
#  'secret',
#  'ancient',
#  'rome',
#  'baffled',
#  'scientist',
#  'uk',
#  'palace',
#  'ally',
#  'fire',
#  'back',
#  'prince',
#  'harry',
#  'claim',
#  'ahead',
#  'tell',
#  'memoir',
#  'release',
#  'tucker',
#  'carlson',
#  'lie',
#  'january',
#  'enabled',
#  'unscrupulous',
#  'people',
#  'make',
#  'mockery',
#  'bill',
#  'right',
#  'richard',
#  'branson',
#  'say',
#  'elon',
#  'musk',
#  'surprised',
#  'kitchen',
#  'last',
#  'year',
#  'spaceflight',
#  'day',
#  'history',
#  'jan',
#  'galileo',
#  'discovers',
#  'moon',
#  'jupiter',
#  'new',
#  'terror',
#  'group',
#  'form',
#  'due',
#  'afghanistan',
#  'withdrawal',
#  'stronger',
#  'limit',
#  'proposed',
#  'control',
#  'deadly',
#  'soot',
#  'pollution',
#  'u',
#  'retired',
#  'nasa',
#  'satellite',
#  'crash',
#  'earth',
#  'sunday',
#  'meet',
#  'american',
#  'invented',
#  'wireless',
#  ...]

# %%
plotfreq(flat_tokens)

# %%
tokens = []

tokenizer = RegexpTokenizer(r'\w+')
for i in saved_text:
    tokens.append(tokenizer.tokenize(i))
flat_tokens = [item for sublist in tokens for item in sublist] #flatten list of lists

# %%
from collections import Counter
my_counter = Counter(flat_tokens)
my_counter.most_common(20)

word_freq = pd.DataFrame(my_counter.most_common(25),
                             columns=['words', 'count'])
word_freq.head()
# Out:
#     words  count
# 0   biden     11
# 1     new     10
# 2  report     10
# 3  border      8
# 4    says      8

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# Plot horizontal bar graph
word_freq.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="brown")
ax.set_title("Common Words Found")
plt.show()
